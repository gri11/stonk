# %% [markdown]
# # How to use PyTorch LSTMs/GRUs for time series regression
# We aim to forcast stock price value by using LSTM with Pytorch.
#
# credit: https://github.com/CrosstabKite/lstm-forecasting/blob/master/lstm_forecasting.ipynb
#
# modified on (12/02/2023)

# %% [markdown]
# # Data

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# !wget https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Out:
# --2024-04-18 11:18:23--  https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv [following]
# --2024-04-18 11:18:24--  https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 284248 (278K) [text/plain]
# Saving to: ‘GOOG.csv’
#
# GOOG.csv            100%[===================>] 277.59K  --.-KB/s    in 0.01s
#
# 2024-04-18 11:18:24 (24.9 MB/s) - ‘GOOG.csv’ saved [284248/284248]

# %%
import pandas as pd

df = pd.read_csv('GOOG.csv', index_col="Date")
df = df.drop(['Adj Close'], axis = 1)
df
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
# 2019-10-04  1191.890015  1211.439941  1189.170044  1209.000000   1021092
#
# [3809 rows x 5 columns]

# %%
df.loc['2019-02-26']
# Out:
# Open      1.105750e+03
# High      1.119510e+03
# Low       1.099920e+03
# Close     1.115130e+03
# Volume    1.471300e+06
# Name: 2019-02-26, dtype: float64

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig = px.line(df['Open'], labels=dict(
    created_at="Date", value="Open", variable="Sensor"
))
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7a5547ad-50cb-4c44-ba49-4e984648456c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a5547ad-50cb-4c44-ba49-4e984648456c")) {                    Plotly.newPlot(                        "7a5547ad-50cb-4c44-ba49-4e984648456c",                        [{"hovertemplate":"Sensor=Open\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08-04","2005-08-05","20 ...

# %% [markdown]
# ## Create the target variable

# %%
target_col = "Open"
features = list(df.columns.difference([target_col]))

forecast_lead = 1
target = f"{target_col}_lead{forecast_lead}"

df[target] = df[target_col].shift(-forecast_lead)
df = df.iloc[:-forecast_lead]

# %%
features
# Out:
# ['Close', 'High', 'Low', 'Volume']

# %%
df
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-27  1243.010010  1244.020020  1214.449951  1225.089966   1353900
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
#
#              Open_lead1
# Date
# 2004-08-19    50.316402
# 2004-08-20    55.168217
# 2004-08-23    55.412300
# 2004-08-24    52.284027
# 2004-08-25    52.279045
# ...                 ...
# 2019-09-27  1220.969971
# 2019-09-30  1219.000000
# 2019-10-01  1196.979980
# 2019-10-02  1180.000000
# 2019-10-03  1191.890015
#
# [3808 rows x 6 columns]

# %% [markdown]
# ## Create a hold-out test set and preprocess the data

# %%
test_start = "2019-01-01"
val_start = "2018-01-01"

df_train = df.loc[:val_start].copy()
df_val = df.loc[val_start:test_start].copy()
df_test = df.loc[test_start:].copy()

print("Test set fraction:", len(df_test) / len(df))
# Out:
# Test set fraction: 0.050157563025210086

# %% [markdown]
# ## Standardize the features and target, based on the training set

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_val[c] = (df_val[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %% [markdown]
# ## Create datasets that PyTorch `DataLoader` can work with

# %%
import torch
from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i):
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %%
i = 27
sequence_length = 4

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)

X, y = train_dataset[i]
print(X)
# Out:
# tensor([[-1.4005, -1.4044, -1.4018,  0.0794],
#         [-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892]])

# %%
X, y = train_dataset[i + 1]
print(X)
# Out:
# tensor([[-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892],
#         [-1.3789, -1.3784, -1.3822,  2.7240]])

# %%
print(df_train[features].iloc[(i - sequence_length + 1): (i + 1)])
# Out:
#                Close      High       Low    Volume
# Date
# 2004-09-23 -1.400509 -1.404409 -1.401750  0.079391
# 2004-09-24 -1.402597 -1.401323 -1.395935  0.150113
# 2004-09-27 -1.405909 -1.408082 -1.400095 -0.097414
# 2004-09-28 -1.387767 -1.394397 -1.394980  1.089247

# %%
from torch.utils.data import DataLoader
torch.manual_seed(99)

train_loader = DataLoader(train_dataset, batch_size=3, shuffle=True)

X, y = next(iter(train_loader))
print(X.shape)
print(X)
# Out:
# torch.Size([3, 4, 4])
# tensor([[[-1.0283e+00, -1.0363e+00, -1.0355e+00,  3.3244e+00],
#          [-1.0139e+00, -1.0227e+00, -1.0264e+00,  3.3321e+00],
#          [-1.0183e+00, -1.0127e+00, -1.0091e+00,  3.6286e+00],
#          [-1.0379e+00, -1.0229e+00, -1.0300e+00,  3.4512e+00]],
#
#         [[-3.0608e-01, -3.1554e-01, -3.1614e-01,  2.0066e+00],
#          [-2.9534e-01, -2.7960e-01, -2.8488e-01,  2.8479e+00],
#          [-2.8260e-01, -2.8693e-01, -2.9963e-01,  6.5448e-01],
#          [-2.2982e-01, -2.3949e-01, -2.4929e-01,  6.8556e-01]],
#
#         [[-4.5368e-03, -1.7926e-03,  1.3788e-03, -4.5791e-01],
#          [-3.9661e-02, -1.2372e-02, -3.4364e-02, -1.4888e-01],
#          [ 3.1979e-02,  2.4656e-02, -2.3751e-02,  4.4746e-01],
#          [ 3.2486e-02,  2.5747e-02, -5.2009e-03, -2.5444e-01]]])

# %% [markdown]
# ## Create the datasets and data loaders for real

# %% [markdown]
# In this tutorial we will
# use sequences of length 60 (60 days) to forcast 1 day ahead.
#
# The PyTorch `DataLoader` is a very convenient way to iterate through these datasets. For
# the training set we'll shuffle (the rows *within* each training sequence are not
# shuffled, only the order in which we draw those blocks). For the test set, shuffling
# isn't necessary.

# %%
torch.manual_seed(101)

batch_size = 32
sequence_length = 60

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([32, 60, 4])
# Target shape: torch.Size([32])

# %%
print(len(features))
# Out:
# 4

# %% [markdown]
# # LSTM

# %% [markdown]
# ## The model and learning algorithm

# %% [markdown]
# ![picture](https://i.stack.imgur.com/SjnTl.png)
#
# Credit : https://stackoverflow.com/questions/48302810/whats-the-difference-between-hidden-and-output-in-pytorch-lstm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionLSTM(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.lstm = nn.LSTM(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        print("batch_size :",batch_size)
        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionLSTM(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))
# Out:
# batch_size : 32
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShallowRegressionLSTM                    [32]                      --
# ├─LSTM: 1-1                              [32, 60, 60]              103,680
# ├─Linear: 1-2                            [32, 1]                   61
# ==========================================================================================
# Total params: 103,741
# Trainable params: 103,741
# Non-trainable params: 0
# Total mult-adds (M): 199.07
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.41
# Estimated Total Size (MB): 1.37
# ==========================================================================================

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    print( num_batches )
    total_loss = 0
    model.train()

    for X, y in data_loader:
        print(X.shape,y.shape)
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0026156753504798166
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.05038839392364025
#
# Epoch 17
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.002442754885260859
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.03341651370283216
# Save new best model
#
# Epoch 18
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.002319909264289616
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.04118284455034882
#
# Epoch 19
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0023114172808215336
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.027682468644343317
# Save new best model
#
# Epoch 20
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0021253071562277225
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.02583468204829842
# Save new best model
#
# Epoch 21
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0021175478979338943
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.03140727570280433
#
# Epoch 22
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0021051455932704485
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.02904213627334684
#
# Epoch 23
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0020204612261501475
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.023221626761369407
# Save new best model
#
# Epoch 24
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# ...
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0010058866772045083
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.019408411520998925
#
# Epoch 37
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0009125575026769613
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.012317766319029033
#
# Epoch 38
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e4896cdb1b59> in <cell line: 2>()
#       2 for ix_epoch in tqdm(range(100)):
#       3     print(f"Epoch {ix_epoch}\n---------")
# ----> 4     train_model(train_loader, model, loss_function, optimizer=optimizer)
#       5     best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
#       6     print()
#
# <ipython-input-24-db160f187ecf> in train_model(data_loader, model, loss_function, optimizer)
#       9         X = X.to(device)
#      10         y = y.to(device)
# ---> 11         output = model(X)
#      12         loss = loss_function(output, y)
#      13
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-20-785fa254084f> in forward(self, x)
#      25
#      26         _, (hn, _) = self.lstm(x, (h0, c0))
# ---> 27         out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
#      28         return out
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model.pth'
model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()

# %% [markdown]
# # GRU

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionGRU(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.gru = nn.GRU(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]

        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, hn = self.gru(x, h0)
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionGRU(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model_gru.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model_gru.pth'
model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_val['Open_lead1'], df_val['Model forecast'])) )

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()

# %% [markdown]
# # ResNLS

# %% [markdown]
# **Data**
#
#
# *   10 consecutive trading days as the unit step
# *   clean
#
#
# *   normalize it to eliminate scale differences
# *   transform it into tensors
#
# **Train** : closing price data of the SSE Composite
# Index from January 1, 2011 to December 31, 2020
#
# **Test** : closing price data from January 1, 2021 to December 31, 2021
#
#
#
# **Conv**
#
#
# *   filter = 64
# *   kernel size = 3
#
# *   applies ReLU as the activation
# function
# *   weight decay of 1e-5
#
# **dropout layer** with a retain probability of 0.8
#
# **LSTM**
#
#
# *   hidden size = 32
#
# **optimizer** Adam
#
# batch size (64) with a larger initial
# learning rate (1e-3) are preferred
#
# epoch = 50

# %% [markdown]
# ## Data

# %% [markdown]
# ### AJ

# %%
val_start = "2016-01-01"
test_start = "2018-01-01"

df_train = df.loc[:val_start].copy()
df_val = df.loc[val_start:test_start].copy()
df_test = df.loc[test_start:].copy()

print("Test set fraction:", len(df_test) / len(df))
# Out:
# Test set fraction: 0.11607142857142858

# %% [markdown]
# ## Other

# %%
import yfinance as yf

# %%
snp = yf.Ticker("^GSPC")

snp_hist = snp.history(start="2016-01-04", end="2022-05-26")

snp_hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-01-04 00:00:00-05:00  2038.199951  2038.199951  1989.680054  2012.660034
# 2016-01-05 00:00:00-05:00  2013.780029  2021.939941  2004.170044  2016.709961
# 2016-01-06 00:00:00-05:00  2011.709961  2011.709961  1979.050049  1990.260010
# 2016-01-07 00:00:00-05:00  1985.319946  1985.319946  1938.829956  1943.089966
# 2016-01-08 00:00:00-05:00  1945.969971  1960.400024  1918.459961  1922.030029
# ...                                ...          ...          ...          ...
# 2022-05-19 00:00:00-04:00  3899.000000  3945.959961  3876.580078  3900.790039
# 2022-05-20 00:00:00-04:00  3927.760010  3943.419922  3810.320068  3901.360107
# 2022-05-23 00:00:00-04:00  3919.419922  3981.879883  3909.040039  3973.750000
# 2022-05-24 00:00:00-04:00  3942.939941  3955.679932  3875.129883  3941.479980
# 2022-05-25 00:00:00-04:00  3929.590088  3999.330078  3925.030029  3978.729980
#
#                                Volume  Dividends  Stock Splits
# Date
# 2016-01-04 00:00:00-05:00  4304880000        0.0           0.0
# 2016-01-05 00:00:00-05:00  3706620000        0.0           0.0
# 2016-01-06 00:00:00-05:00  4336660000        0.0           0.0
# 2016-01-07 00:00:00-05:00  5076590000        0.0           0.0
# 2016-01-08 00:00:00-05:00  4664940000        0.0           0.0
# ...                               ...        ...           ...
# 2022-05-19 00:00:00-04:00  5113550000        0.0           0.0
# 2022-05-20 00:00:00-04:00  5130730000        0.0           0.0
# 2022-05-23 00:00:00-04:00  4420030000        0.0           0.0
# 2022-05-24 00:00:00-04:00  4923190000        0.0           0.0
# 2022-05-25 00:00:00-04:00  4802560000        0.0           0.0
#
# [1611 rows x 7 columns]

# %%
pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig = px.line(snp_hist['Open'], labels=dict(
    created_at="Date", value="Open", variable="Sensor"
))
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bccf8c8-ed77-49ee-9df0-b414ceb9e7ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bccf8c8-ed77-49ee-9df0-b414ceb9e7ba")) {                    Plotly.newPlot(                        "5bccf8c8-ed77-49ee-9df0-b414ceb9e7ba",                        [{"hovertemplate":"Sensor=Open\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2016-01-04T00:00:00-05:00","2016-01-05T00:00:00-05:00","2016-01-06T00:00:00-05:00","2016-01-07T00:00:00-05:00","2016-01-08T00:00:00-05:00","2016-01-11T00:00:00-05:00","2016-01-12T00:00:00-05:00","2016-01-13T00:00:00-05:00","2016-01-14T00:00:00-05:00","2016-01-15T00:00:00-05:00","2016-01-19T00:00:00-05:00","2016-01-20T00:00:00-05:00","2016-01-21T00:00:00-05:00","2016-01-22T00:00:00-05:00","2016-01-25T00:00:00-05:00","2016-01-26T00:00:00-05:00","2016-01-27T00:00:00-05:00","2016-01-28T00:00:00-05:00","2016-01-29T00:00:00-05:00","2016-02-01T00:00:00-05:00","2016-02-02T00:00:00-05:00","2016-02-03T00:00:00-05:00","2016-02-04T00:00:00-05:00","2016-02-05T00:00:00-05:00","2016-02-08T00:00:00-05:00","2016-02-09T00:00:00-05:00","2016-02-10T00:00:00-05:00","2016-02-11T00:00:00-05:00","2016-02-12T00:00:00-05:00","2016-02-16T00:00:00-05:00","2016-02-17T00:00:00-05:00","2016-02-18T00:00:00-05:00","2016-02-19T00:00:00-05:00","2016-02-22T00:00:00-05:00","2016-02-23T00:00:00-05:00","2016-02-24T00:00:00-05:00","2016-02-25T00:00:00-05:00","2016-02-26T00:00:00-05:00","2016-02-29T00:00:00-05:00","2016-03-01T00:00:00-05:00","2016-03-02T00:00:00-05:00","2016-03-03T00:00:00-05:00","2016-03-04T00:00:00-05:00","2016-03-07T00:00:00-05:00","2016-03-08T00:00:00-05:00","2016-03-09T00:00:00-05:00","2016-03-10T00:00:00-05:00","2016-03-11T00:00:00-05:00","2016-03-14T00:00:00-04:00","2016-03-15T00:00:00-04:00","2016-03-16T00:00:00-04:00","2016-03-17T00:00:00-04:00","2016-03-18T00:00:00-04:00","2016-03-21T00:00:00-04:00","2016-03-22T00:00:00-04:00","2016-03-23T00:00:00-04:00","2016-03-24T00:00:00-04:00","2016-03-28T00:00:00-04:00","2016-03-29T00:00:00-04:00","2016-03-30T00:00:00-04:00","2016-03-31T00:00:00-04:00","2016-04-01T00:00:00-04:00","2016-04-04T00:00:00-04:00","2016-04-05T00:00:00-04:00","2016-04-06T00:00:00-04:00","2016-04-07T00:00:00-04:00","2016-04-08T00:00:00-04:00","2016-04-11T00:00:00-04:00","2016-04-12T00:00:00-04:00","2016-04-13T00:00:00-04:00","2016-04-14T00:00:00-04:00","2016-04-15T00:00:00-04:00","2016-04-18T00:00:00-04:00","2016-04-19T00:00:00-04:00","2016-04-20T00:00:00-04:00","2016-04-21T00:00:00-04:00","2016-04-22T00:00:00-04:00","2016-04-25T00:00:00-04:00","2016-04-26T00:00:00-04:00","2016-04-27T00:00:00-04:00","2016-04-28T00:00:00-04:00","2016-04-29T00:00:00-04:00","2016-05-02T00:00:00-04:00","2016-05-03T00:00:00-04:00","2016-05-04T00:00:00-04:00","2016-05-05T00:00:00-04:00","2016-05-06T00:00:00-04:00","2016-05-09T00:00:00-04:00","2016-05-10T00:00:00-04:00","2016-05-11T00:00:00-04:00","2016-05-12T00:00:00-04:00","2016-05-13T00:00:00-04:00","2016-05-16T00:00:00-04:00","2016-05-17T00:00:00-04:00","2016-05-18T00:00:00-04:00","2016-05-19T00:00:00-04:00","2016-05-20T00:00:00-04:00","2016-05-23T00:00:00-04:00","2016-05-24T00:00:00-04:00","2016-05-25T00:00:00-04:00","2016-05-26T00:00:00-04:00","2016-05-27T00:00:00-04:00","2016-05-31T00:00:00-04:00","2016-06-01T00:00:00-04:00","2016-06-02T00:00:00-04:00","2016-06-03T00:00:00-04:00","2016-06-06T00:00:00-04:00","2016-06-07T00:00:00-04:00","2016-06-08T00:00:00-04:00","2016-06-09T00:00:00-04:00","2016-06-10T00:00:00-04:00","2016-06-13T00:00:00-04:00","2016-06-14T00:00:00-04:00","2016-06-15 ...

# %% [markdown]
# ### Create the target variable

# %%
target_col = "Open"
features = list(snp_hist.columns.difference([target_col]))

forecast_lead = 1
target = f"{target_col}_lead{forecast_lead}"

snp_hist[target] = snp_hist[target_col].shift(-forecast_lead)
snp_hist = snp_hist.iloc[:-forecast_lead]

# %%
snp_hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-01-04 00:00:00-05:00  2038.199951  2038.199951  1989.680054  2012.660034
# 2016-01-05 00:00:00-05:00  2013.780029  2021.939941  2004.170044  2016.709961
# 2016-01-06 00:00:00-05:00  2011.709961  2011.709961  1979.050049  1990.260010
# 2016-01-07 00:00:00-05:00  1985.319946  1985.319946  1938.829956  1943.089966
# 2016-01-08 00:00:00-05:00  1945.969971  1960.400024  1918.459961  1922.030029
# ...                                ...          ...          ...          ...
# 2022-05-18 00:00:00-04:00  4051.979980  4051.979980  3911.909912  3923.679932
# 2022-05-19 00:00:00-04:00  3899.000000  3945.959961  3876.580078  3900.790039
# 2022-05-20 00:00:00-04:00  3927.760010  3943.419922  3810.320068  3901.360107
# 2022-05-23 00:00:00-04:00  3919.419922  3981.879883  3909.040039  3973.750000
# 2022-05-24 00:00:00-04:00  3942.939941  3955.679932  3875.129883  3941.479980
#
#                                Volume  Dividends  Stock Splits   Open_lead1
# Date
# 2016-01-04 00:00:00-05:00  4304880000        0.0           0.0  2013.780029
# 2016-01-05 00:00:00-05:00  3706620000        0.0           0.0  2011.709961
# 2016-01-06 00:00:00-05:00  4336660000        0.0           0.0  1985.319946
# 2016-01-07 00:00:00-05:00  5076590000        0.0           0.0  1945.969971
# 2016-01-08 00:00:00-05:00  4664940000        0.0           0.0  1926.119995
# ...                               ...        ...           ...          ...
# 2022-05-18 00:00:00-04:00  5103220000        0.0           0.0  3899.000000
# 2022-05-19 00:00:00-04:00  5113550000        0.0           0.0  3927.760010
# 2022-05-20 00:00:00-04:00  5130730000        0.0           0.0  3919.419922
# 2022-05-23 00:00:00-04:00  4420030000        0.0           0.0  3942.939941
# 2022-05-24 00:00:00-04:00  4923190000        0.0           0.0  3929.590088
#
# [1610 rows x 8 columns]

# %% [markdown]
# ### Create a hold-out test set and preprocess the data

# %%
snp_hist_val_start = "2018-01-01"
snp_hist_test_start = "2018-06-01"

snp_hist_train = snp_hist.loc[:snp_hist_val_start].copy()
snp_hist_val = snp_hist.loc[snp_hist_val_start:snp_hist_test_start].copy()
snp_hist_test = snp_hist.loc[snp_hist_test_start:].copy()

print("Test set fraction:", len(snp_hist_test) / len(snp_hist))
# Out:
# Test set fraction: 0.6229813664596273

# %% [markdown]
# ## HuggingFace

# %%
# !unzip sp500_daily_ratios_20yrs.zip

# %%
# sp500 = pd.read_csv("sp500_daily_ratios_20yrs.csv")

# %%
# sp500.head()

# %%
# sp500.info()

# %% [markdown]
# ## Standardize the features and target, based on the training set

# %%
def prepData(df_train,df_val,df_test):
  target_mean = df_train[target].mean()
  target_stdev = df_train[target].std()

  for c in df_train.columns:
      mean = df_train[c].mean()
      stdev = df_train[c].std()

      df_train[c] = (df_train[c] - mean) / stdev
      df_val[c] = (df_val[c] - mean) / stdev
      df_test[c] = (df_test[c] - mean) / stdev
  return df_train,df_val,df_test

# %% [markdown]
# ## change dataset here

# %% [markdown]
# aj dataset

# %%
df_train,df_val,df_test = prepData(df_train,df_val,df_test)

# %% [markdown]
# other dataset

# %%
# val_start = snp_hist_val_start
# test_start = snp_hist_test_start
# df_train,df_val,df_test= prepData(snp_hist_train,snp_hist_val,snp_hist_test)

# %%
print(val_start,test_start)
# Out:
# 2016-01-01 2018-01-01

# %%
features = ['Close', 'High', 'Low', 'Volume']

# %% [markdown]
# ## DataLoader

# %%
torch.manual_seed(101)
# aj
# batch_size = 32
# sequence_length = 60

# # best in paper
batch_size = 64
sequence_length = 5

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([64, 5, 4])
# Target shape: torch.Size([64])

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn
from torchinfo import summary

# input = (batch,10,4)
# output = (batch,10,4)
# filter of each conv = 64
# conv1 = (10) -> (64)
# conv2 = (64) -> (64)
# linear = (64) -> (10)
# shortcut = (10) -> (10)
class ResBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, filter, kernel_size=3, stride=1, padding=1):
        super(ResBlock, self).__init__()
        self.conv1 = torch.nn.Conv1d(in_channels, filter, kernel_size, stride, padding)
        self.conv2 = torch.nn.Conv1d(filter, filter, kernel_size, stride, padding)
        self.linear = torch.nn.Linear(filter, out_channels)
        self.relu = torch.nn.ReLU()
        self.bn1 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.bn2 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.dropout = nn.Dropout(0.2)
        # intialise weights of the attention mechanism
        self.weight = nn.Parameter(torch.zeros(1)).to(device)


    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.bn1(out)

        out = self.dropout(out)

        out = self.conv2(out)
        out = self.relu(out)
        out = self.bn2(out)

        out = out.view(out.size(0), -1)
        out = self.linear(out)
        out = self.weight*out
        out += x.view(x.size(0), -1)
        return out

# model = ResBlock(10, 10, 64)
# summary(model, input_size=(1, 10, 1))

# %%
class ResNLS(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_layer, num_layer, num_feature=4, filter=64, kernel_size=3):
        super(ResNLS, self).__init__()
        self.resblock1 = ResBlock(in_channels, in_channels, filter)
        self.resblock2 = ResBlock(in_channels, in_channels, filter)
        self.resblock3 = ResBlock(in_channels, in_channels, filter)
        self.resblock4 = ResBlock(in_channels, in_channels, filter)
        self.num_layers = num_layer
        self.hidden_layer = hidden_layer
        self.lstm = torch.nn.LSTM(num_feature, hidden_layer, num_layer, batch_first=True)
        self.linear = torch.nn.Linear(hidden_layer, out_channels)


    def forward(self, x):
        batch_size = x.size(0)
        out = torch.split(x, 1, 2)
        out1 = self.resblock1(out[0])
        out2 = self.resblock2(out[1])
        out3 = self.resblock3(out[2])
        out4 = self.resblock4(out[3])
        out1 = out1.unsqueeze(2)
        out2 = out2.unsqueeze(2)
        out3 = out3.unsqueeze(2)
        out4 = out4.unsqueeze(2)
        out = torch.cat((out1, out2, out3, out4), 2)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        _, (hn, _) = self.lstm(out, (h0, c0))
        out = self.linear(hn[-1]).flatten()
        return out

# %%
# Init from paper
num_consecutive_days = sequence_length
days_pred = 1
# num_lstm_hiddensize = 32
num_lstm_hiddensize = 64
# lstm_layers = 4 # from aj
# lstm_layers = 64 # from paper
lstm_layers = 1

num_features = len(features)
filters = 64  # Number of filters in convolutional layers
kernel_size = 3  # Kernel size for convolutional layers

model = ResNLS(num_consecutive_days,
               days_pred,
               num_lstm_hiddensize,
               lstm_layers,
               num_features,
               filters,
               kernel_size)
model.to(device)
summary(model, input_size=(batch_size, num_consecutive_days, num_features))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNLS                                   [64]                      --
# ├─ResBlock: 1-1                          [64, 5]                   --
# │    └─Conv1d: 2-1                       [64, 64, 1]               1,024
# │    └─ReLU: 2-2                         [64, 64, 1]               --
# │    └─BatchNorm1d: 2-3                  [64, 64, 1]               128
# │    └─Dropout: 2-4                      [64, 64, 1]               --
# │    └─Conv1d: 2-5                       [64, 64, 1]               12,352
# │    └─ReLU: 2-6                         [64, 64, 1]               --
# │    └─BatchNorm1d: 2-7                  [64, 64, 1]               128
# │    └─Linear: 2-8                       [64, 5]                   325
# ├─ResBlock: 1-2                          [64, 5]                   --
# │    └─Conv1d: 2-9                       [64, 64, 1]               1,024
# │    └─ReLU: 2-10                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-11                 [64, 64, 1]               128
# │    └─Dropout: 2-12                     [64, 64, 1]               --
# │    └─Conv1d: 2-13                      [64, 64, 1]               12,352
# │    └─ReLU: 2-14                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-15                 [64, 64, 1]               128
# │    └─Linear: 2-16                      [64, 5]                   325
# ├─ResBlock: 1-3                          [64, 5]                   --
# │    └─Conv1d: 2-17                      [64, 64, 1]               1,024
# │    └─ReLU: 2-18                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-19                 [64, 64, 1]               128
# │    └─Dropout: 2-20                     [64, 64, 1]               --
# │    └─Conv1d: 2-21                      [64, 64, 1]               12,352
# │    └─ReLU: 2-22                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-23                 [64, 64, 1]               128
# │    └─Linear: 2-24                      [64, 5]                   325
# ├─ResBlock: 1-4                          [64, 5]                   --
# │    └─Conv1d: 2-25                      [64, 64, 1]               1,024
# │    └─ReLU: 2-26                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-27                 [64, 64, 1]               128
# │    └─Dropout: 2-28                     [64, 64, 1]               --
# │    └─Conv1d: 2-29                      [64, 64, 1]               12,352
# │    └─ReLU: 2-30                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-31                 [64, 64, 1]               128
# │    └─Linear: 2-32                      [64, 5]                   325
# ├─LSTM: 1-5                              [64, 5, 64]               17,920
# ├─Linear: 1-6                            [64, 1]                   65
# ==========================================================================================
# Total params: 73,813
# Trainable params: 73,813
# Non-trainable params: 0
# Total mult-adds (M): 9.31
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.70
# Params size (MB): 0.30
# Estimated Total Size (MB): 1.00
# ==========================================================================================

# %%
parameters_to_decay = []
for name, param in model.named_parameters():
  if 'conv1' in name or 'conv2' in name:
        parameters_to_decay.append(param)

weight_decay=1e-5
learning_rate = 1e-3 # Optimizer lr
# optimizer = torch.optim.Adam([{'params': parameters_to_decay, 'weight_decay': weight_decay}], lr=learning_rate)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)

loss_function = nn.MSELoss() # We use Mean Absolute Error (MAE), Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")
    return avg_loss

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss , avg_loss

# %%
best_val_loss = torch.inf
train_losses = []
val_losses = []
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_losses.append(train_model(train_loader, model, loss_function, optimizer=optimizer))
    best_val_loss,avg_loss = test_model(val_loader, model, loss_function, best_val_loss)
    val_losses.append(avg_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 0.39620060804817414
# Test loss: 1.2930511478334665
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.023391995744572746
# Test loss: 1.1888614613562822
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.009060085570025776
# Test loss: 0.7468491760082543
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.0042815632083349755
# Test loss: 0.49912829883396626
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.0032059165778466395
# Test loss: 0.3771549906814471
# Save new best model
#
# Epoch 5
# ---------
# Train loss: 0.003140127467405465
# Test loss: 0.34235030855052173
# Save new best model
#
# Epoch 6
# ---------
# Train loss: 0.0028467796380735105
# Test loss: 0.3102191122015938
# Save new best model
#
# Epoch 7
# ---------
# Train loss: 0.0027202122068653504
# Test loss: 0.297875776712317
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.0027034930367436675
# Test loss: 0.2668632445274852
# Save new best model
#
# Epoch 9
# ---------
# Train loss: 0.0027650460730203326
# Test loss: 0.24296046380186453
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.0025489630591538216
# Test loss: 0.23451220843708143
# Save new best model
#
# Epoch 11
# ---------
# Train loss: 0.0024041159259569314
# Test loss: 0.22085751849226654
# Save new best model
#
# Epoch 12
# ---------
# Train loss: 0.0023559614032920865
# Test loss: 0.21580490353517234
# Save new best model
#
# Epoch 13
# ---------
# Train loss: 0.0022116209962405264
# Test loss: 0.20238991494989023
# Save new best model
#
# Epoch 14
# ---------
# Train loss: 0.002268423879933026
# Test loss: 0.17977430793689564
# Save new best model
#
# Epoch 15
# ---------
# Train loss: 0.002210516875816716
# Test loss: 0.15176059352234006
# Save new best model
#
# Epoch 16
# ---------
# Train loss: 0.0020881837583146988
# Test loss: 0.1598629129002802
#
# Epoch 17
# ---------
# Train loss: 0.0020307921830357775
# Test loss: 0.13573085263487883
# Save new best model
#
# Epoch 18
# ---------
# Train loss: 0.002002791041094396
# Test loss: 0.12778725688986015
# Save new best model
#
# Epoch 19
# ---------
# Train loss: 0.0020419419626705347
# Test loss: 0.11172414425527677
# Save new best model
#
# Epoch 20
# ---------
# Train loss: 0.0020706161559145486
# Test loss: 0.14219720114488155
#
# Epoch 21
# ---------
# Train loss: 0.001938937932977246
# Test loss: 0.11530734092229977
#
# Epoch 22
# ---------
# Train loss: 0.0018169540588537025
# Test loss: 0.1108412955654785
# Save new best model
#
# Epoch 23
# ---------
# Train loss: 0.001749868592661288
# Test loss: 0.09526364598423243
# Save new best model
#
# Epoch 24
# ---------
# Train loss: 0.0018043239381060833
# Test loss: 0.08403361472301185
# Save new best model
#
# Epoch 25
# ---------
# Train loss: 0.0018357226508669555
# Test loss: 0.07289395586121827
# Save new best model
#
# Epoch 26
# ---------
# Train loss: 0.0019130816993614037
# Test loss: 0.07259601156692952
# Save new best model
#
# Epoch 27
# ---------
# Train loss: 0.0017398529065152009
# Test loss: 0.0854012222844176
#
# Epoch 28
# ---------
# Train loss: 0.001804862206336111
# Test loss: 0.07738966478791554
#
# Epoch 29
# ---------
# Train loss: 0.001750337855062551
# Test loss: 0.06473483919398859
# Save new best model
#
# Epoch 30
# ---------
# Train loss: 0.0015544186941244536
# Test loss: 0.06859064614400268
#
# Epoch 31
# ---------
# Train loss: 0.0014944392553944556
# Test loss: 0.07338884883210994
#
# Epoch 32
# ---------
# Train loss: 0.0015068580034292406
# Test loss: 0.06543594901449978
#
# Epoch 33
# ---------
# Train loss: 0.0013951842382084578
# Test loss: 0.06314748240401968
# Save new best model
#
# Epoch 34
# ---------
# Train loss: 0.0014124681539316145
# Test loss: 0.05395389543264173
# Save new best model
#
# Epoch 35
# ---------
# Train loss: 0.001379212676288767
# Test loss: 0.06717711844248697
#
# Epoch 36
# ---------
# Train loss: 0.001370686372845537
# Test loss: 0.046995598037028685
# Save new best model
#
# Epoch 37
# ---------
# Train loss: 0.0013364974551627205
# Test loss: 0.05836066397023387
#
# Epoch 38
# ---------
# Train loss: 0.0014025259568976858
# Test loss: 0.046833880740450695
# Save new best model
#
# Epoch 39
# ---------
# Train loss: 0.0014105373702477664
# Test loss: 0.05959475794225
#
# Epoch 40
# ---------
# Train loss: 0.0012320884490489132
# Test loss: 0.062064683821517974
#
# Epoch 41
# ---------
# Train loss: 0.0012541621192617134
# Test loss: 0.05780696659348905
#
# Epoch 42
# ---------
# Train loss: 0.0012796549501621888
# Test loss: 0.04794885285082273
#
# Epoch 43
# ---------
# Train loss: 0.0011665420335096619
# Test loss: 0.04262017570727039
# Save new best model
#
# Epoch 44
# ---------
# Train loss: 0.001246851746044639
# Test loss: 0.04939355011447333
#
# Epoch 45
# ---------
# Train loss: 0.0011443378668951078
# Test loss: 0.04701698792632669
#
# Epoch 46
# ---------
# Train loss: 0.0010877256417491784
# Test loss: 0.041207676273188554
# Save new best model
#
# Epoch 47
# ---------
# Train loss: 0.0010620767341202333
# Test loss: 0.042948401140165515
#
# Epoch 48
# ---------
# Train loss: 0.001085227924502558
# Test loss: 0.04524554844829254
#
# Epoch 49
# ---------
# Train loss: 0.0010692432542176297
# Test loss: 0.04685184906702489
#
# Epoch 50
# ---------
# Train loss: 0.0010742691261435135
# Test loss: 0.03877493539766874
# Save new best model
#
# Epoch 51
# ---------
# Train loss: 0.0010649578490604958
# Test loss: 0.048783978912979364
#
# Epoch 52
# ---------
# Train loss: 0.0010818005914592908
# Test loss: 0.04189882008358836
#
# Epoch 53
# ---------
# Train loss: 0.0010284722122984628
# Test loss: 0.04778879112564027
#
# Epoch 54
# ---------
# Train loss: 0.0010466478758543315
# Test loss: 0.033533065899973735
# Save new best model
#
# Epoch 55
# ---------
# Train loss: 0.0010995664426849947
# Test loss: 0.04016961986781098
#
# Epoch 56
# ---------
# Train loss: 0.0009506820112518552
# Test loss: 0.03781334208906628
#
# Epoch 57
# ---------
# Train loss: 0.0010592028356364203
# Test loss: 0.04447011789306998
#
# Epoch 58
# ---------
# Train loss: 0.0010600371363883216
# Test loss: 0.040571238670963794
#
# Epoch 59
# ---------
# Train loss: 0.0009249855615457313
# Test loss: 0.03811481506272685
#
# Epoch 60
# ---------
# Train loss: 0.0009382748821129401
# Test loss: 0.037227441353024915
#
# Epoch 61
# ---------
# Train loss: 0.0008929927341846956
# Test loss: 0.03191260177118238
# Save new best model
#
# Epoch 62
# ---------
# Train loss: 0.0010466875320869601
# Test loss: 0.041246594686526805
#
# Epoch 63
# ---------
# Train loss: 0.0009305167057189263
# Test loss: 0.04305024199129548
#
# Epoch 64
# ---------
# Train loss: 0.0009463392573201822
# Test loss: 0.03482045642158482
#
# Epoch 65
# ---------
# Train loss: 0.0008801940547224755
# Test loss: 0.036553783938870765
#
# Epoch 66
# ---------
# Train loss: 0.0008696704494973852
# Test loss: 0.03491541220864747
#
# Epoch 67
# ---------
# Train loss: 0.0011025506427459833
# Test loss: 0.036913369709509425
#
# Epoch 68
# ---------
# Train loss: 0.0009239877199029757
# Test loss: 0.033900434253155254
#
# Epoch 69
# ---------
# Train loss: 0.0008458961525724994
# Test loss: 0.03463324565382209
#
# Epoch 70
# ---------
# Train loss: 0.000854312140856766
# Test loss: 0.03526112672989257
#
# Epoch 71
# ---------
# Train loss: 0.0008429989846061087
# Test loss: 0.03032826016715262
# Save new best model
#
# Epoch 72
# ---------
# Train loss: 0.0008487532393903368
# Test loss: 0.029420382845273707
# Save new best model
#
# Epoch 73
# ---------
# Train loss: 0.0008387975921828507
# Test loss: 0.025257904722820967
# Save new best model
#
# Epoch 74
# ---------
# Train loss: 0.000907997231438963
# Test loss: 0.04138584487373009
#
# Epoch 75
# ---------
# Train loss: 0.0008085301753857898
# Test loss: 0.0310236986115342
#
# Epoch 76
# ---------
# Train loss: 0.0008010190704630481
# Test loss: 0.03505062326439656
#
# Epoch 77
# ---------
# Train loss: 0.0008241596537926751
# Test loss: 0.02927356935106218
#
# Epoch 78
# ---------
# Train loss: 0.0008055626553767878
# Test loss: 0.041528249537805095
#
# Epoch 79
# ---------
# Train loss: 0.0008392706494002293
# Test loss: 0.030207036499632522
#
# Epoch 80
# ---------
# Train loss: 0.0008932304659133984
# Test loss: 0.03817620311747305
#
# Epoch 81
# ---------
# Train loss: 0.0008762845889173655
# Test loss: 0.03490126281394623
#
# Epoch 82
# ---------
# Train loss: 0.000794700897919635
# Test loss: 0.024669875114341266
# Save new best model
#
# Epoch 83
# ---------
# Train loss: 0.0007807026633397779
# Test loss: 0.029516811424400657
#
# Epoch 84
# ---------
# Train loss: 0.0007986176587615369
# Test loss: 0.022246594111493323
# Save new best model
#
# Epoch 85
# ---------
# Train loss: 0.0007600398870029798
# Test loss: 0.028867166402051225
#
# Epoch 86
# ---------
# Train loss: 0.0007870988635760214
# Test loss: 0.03516401309752837
#
# Epoch 87
# ---------
# Train loss: 0.0007734443219507941
# Test loss: 0.023832946593756787
#
# Epoch 88
# ---------
# Train loss: 0.0008251169580034912
# Test loss: 0.03129584153066389
#
# Epoch 89
# ---------
# Train loss: 0.0007935617684981682
# Test loss: 0.021671473441529088
# Save new best model
#
# Epoch 90
# ---------
# Train loss: 0.000759406621930086
# Test loss: 0.021293049278028775
# Save new best model
#
# Epoch 91
# ---------
# Train loss: 0.0007772110687154863
# Test loss: 0.023062375898007303
#
# Epoch 92
# ---------
# Train loss: 0.0007639690842350117
# Test loss: 0.019887755886884406
# Save new best model
#
# Epoch 93
# ---------
# Train loss: 0.0008084847349285458
# Test loss: 0.020053165033459663
#
# Epoch 94
# ---------
# Train loss: 0.0007484795276670613
# Test loss: 0.01950182118889643
# Save new best model
#
# Epoch 95
# ---------
# Train loss: 0.0007713656235460399
# Test loss: 0.025320801927591674
#
# Epoch 96
# ---------
# Train loss: 0.0007766765639341126
# Test loss: 0.01898779912153259
# Save new best model
#
# Epoch 97
# ---------
# Train loss: 0.0007539178616651852
# Test loss: 0.01834268525999505
# Save new best model
#
# Epoch 98
# ---------
# Train loss: 0.000796223791096256
# Test loss: 0.018540998309617862
#
# Epoch 99
# ---------
# Train loss: 0.0009039456859075774
# Test loss: 0.023204678742331453

# %% [markdown]
# ## Eval

# %% [markdown]
# ### train loss / val loss

# %%
import matplotlib.pyplot as plt
def plotLosses(train_loss,val_loss):
  plt.figure(figsize=(30, 10))
  plt.plot(train_loss,color="blue",label="train loss")
  plt.plot(val_loss,color="red",label="val loss")
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend()
  plt.show()

plotLosses(train_losses,val_losses)

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            print(X)
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
# PATH = './model_gru.pth'
# model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

for c in df_test.columns:
    df_test[c] = df_test[c] * target_stdev + target_mean

print(df_out)
# Out:
# tensor([[[-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746]],
#
#         [[-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7010, -1.7086, -1.7176,  1.6217]],
#
#         [[-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7271, -1.7249, -1.7325,  4.1746],
#          [-1.7010, -1.7086, -1.7176,  1.6217],
#          [-1.6975, -1.6943, -1.6894,  1.0862]],
#
#         ...,
#
#         [[-1.5037, -1.4939, -1.5045,  1.5366],
#          [-1.5065, -1.5026, -1.5010,  1.4383],
#          [-1.4569, -1.4661, -1.4969,  2.4530],
#          [-1.4603, -1.4465, -1.4646,  2.8644],
#          [-1.4509, -1.4513, -1.4601,  1.7322]],
#
#         [[-1.5065, -1.5026, -1.5010,  1.4383],
#          [-1.4569, -1.4661, -1.4969,  2.4530],
#          [-1.4603, -1.4465, -1.4646,  2.8644],
#          [-1.4509, -1.4513, -1.4601,  1.7322],
#          [-1.4912, -1.4800, -1.4862,  3.8393]],
#
#         [[-1.4569, -1.4661, -1.4969,  2.4530],
#          [-1.4603, -1.4465, -1.4646,  2.8644],
#          [-1.4509, -1.4513, -1.4601,  1.7322],
#          [-1.4912, -1.4800, -1.4862,  3.8393],
#          [-1.4913, -1.4864, -1.4922,  3.1886]]])
# tensor([[[-1.4603, -1.4465, -1.4646,  2.8644],
#          [-1.4509, -1.4513, -1.4601,  1.7322],
#          [-1.4912, -1.4800, -1.4862,  3.8393],
#          [-1.4913, -1.4864, -1.4922,  3.1886],
#          [-1.5075, -1.4964, -1.5030,  2.8372]],
#
#         [[-1.4509, -1.4513, -1.4601,  1.7322],
#          [-1.4912, -1.4800, -1.4862,  3.8393],
#          [-1.4913, -1.4864, -1.4922,  3.1886],
#          [-1.5075, -1.4964, -1.5030,  2.8372],
#          [-1.5014, -1.5108, -1.5004,  1.0002]],
#
#         [[-1.4912, -1.4800, -1.4862,  3.8393],
#          [-1.4913, -1.4864, -1.4922,  3.1886],
#          [-1.5075, -1.4964, -1.5030,  2.8372],
#          [-1.5014, -1.5108, -1.5004,  1.0002],
#          [-1.5155, -1.5124, -1.5175,  1.8413]],
#
#         ...,
#
#         [[-1.4407, -1.4386, -1.4388,  3.3872],
#          [-1.4426, -1.4383, -1.4361,  2.0161],
#          [-1.4244, -1.4358, -1.4527,  7.9630],
#          [-1.4171, -1.4139, -1.4130,  4.9764],
#          [-1.4067, -1.4155, -1.4090,  2.8145]],
#
#         [[-1.4426, -1.4383, -1.4361,  2.0161],
#          [-1.4244, -1.4358, -1.4527,  7.9630],
#          [-1.4171, -1.4139, -1.4130,  4.9764],
#          [-1.4067, -1.4155, -1.4090,  2.8145],
#          [-1.4083, -1.4142, -1.4007,  1.3847]],
#
#         [[-1.4244, -1.4358, -1.4527,  7.9630],
#          [-1.4171, -1.4139, -1.4130,  4.9764],
#          [-1.4067, -1.4155, -1.4090,  2.8145],
#          [-1.4083, -1.4142, -1.4007,  1.3847],
#          [-1.4082, -1.4171, -1.4012,  0.9340]]])
# tensor([[[-1.4171, -1.4139, -1.4130,  4.9764],
#          [-1.4067, -1.4155, -1.4090,  2.8145],
#          [-1.4083, -1.4142, -1.4007,  1.3847],
#          [-1.4082, -1.4171, -1.4012,  0.9340],
#          [-1.4297, -1.4169, -1.4218,  2.1020]],
#
#         [[-1.4067, -1.4155, -1.4090,  2.8145],
#          [-1.4083, -1.4142, -1.4007,  1.3847],
#          [-1.4082, -1.4171, -1.4012,  0.9340],
#          [-1.4297, -1.4169, -1.4218,  2.1020],
#          [-1.4212, -1.4313, -1.4275,  2.5933]],
#
#         [[-1.4083, -1.4142, -1.4007,  1.3847],
#          [-1.4082, -1.4171, -1.4012,  0.9340],
#          [-1.4297, -1.4169, -1.4218,  2.1020],
#          [-1.4212, -1.4313, -1.4275,  2.5933],
#          [-1.4378, -1.4463, -1.4487,  4.9838]],
#
#         ...,
#
#         [[-1.3059, -1.3124, -1.3004,  0.6838],
#          [-1.3000, -1.3107, -1.2963,  0.2785],
#          [-1.2932, -1.3047, -1.2909,  0.7758],
#          [-1.2735, -1.2836, -1.2800,  1.8282],
#          [-1.2735, -1.2797, -1.2643,  1.2216]],
#
#         [[-1.3000, -1.3107, -1.2963,  0.2785],
#          [-1.2932, -1.3047, -1.2909,  0.7758],
#          [-1.2735, -1.2836, -1.2800,  1.8282],
#          [-1.2735, -1.2797, -1.2643,  1.2216],
#          [-1.2655, -1.2780, -1.2598,  0.8586]],
#
#         [[-1.2932, -1.3047, -1.2909,  0.7758],
#          [-1.2735, -1.2836, -1.2800,  1.8282],
#          [-1.2735, -1.2797, -1.2643,  1.2216],
#          [-1.2655, -1.2780, -1.2598,  0.8586],
#          [-1.2203, -1.2247, -1.2497,  3.9494]]])
# tensor([[[-1.2735, -1.2836, -1.2800,  1.8282],
#          [-1.2735, -1.2797, -1.2643,  1.2216],
#          [-1.2655, -1.2780, -1.2598,  0.8586],
#          [-1.2203, -1.2247, -1.2497,  3.9494],
#          [-1.2185, -1.2008, -1.2142,  5.7383]],
#
#         [[-1.2735, -1.2797, -1.2643,  1.2216],
#          [-1.2655, -1.2780, -1.2598,  0.8586],
#          [-1.2203, -1.2247, -1.2497,  3.9494],
#          [-1.2185, -1.2008, -1.2142,  5.7383],
#          [-1.2028, -1.2153, -1.2237,  3.1710]],
#
#         [[-1.2655, -1.2780, -1.2598,  0.8586],
#          [-1.2203, -1.2247, -1.2497,  3.9494],
#          [-1.2185, -1.2008, -1.2142,  5.7383],
#          [-1.2028, -1.2153, -1.2237,  3.1710],
#          [-1.2081, -1.2063, -1.1985,  2.1167]],
#
#         ...,
#
#         [[-1.1270, -1.1121, -1.1147,  0.8613],
#          [-1.1216, -1.1283, -1.1161,  0.6122],
#          [-1.1234, -1.1322, -1.1139, -0.1417],
#          [-1.1401, -1.1519, -1.1435,  1.7255],
#          [-1.1401, -1.1489, -1.1283,  0.2462]],
#
#         [[-1.1216, -1.1283, -1.1161,  0.6122],
#          [-1.1234, -1.1322, -1.1139, -0.1417],
#          [-1.1401, -1.1519, -1.1435,  1.7255],
#          [-1.1401, -1.1489, -1.1283,  0.2462],
#          [-1.1597, -1.1488, -1.1489,  0.5430]],
#
#         [[-1.1234, -1.1322, -1.1139, -0.1417],
#          [-1.1401, -1.1519, -1.1435,  1.7255],
#          [-1.1401, -1.1489, -1.1283,  0.2462],
#          [-1.1597, -1.1488, -1.1489,  0.5430],
#          [-1.1415, -1.1544, -1.1464,  0.3113]]])
# tensor([[[-1.1401, -1.1519, -1.1435,  1.7255],
#          [-1.1401, -1.1489, -1.1283,  0.2462],
#          [-1.1597, -1.1488, -1.1489,  0.5430],
#          [-1.1415, -1.1544, -1.1464,  0.3113],
#          [-1.1317, -1.1381, -1.1387,  0.9590]],
#
#         [[-1.1401, -1.1489, -1.1283,  0.2462],
#          [-1.1597, -1.1488, -1.1489,  0.5430],
#          [-1.1415, -1.1544, -1.1464,  0.3113],
#          [-1.1317, -1.1381, -1.1387,  0.9590],
#          [-1.1316, -1.1406, -1.1272, -0.0264]],
#
#         [[-1.1597, -1.1488, -1.1489,  0.5430],
#          [-1.1415, -1.1544, -1.1464,  0.3113],
#          [-1.1317, -1.1381, -1.1387,  0.9590],
#          [-1.1316, -1.1406, -1.1272, -0.0264],
#          [-1.1284, -1.1373, -1.1183, -0.1716]],
#
#         ...,
#
#         [[-0.7580, -0.7697, -0.7602,  0.7755],
#          [-0.7716, -0.7736, -0.7621,  0.9665],
#          [-0.7541, -0.7676, -0.7517,  0.9829],
#          [-0.7368, -0.7515, -0.7339,  1.1037],
#          [-0.7474, -0.7493, -0.7328,  0.5927]],
#
#         [[-0.7716, -0.7736, -0.7621,  0.9665],
#          [-0.7541, -0.7676, -0.7517,  0.9829],
#          [-0.7368, -0.7515, -0.7339,  1.1037],
#          [-0.7474, -0.7493, -0.7328,  0.5927],
#          [-0.7175, -0.7315, -0.7537,  1.3662]],
#
#         [[-0.7541, -0.7676, -0.7517,  0.9829],
#          [-0.7368, -0.7515, -0.7339,  1.1037],
#          [-0.7474, -0.7493, -0.7328,  0.5927],
#          [-0.7175, -0.7315, -0.7537,  1.3662],
#          [-0.6943, -0.7077, -0.7118,  1.1934]]])
# tensor([[[-0.7368, -0.7515, -0.7339,  1.1037],
#          [-0.7474, -0.7493, -0.7328,  0.5927],
#          [-0.7175, -0.7315, -0.7537,  1.3662],
#          [-0.6943, -0.7077, -0.7118,  1.1934],
#          [-0.6734, -0.6836, -0.6804,  1.3077]],
#
#         [[-0.7474, -0.7493, -0.7328,  0.5927],
#          [-0.7175, -0.7315, -0.7537,  1.3662],
#          [-0.6943, -0.7077, -0.7118,  1.1934],
#          [-0.6734, -0.6836, -0.6804,  1.3077],
#          [-0.6546, -0.6705, -0.6491,  0.0819]],
#
#         [[-0.7175, -0.7315, -0.7537,  1.3662],
#          [-0.6943, -0.7077, -0.7118,  1.1934],
#          [-0.6734, -0.6836, -0.6804,  1.3077],
#          [-0.6546, -0.6705, -0.6491,  0.0819],
#          [-0.6714, -0.6624, -0.6585,  1.5235]],
#
#         ...,
#
#         [[-0.8576, -0.8710, -0.9149,  3.9324],
#          [-0.8502, -0.8543, -0.8520,  2.2975],
#          [-0.8572, -0.8498, -0.8471,  0.9807],
#          [-0.8608, -0.8647, -0.8512,  0.4643],
#          [-0.8197, -0.8248, -0.8462,  1.8842]],
#
#         [[-0.8502, -0.8543, -0.8520,  2.2975],
#          [-0.8572, -0.8498, -0.8471,  0.9807],
#          [-0.8608, -0.8647, -0.8512,  0.4643],
#          [-0.8197, -0.8248, -0.8462,  1.8842],
#          [-0.8219, -0.8286, -0.8195,  0.4662]],
#
#         [[-0.8572, -0.8498, -0.8471,  0.9807],
#          [-0.8608, -0.8647, -0.8512,  0.4643],
#          [-0.8197, -0.8248, -0.8462,  1.8842],
#          [-0.8219, -0.8286, -0.8195,  0.4662],
#          [-0.7795, -0.7908, -0.7972,  1.3374]]])
# tensor([[[-0.8608, -0.8647, -0.8512,  0.4643],
#          [-0.8197, -0.8248, -0.8462,  1.8842],
#          [-0.8219, -0.8286, -0.8195,  0.4662],
#          [-0.7795, -0.7908, -0.7972,  1.3374],
#          [-0.8702, -0.7719, -0.9346,  8.1676]],
#
#         [[-0.8197, -0.8248, -0.8462,  1.8842],
#          [-0.8219, -0.8286, -0.8195,  0.4662],
#          [-0.7795, -0.7908, -0.7972,  1.3374],
#          [-0.8702, -0.7719, -0.9346,  8.1676],
#          [-0.8631, -0.8631, -0.8596,  1.7696]],
#
#         [[-0.8219, -0.8286, -0.8195,  0.4662],
#          [-0.7795, -0.7908, -0.7972,  1.3374],
#          [-0.8702, -0.7719, -0.9346,  8.1676],
#          [-0.8631, -0.8631, -0.8596,  1.7696],
#          [-0.8250, -0.8253, -0.8567,  3.2347]],
#
#         ...,
#
#         [[-0.8460, -0.8467, -0.8620,  1.6146],
#          [-0.8430, -0.8515, -0.8466,  0.9617],
#          [-0.8278, -0.8162, -0.8193,  1.0502],
#          [-0.8093, -0.8177, -0.8257,  1.1836],
#          [-0.8036, -0.8191, -0.8234,  0.8659]],
#
#         [[-0.8430, -0.8515, -0.8466,  0.9617],
#          [-0.8278, -0.8162, -0.8193,  1.0502],
#          [-0.8093, -0.8177, -0.8257,  1.1836],
#          [-0.8036, -0.8191, -0.8234,  0.8659],
#          [-0.8090, -0.8097, -0.7980, -0.1922]],
#
#         [[-0.8278, -0.8162, -0.8193,  1.0502],
#          [-0.8093, -0.8177, -0.8257,  1.1836],
#          [-0.8036, -0.8191, -0.8234,  0.8659],
#          [-0.8090, -0.8097, -0.7980, -0.1922],
#          [-0.8397, -0.8256, -0.8262, -0.0406]]])
# tensor([[[-0.8093, -0.8177, -0.8257,  1.1836],
#          [-0.8036, -0.8191, -0.8234,  0.8659],
#          [-0.8090, -0.8097, -0.7980, -0.1922],
#          [-0.8397, -0.8256, -0.8262, -0.0406],
#          [-0.8401, -0.8345, -0.8416,  0.8160]],
#
#         [[-0.8036, -0.8191, -0.8234,  0.8659],
#          [-0.8090, -0.8097, -0.7980, -0.1922],
#          [-0.8397, -0.8256, -0.8262, -0.0406],
#          [-0.8401, -0.8345, -0.8416,  0.8160],
#          [-0.8048, -0.8191, -0.8257,  0.4180]],
#
#         [[-0.8090, -0.8097, -0.7980, -0.1922],
#          [-0.8397, -0.8256, -0.8262, -0.0406],
#          [-0.8401, -0.8345, -0.8416,  0.8160],
#          [-0.8048, -0.8191, -0.8257,  0.4180],
#          [-0.8152, -0.8058, -0.8065,  0.4433]],
#
#         ...,
#
#         [[-0.8222, -0.8321, -0.8138, -0.1090],
#          [-0.8190, -0.8312, -0.8151, -0.0761],
#          [-0.8349, -0.8344, -0.8222, -0.1980],
#          [-0.8339, -0.8405, -0.8236, -0.2354],
#          [-0.8354, -0.8440, -0.8228, -0.4728]],
#
#         [[-0.8190, -0.8312, -0.8151, -0.0761],
#          [-0.8349, -0.8344, -0.8222, -0.1980],
#          [-0.8339, -0.8405, -0.8236, -0.2354],
#          [-0.8354, -0.8440, -0.8228, -0.4728],
#          [-0.8103, -0.8257, -0.8146, -0.0761]],
#
#         [[-0.8349, -0.8344, -0.8222, -0.1980],
#          [-0.8339, -0.8405, -0.8236, -0.2354],
#          [-0.8354, -0.8440, -0.8228, -0.4728],
#          [-0.8103, -0.8257, -0.8146, -0.0761],
#          [-0.8168, -0.8213, -0.8073, -0.0069]]])
# tensor([[[-0.8339, -0.8405, -0.8236, -0.2354],
#          [-0.8354, -0.8440, -0.8228, -0.4728],
#          [-0.8103, -0.8257, -0.8146, -0.0761],
#          [-0.8168, -0.8213, -0.8073, -0.0069],
#          [-0.8110, -0.8137, -0.8030, -0.1040]],
#
#         [[-0.8354, -0.8440, -0.8228, -0.4728],
#          [-0.8103, -0.8257, -0.8146, -0.0761],
#          [-0.8168, -0.8213, -0.8073, -0.0069],
#          [-0.8110, -0.8137, -0.8030, -0.1040],
#          [-0.8182, -0.8218, -0.8040, -0.3575]],
#
#         [[-0.8103, -0.8257, -0.8146, -0.0761],
#          [-0.8168, -0.8213, -0.8073, -0.0069],
#          [-0.8110, -0.8137, -0.8030, -0.1040],
#          [-0.8182, -0.8218, -0.8040, -0.3575],
#          [-0.8180, -0.8247, -0.8073, -0.4246]],
#
#         ...,
#
#         [[-0.4375, -0.4443, -0.4275,  0.1484],
#          [-0.3898, -0.4067, -0.4171,  0.9203],
#          [-0.3952, -0.3969, -0.3843,  0.0026],
#          [-0.4050, -0.4148, -0.3902, -0.6443],
#          [-0.4712, -0.4334, -0.4535,  0.6626]],
#
#         [[-0.3898, -0.4067, -0.4171,  0.9203],
#          [-0.3952, -0.3969, -0.3843,  0.0026],
#          [-0.4050, -0.4148, -0.3902, -0.6443],
#          [-0.4712, -0.4334, -0.4535,  0.6626],
#          [-0.4557, -0.4721, -0.4789,  0.7731]],
#
#         [[-0.3952, -0.3969, -0.3843,  0.0026],
#          [-0.4050, -0.4148, -0.3902, -0.6443],
#          [-0.4712, -0.4334, -0.4535,  0.6626],
#          [-0.4557, -0.4721, -0.4789,  0.7731],
#          [-0.4715, -0.4562, -0.4617,  0.4267]]])
# tensor([[[-0.4050, -0.4148, -0.3902, -0.6443],
#          [-0.4712, -0.4334, -0.4535,  0.6626],
#          [-0.4557, -0.4721, -0.4789,  0.7731],
#          [-0.4715, -0.4562, -0.4617,  0.4267],
#          [-0.4710, -0.4703, -0.4640,  0.2543]],
#
#         [[-0.4712, -0.4334, -0.4535,  0.6626],
#          [-0.4557, -0.4721, -0.4789,  0.7731],
#          [-0.4715, -0.4562, -0.4617,  0.4267],
#          [-0.4710, -0.4703, -0.4640,  0.2543],
#          [-0.4841, -0.4768, -0.4741,  0.2669]],
#
#         [[-0.4557, -0.4721, -0.4789,  0.7731],
#          [-0.4715, -0.4562, -0.4617,  0.4267],
#          [-0.4710, -0.4703, -0.4640,  0.2543],
#          [-0.4841, -0.4768, -0.4741,  0.2669],
#          [-0.4709, -0.4800, -0.4713,  0.0959]],
#
#         ...,
#
#         [[-0.5359, -0.5195, -0.5226, -0.1214],
#          [-0.5887, -0.5697, -0.5771,  1.1272],
#          [-0.5865, -0.5896, -0.5907,  0.8280],
#          [-0.5905, -0.5937, -0.6007,  0.9806],
#          [-0.6217, -0.6057, -0.6051,  0.4894]],
#
#         [[-0.5887, -0.5697, -0.5771,  1.1272],
#          [-0.5865, -0.5896, -0.5907,  0.8280],
#          [-0.5905, -0.5937, -0.6007,  0.9806],
#          [-0.6217, -0.6057, -0.6051,  0.4894],
#          [-0.6143, -0.6161, -0.6106,  0.4360]],
#
#         [[-0.5865, -0.5896, -0.5907,  0.8280],
#          [-0.5905, -0.5937, -0.6007,  0.9806],
#          [-0.6217, -0.6057, -0.6051,  0.4894],
#          [-0.6143, -0.6161, -0.6106,  0.4360],
#          [-0.5600, -0.5723, -0.5764,  0.7114]]])
# tensor([[[-0.5905, -0.5937, -0.6007,  0.9806],
#          [-0.6217, -0.6057, -0.6051,  0.4894],
#          [-0.6143, -0.6161, -0.6106,  0.4360],
#          [-0.5600, -0.5723, -0.5764,  0.7114],
#          [-0.5663, -0.5588, -0.5537,  0.4778]],
#
#         [[-0.6217, -0.6057, -0.6051,  0.4894],
#          [-0.6143, -0.6161, -0.6106,  0.4360],
#          [-0.5600, -0.5723, -0.5764,  0.7114],
#          [-0.5663, -0.5588, -0.5537,  0.4778],
#          [-0.5693, -0.5512, -0.5543,  0.2041]],
#
#         [[-0.6143, -0.6161, -0.6106,  0.4360],
#          [-0.5600, -0.5723, -0.5764,  0.7114],
#          [-0.5663, -0.5588, -0.5537,  0.4778],
#          [-0.5693, -0.5512, -0.5543,  0.2041],
#          [-0.5750, -0.5742, -0.5675,  0.1141]],
#
#         ...,
#
#         [[-0.4635, -0.4658, -0.4560,  0.1702],
#          [-0.4259, -0.4429, -0.4593,  0.6442],
#          [-0.4282, -0.4106, -0.4130,  1.0364],
#          [-0.4200, -0.4228, -0.4102,  0.0723],
#          [-0.3983, -0.4050, -0.4113,  0.6103]],
#
#         [[-0.4259, -0.4429, -0.4593,  0.6442],
#          [-0.4282, -0.4106, -0.4130,  1.0364],
#          [-0.4200, -0.4228, -0.4102,  0.0723],
#          [-0.3983, -0.4050, -0.4113,  0.6103],
#          [-0.3598, -0.3774, -0.3816,  1.3923]],
#
#         [[-0.4282, -0.4106, -0.4130,  1.0364],
#          [-0.4200, -0.4228, -0.4102,  0.0723],
#          [-0.3983, -0.4050, -0.4113,  0.6103],
#          [-0.3598, -0.3774, -0.3816,  1.3923],
#          [-0.3617, -0.3717, -0.3531,  0.7939]]])
# tensor([[[-0.4200, -0.4228, -0.4102,  0.0723],
#          [-0.3983, -0.4050, -0.4113,  0.6103],
#          [-0.3598, -0.3774, -0.3816,  1.3923],
#          [-0.3617, -0.3717, -0.3531,  0.7939],
#          [-0.3722, -0.3531, -0.3622,  1.4352]],
#
#         [[-0.3983, -0.4050, -0.4113,  0.6103],
#          [-0.3598, -0.3774, -0.3816,  1.3923],
#          [-0.3617, -0.3717, -0.3531,  0.7939],
#          [-0.3722, -0.3531, -0.3622,  1.4352],
#          [-0.3708, -0.3754, -0.3722,  0.4367]],
#
#         [[-0.3598, -0.3774, -0.3816,  1.3923],
#          [-0.3617, -0.3717, -0.3531,  0.7939],
#          [-0.3722, -0.3531, -0.3622,  1.4352],
#          [-0.3708, -0.3754, -0.3722,  0.4367],
#          [-0.3843, -0.3799, -0.3705,  0.0370]],
#
#         ...,
#
#         [[-0.4004, -0.3905, -0.3843, -0.2841],
#          [-0.3793, -0.3960, -0.3796, -0.4535],
#          [-0.3841, -0.3891, -0.3685, -0.4295],
#          [-0.3715, -0.3856, -0.3656, -0.3534],
#          [-0.3392, -0.3482, -0.3553, -0.1860]],
#
#         [[-0.3793, -0.3960, -0.3796, -0.4535],
#          [-0.3841, -0.3891, -0.3685, -0.4295],
#          [-0.3715, -0.3856, -0.3656, -0.3534],
#          [-0.3392, -0.3482, -0.3553, -0.1860],
#          [-0.3305, -0.3434, -0.3302, -0.2750]],
#
#         [[-0.3841, -0.3891, -0.3685, -0.4295],
#          [-0.3715, -0.3856, -0.3656, -0.3534],
#          [-0.3392, -0.3482, -0.3553, -0.1860],
#          [-0.3305, -0.3434, -0.3302, -0.2750],
#          [-0.3445, -0.3423, -0.3433, -0.2018]]])
# tensor([[[-0.3715, -0.3856, -0.3656, -0.3534],
#          [-0.3392, -0.3482, -0.3553, -0.1860],
#          [-0.3305, -0.3434, -0.3302, -0.2750],
#          [-0.3445, -0.3423, -0.3433, -0.2018],
#          [-0.3581, -0.3702, -0.3481, -0.1930]],
#
#         [[-0.3392, -0.3482, -0.3553, -0.1860],
#          [-0.3305, -0.3434, -0.3302, -0.2750],
#          [-0.3445, -0.3423, -0.3433, -0.2018],
#          [-0.3581, -0.3702, -0.3481, -0.1930],
#          [-0.3740, -0.3675, -0.3676, -0.2953]],
#
#         [[-0.3305, -0.3434, -0.3302, -0.2750],
#          [-0.3445, -0.3423, -0.3433, -0.2018],
#          [-0.3581, -0.3702, -0.3481, -0.1930],
#          [-0.3740, -0.3675, -0.3676, -0.2953],
#          [-0.3517, -0.3688, -0.3516, -0.4174]],
#
#         ...,
#
#         [[ 0.2068,  0.1918,  0.1629,  0.8009],
#          [ 0.2223,  0.2194,  0.2143,  0.4016],
#          [ 0.2092,  0.2462,  0.1957,  0.7960],
#          [ 0.1717,  0.1941,  0.1925, -0.0384],
#          [ 0.1803,  0.1843,  0.1793, -0.0602]],
#
#         [[ 0.2223,  0.2194,  0.2143,  0.4016],
#          [ 0.2092,  0.2462,  0.1957,  0.7960],
#          [ 0.1717,  0.1941,  0.1925, -0.0384],
#          [ 0.1803,  0.1843,  0.1793, -0.0602],
#          [ 0.2272,  0.2068,  0.2135, -0.0654]],
#
#         [[ 0.2092,  0.2462,  0.1957,  0.7960],
#          [ 0.1717,  0.1941,  0.1925, -0.0384],
#          [ 0.1803,  0.1843,  0.1793, -0.0602],
#          [ 0.2272,  0.2068,  0.2135, -0.0654],
#          [ 0.2819,  0.2641,  0.2447,  0.0980]]])
# tensor([[[ 0.1717,  0.1941,  0.1925, -0.0384],
#          [ 0.1803,  0.1843,  0.1793, -0.0602],
#          [ 0.2272,  0.2068,  0.2135, -0.0654],
#          [ 0.2819,  0.2641,  0.2447,  0.0980],
#          [ 0.2806,  0.2688,  0.2891, -0.1490]],
#
#         [[ 0.1803,  0.1843,  0.1793, -0.0602],
#          [ 0.2272,  0.2068,  0.2135, -0.0654],
#          [ 0.2819,  0.2641,  0.2447,  0.0980],
#          [ 0.2806,  0.2688,  0.2891, -0.1490],
#          [ 0.2922,  0.2909,  0.3006, -0.1480]],
#
#         [[ 0.2272,  0.2068,  0.2135, -0.0654],
#          [ 0.2819,  0.2641,  0.2447,  0.0980],
#          [ 0.2806,  0.2688,  0.2891, -0.1490],
#          [ 0.2922,  0.2909,  0.3006, -0.1480],
#          [ 0.2294,  0.2785,  0.2506,  0.3855]],
#
#         ...,
#
#         [[-0.5618, -0.5277, -0.5675,  0.7163],
#          [-0.6024, -0.5906, -0.6146,  2.1343],
#          [-0.5922, -0.5880, -0.5876,  0.6887],
#          [-0.6412, -0.5908, -0.6297,  0.6966],
#          [-0.6391, -0.6340, -0.6460,  0.8372]],
#
#         [[-0.6024, -0.5906, -0.6146,  2.1343],
#          [-0.5922, -0.5880, -0.5876,  0.6887],
#          [-0.6412, -0.5908, -0.6297,  0.6966],
#          [-0.6391, -0.6340, -0.6460,  0.8372],
#          [-0.7036, -0.6632, -0.6894,  0.8175]],
#
#         [[-0.5922, -0.5880, -0.5876,  0.6887],
#          [-0.6412, -0.5908, -0.6297,  0.6966],
#          [-0.6391, -0.6340, -0.6460,  0.8372],
#          [-0.7036, -0.6632, -0.6894,  0.8175],
#          [-0.6179, -0.6335, -0.6512,  1.0137]]])
# tensor([[[-0.6412, -0.5908, -0.6297,  0.6966],
#          [-0.6391, -0.6340, -0.6460,  0.8372],
#          [-0.7036, -0.6632, -0.6894,  0.8175],
#          [-0.6179, -0.6335, -0.6512,  1.0137],
#          [-0.6168, -0.6084, -0.6071,  0.5054]],
#
#         [[-0.6391, -0.6340, -0.6460,  0.8372],
#          [-0.7036, -0.6632, -0.6894,  0.8175],
#          [-0.6179, -0.6335, -0.6512,  1.0137],
#          [-0.6168, -0.6084, -0.6071,  0.5054],
#          [-0.6075, -0.6113, -0.6376,  0.7565]],
#
#         [[-0.7036, -0.6632, -0.6894,  0.8175],
#          [-0.6179, -0.6335, -0.6512,  1.0137],
#          [-0.6168, -0.6084, -0.6071,  0.5054],
#          [-0.6075, -0.6113, -0.6376,  0.7565],
#          [-0.6242, -0.6037, -0.6316,  0.4872]],
#
#         ...,
#
#         [[-0.2015, -0.1777, -0.2040, -0.0431],
#          [-0.1854, -0.1859, -0.1910, -0.2632],
#          [-0.1394, -0.1532, -0.1526, -0.1339],
#          [-0.2025, -0.1770, -0.1829,  0.0572],
#          [-0.2323, -0.2118, -0.2540,  0.1867]],
#
#         [[-0.1854, -0.1859, -0.1910, -0.2632],
#          [-0.1394, -0.1532, -0.1526, -0.1339],
#          [-0.2025, -0.1770, -0.1829,  0.0572],
#          [-0.2323, -0.2118, -0.2540,  0.1867],
#          [-0.2444, -0.2481, -0.2495, -0.1945]],
#
#         [[-0.1394, -0.1532, -0.1526, -0.1339],
#          [-0.2025, -0.1770, -0.1829,  0.0572],
#          [-0.2323, -0.2118, -0.2540,  0.1867],
#          [-0.2444, -0.2481, -0.2495, -0.1945],
#          [-0.2737, -0.2529, -0.2571, -0.1581]]])
# tensor([[[-0.2025, -0.1770, -0.1829,  0.0572],
#          [-0.2323, -0.2118, -0.2540,  0.1867],
#          [-0.2444, -0.2481, -0.2495, -0.1945],
#          [-0.2737, -0.2529, -0.2571, -0.1581],
#          [-0.2484, -0.2508, -0.2491,  0.2342]],
#
#         [[-0.2323, -0.2118, -0.2540,  0.1867],
#          [-0.2444, -0.2481, -0.2495, -0.1945],
#          [-0.2737, -0.2529, -0.2571, -0.1581],
#          [-0.2484, -0.2508, -0.2491,  0.2342],
#          [-0.1877, -0.1933, -0.2016,  0.3961]],
#
#         [[-0.2444, -0.2481, -0.2495, -0.1945],
#          [-0.2737, -0.2529, -0.2571, -0.1581],
#          [-0.2484, -0.2508, -0.2491,  0.2342],
#          [-0.1877, -0.1933, -0.2016,  0.3961],
#          [-0.1835, -0.1823, -0.1846, -0.2213]],
#
#         ...,
#
#         [[-0.5376, -0.5226, -0.5363, -0.0409],
#          [-0.5839, -0.5585, -0.5698,  0.0839],
#          [-0.6035, -0.5935, -0.6005,  0.0105],
#          [-0.6829, -0.5920, -0.6746,  1.0583],
#          [-0.6871, -0.6587, -0.6830,  0.6404]],
#
#         [[-0.5839, -0.5585, -0.5698,  0.0839],
#          [-0.6035, -0.5935, -0.6005,  0.0105],
#          [-0.6829, -0.5920, -0.6746,  1.0583],
#          [-0.6871, -0.6587, -0.6830,  0.6404],
#          [-0.7018, -0.6844, -0.7005,  0.4060]],
#
#         [[-0.6035, -0.5935, -0.6005,  0.0105],
#          [-0.6829, -0.5920, -0.6746,  1.0583],
#          [-0.6871, -0.6587, -0.6830,  0.6404],
#          [-0.7018, -0.6844, -0.7005,  0.4060],
#          [-0.6378, -0.6499, -0.7113,  0.4632]]])
# tensor([[[-0.6829, -0.5920, -0.6746,  1.0583],
#          [-0.6871, -0.6587, -0.6830,  0.6404],
#          [-0.7018, -0.6844, -0.7005,  0.4060],
#          [-0.6378, -0.6499, -0.7113,  0.4632],
#          [-0.6250, -0.6275, -0.6369,  0.3596]],
#
#         [[-0.6871, -0.6587, -0.6830,  0.6404],
#          [-0.7018, -0.6844, -0.7005,  0.4060],
#          [-0.6378, -0.6499, -0.7113,  0.4632],
#          [-0.6250, -0.6275, -0.6369,  0.3596],
#          [-0.6374, -0.6276, -0.6543,  0.4856]],
#
#         [[-0.7018, -0.6844, -0.7005,  0.4060],
#          [-0.6378, -0.6499, -0.7113,  0.4632],
#          [-0.6250, -0.6275, -0.6369,  0.3596],
#          [-0.6374, -0.6276, -0.6543,  0.4856],
#          [-0.6078, -0.6039, -0.6485,  0.5845]],
#
#         ...,
#
#         [[-1.1420, -1.1491, -1.1753,  0.3308],
#          [-1.1586, -1.1422, -1.1640,  0.0928],
#          [-1.1271, -1.1398, -1.1796,  0.4748],
#          [-1.0679, -1.0580, -1.1205,  0.8541],
#          [-1.0553, -1.0302, -1.0711,  0.5610]],
#
#         [[-1.1586, -1.1422, -1.1640,  0.0928],
#          [-1.1271, -1.1398, -1.1796,  0.4748],
#          [-1.0679, -1.0580, -1.1205,  0.8541],
#          [-1.0553, -1.0302, -1.0711,  0.5610],
#          [-1.0460, -1.0402, -1.0464,  0.1747]],
#
#         [[-1.1271, -1.1398, -1.1796,  0.4748],
#          [-1.0679, -1.0580, -1.1205,  0.8541],
#          [-1.0553, -1.0302, -1.0711,  0.5610],
#          [-1.0460, -1.0402, -1.0464,  0.1747],
#          [-1.0740, -1.0468, -1.0685,  0.3949]]])
# tensor([[[-1.0679, -1.0580, -1.1205,  0.8541],
#          [-1.0553, -1.0302, -1.0711,  0.5610],
#          [-1.0460, -1.0402, -1.0464,  0.1747],
#          [-1.0740, -1.0468, -1.0685,  0.3949],
#          [-1.0233, -1.0351, -1.0810,  0.2881]],
#
#         [[-1.0553, -1.0302, -1.0711,  0.5610],
#          [-1.0460, -1.0402, -1.0464,  0.1747],
#          [-1.0740, -1.0468, -1.0685,  0.3949],
#          [-1.0233, -1.0351, -1.0810,  0.2881],
#          [-1.0399, -1.0286, -1.0445,  0.5255]],
#
#         [[-1.0460, -1.0402, -1.0464,  0.1747],
#          [-1.0740, -1.0468, -1.0685,  0.3949],
#          [-1.0233, -1.0351, -1.0810,  0.2881],
#          [-1.0399, -1.0286, -1.0445,  0.5255],
#          [-0.9922, -0.9928, -1.0242,  0.6007]],
#
#         ...,
#
#         [[-1.1045, -1.0673, -1.0960,  0.4632],
#          [-1.0481, -1.0545, -1.0802,  0.5237],
#          [-1.0163, -1.0237, -1.0425,  0.3351],
#          [-0.9979, -1.0074, -1.0164,  0.1249],
#          [-0.9950, -0.9994, -0.9987, -0.1363]],
#
#         [[-1.0481, -1.0545, -1.0802,  0.5237],
#          [-1.0163, -1.0237, -1.0425,  0.3351],
#          [-0.9979, -1.0074, -1.0164,  0.1249],
#          [-0.9950, -0.9994, -0.9987, -0.1363],
#          [-1.0104, -0.9921, -1.0001,  0.1069]],
#
#         [[-1.0163, -1.0237, -1.0425,  0.3351],
#          [-0.9979, -1.0074, -1.0164,  0.1249],
#          [-0.9950, -0.9994, -0.9987, -0.1363],
#          [-1.0104, -0.9921, -1.0001,  0.1069],
#          [-0.9593, -0.9739, -0.9985,  0.0521]]])
# tensor([[[-0.9979, -1.0074, -1.0164,  0.1249],
#          [-0.9950, -0.9994, -0.9987, -0.1363],
#          [-1.0104, -0.9921, -1.0001,  0.1069],
#          [-0.9593, -0.9739, -0.9985,  0.0521],
#          [-0.9666, -0.9587, -0.9690,  0.1222]],
#
#         [[-0.9950, -0.9994, -0.9987, -0.1363],
#          [-1.0104, -0.9921, -1.0001,  0.1069],
#          [-0.9593, -0.9739, -0.9985,  0.0521],
#          [-0.9666, -0.9587, -0.9690,  0.1222],
#          [-0.9770, -0.9717, -0.9712, -0.0884]],
#
#         [[-1.0104, -0.9921, -1.0001,  0.1069],
#          [-0.9593, -0.9739, -0.9985,  0.0521],
#          [-0.9666, -0.9587, -0.9690,  0.1222],
#          [-0.9770, -0.9717, -0.9712, -0.0884],
#          [-0.9762, -0.9815, -0.9746,  0.0580]],
#
#         ...,
#
#         [[-0.6317, -0.6324, -0.6278, -0.2885],
#          [-0.6416, -0.6408, -0.6446, -0.2642],
#          [-0.6533, -0.6543, -0.6390, -0.3796],
#          [-0.6669, -0.6739, -0.6625, -0.3672],
#          [-0.6933, -0.6941, -0.6863, -0.1759]],
#
#         [[-0.6416, -0.6408, -0.6446, -0.2642],
#          [-0.6533, -0.6543, -0.6390, -0.3796],
#          [-0.6669, -0.6739, -0.6625, -0.3672],
#          [-0.6933, -0.6941, -0.6863, -0.1759],
#          [-0.6958, -0.6954, -0.6816, -0.3365]],
#
#         [[-0.6533, -0.6543, -0.6390, -0.3796],
#          [-0.6669, -0.6739, -0.6625, -0.3672],
#          [-0.6933, -0.6941, -0.6863, -0.1759],
#          [-0.6958, -0.6954, -0.6816, -0.3365],
#          [-0.6985, -0.6998, -0.6943, -0.2336]]])
# tensor([[[-0.6669, -0.6739, -0.6625, -0.3672],
#          [-0.6933, -0.6941, -0.6863, -0.1759],
#          [-0.6958, -0.6954, -0.6816, -0.3365],
#          [-0.6985, -0.6998, -0.6943, -0.2336],
#          [-0.7021, -0.7032, -0.6895, -0.3282]],
#
#         [[-0.6933, -0.6941, -0.6863, -0.1759],
#          [-0.6958, -0.6954, -0.6816, -0.3365],
#          [-0.6985, -0.6998, -0.6943, -0.2336],
#          [-0.7021, -0.7032, -0.6895, -0.3282],
#          [-0.6824, -0.6974, -0.6843, -0.0538]],
#
#         [[-0.6958, -0.6954, -0.6816, -0.3365],
#          [-0.6985, -0.6998, -0.6943, -0.2336],
#          [-0.7021, -0.7032, -0.6895, -0.3282],
#          [-0.6824, -0.6974, -0.6843, -0.0538],
#          [-0.7240, -0.7071, -0.7261, -0.0853]],
#
#         ...,
#
#         [[-0.5391, -0.5487, -0.5389, -0.5362],
#          [-0.5163, -0.5335, -0.5284, -0.4569],
#          [-0.5124, -0.5258, -0.5098, -0.6045],
#          [-0.5026, -0.5145, -0.5019, -0.5875],
#          [-0.4947, -0.5076, -0.4931, -0.4888]],
#
#         [[-0.5163, -0.5335, -0.5284, -0.4569],
#          [-0.5124, -0.5258, -0.5098, -0.6045],
#          [-0.5026, -0.5145, -0.5019, -0.5875],
#          [-0.4947, -0.5076, -0.4931, -0.4888],
#          [-0.4596, -0.4737, -0.4741, -0.4450]],
#
#         [[-0.5124, -0.5258, -0.5098, -0.6045],
#          [-0.5026, -0.5145, -0.5019, -0.5875],
#          [-0.4947, -0.5076, -0.4931, -0.4888],
#          [-0.4596, -0.4737, -0.4741, -0.4450],
#          [-0.4484, -0.4477, -0.4456, -0.0015]]])
# tensor([[[-0.5026, -0.5145, -0.5019, -0.5875],
#          [-0.4947, -0.5076, -0.4931, -0.4888],
#          [-0.4596, -0.4737, -0.4741, -0.4450],
#          [-0.4484, -0.4477, -0.4456, -0.0015],
#          [-0.4493, -0.4490, -0.4322, -0.2819]],
#
#         [[-0.4947, -0.5076, -0.4931, -0.4888],
#          [-0.4596, -0.4737, -0.4741, -0.4450],
#          [-0.4484, -0.4477, -0.4456, -0.0015],
#          [-0.4493, -0.4490, -0.4322, -0.2819],
#          [-0.4312, -0.4427, -0.4487, -0.5546]],
#
#         [[-0.4596, -0.4737, -0.4741, -0.4450],
#          [-0.4484, -0.4477, -0.4456, -0.0015],
#          [-0.4493, -0.4490, -0.4322, -0.2819],
#          [-0.4312, -0.4427, -0.4487, -0.5546],
#          [-0.4244, -0.4327, -0.4106, -0.3385]],
#
#         ...,
#
#         [[-0.1305, -0.1491, -0.1284, -0.6330],
#          [-0.1224, -0.1316, -0.1059, -0.6593],
#          [-0.1257, -0.1315, -0.1147, -0.6473],
#          [-0.1086, -0.1231, -0.0987, -0.6021],
#          [-0.1171, -0.1262, -0.1040, -0.5163]],
#
#         [[-0.1224, -0.1316, -0.1059, -0.6593],
#          [-0.1257, -0.1315, -0.1147, -0.6473],
#          [-0.1086, -0.1231, -0.0987, -0.6021],
#          [-0.1171, -0.1262, -0.1040, -0.5163],
#          [-0.1020, -0.1132, -0.0854, -0.3927]],
#
#         [[-0.1257, -0.1315, -0.1147, -0.6473],
#          [-0.1086, -0.1231, -0.0987, -0.6021],
#          [-0.1171, -0.1262, -0.1040, -0.5163],
#          [-0.1020, -0.1132, -0.0854, -0.3927],
#          [-0.1144, -0.1221, -0.0949, -0.4325]]])
# tensor([[[-0.1086, -0.1231, -0.0987, -0.6021],
#          [-0.1171, -0.1262, -0.1040, -0.5163],
#          [-0.1020, -0.1132, -0.0854, -0.3927],
#          [-0.1144, -0.1221, -0.0949, -0.4325],
#          [-0.1063, -0.1179, -0.0908, -0.2239]],
#
#         [[-0.1171, -0.1262, -0.1040, -0.5163],
#          [-0.1020, -0.1132, -0.0854, -0.3927],
#          [-0.1144, -0.1221, -0.0949, -0.4325],
#          [-0.1063, -0.1179, -0.0908, -0.2239],
#          [-0.0990, -0.1149, -0.0886, -0.4483]],
#
#         [[-0.1020, -0.1132, -0.0854, -0.3927],
#          [-0.1144, -0.1221, -0.0949, -0.4325],
#          [-0.1063, -0.1179, -0.0908, -0.2239],
#          [-0.0990, -0.1149, -0.0886, -0.4483],
#          [-0.0910, -0.1095, -0.0782, -0.6097]],
#
#         ...,
#
#         [[-0.2149, -0.2136, -0.2191,  0.0384],
#          [-0.2083, -0.2170, -0.2035, -0.2473],
#          [-0.2072, -0.2071, -0.1920, -0.2730],
#          [-0.2044, -0.2169, -0.1962, -0.6339],
#          [-0.2253, -0.2183, -0.2149,  0.0712]],
#
#         [[-0.2083, -0.2170, -0.2035, -0.2473],
#          [-0.2072, -0.2071, -0.1920, -0.2730],
#          [-0.2044, -0.2169, -0.1962, -0.6339],
#          [-0.2253, -0.2183, -0.2149,  0.0712],
#          [-0.2335, -0.2221, -0.2248, -0.1133]],
#
#         [[-0.2072, -0.2071, -0.1920, -0.2730],
#          [-0.2044, -0.2169, -0.1962, -0.6339],
#          [-0.2253, -0.2183, -0.2149,  0.0712],
#          [-0.2335, -0.2221, -0.2248, -0.1133],
#          [-0.2613, -0.2498, -0.2652,  0.2365]]])
# tensor([[[-0.2044, -0.2169, -0.1962, -0.6339],
#          [-0.2253, -0.2183, -0.2149,  0.0712],
#          [-0.2335, -0.2221, -0.2248, -0.1133],
#          [-0.2613, -0.2498, -0.2652,  0.2365],
#          [-0.2341, -0.2448, -0.2727,  0.4851]],
#
#         [[-0.2253, -0.2183, -0.2149,  0.0712],
#          [-0.2335, -0.2221, -0.2248, -0.1133],
#          [-0.2613, -0.2498, -0.2652,  0.2365],
#          [-0.2341, -0.2448, -0.2727,  0.4851],
#          [-0.2159, -0.2053, -0.2104, -0.1306]],
#
#         [[-0.2335, -0.2221, -0.2248, -0.1133],
#          [-0.2613, -0.2498, -0.2652,  0.2365],
#          [-0.2341, -0.2448, -0.2727,  0.4851],
#          [-0.2159, -0.2053, -0.2104, -0.1306],
#          [-0.2165, -0.2203, -0.2059, -0.4191]],
#
#         ...,
#
#         [[-0.4279, -0.4378, -0.4620, -0.0537],
#          [-0.4172, -0.4262, -0.4161, -0.5142],
#          [-0.4211, -0.4201, -0.4142, -0.5871],
#          [-0.4213, -0.4279, -0.4095, -0.3778],
#          [-0.4587, -0.4360, -0.4531, -0.3520]],
#
#         [[-0.4172, -0.4262, -0.4161, -0.5142],
#          [-0.4211, -0.4201, -0.4142, -0.5871],
#          [-0.4213, -0.4279, -0.4095, -0.3778],
#          [-0.4587, -0.4360, -0.4531, -0.3520],
#          [-0.4663, -0.4502, -0.4503, -0.5305]],
#
#         [[-0.4211, -0.4201, -0.4142, -0.5871],
#          [-0.4213, -0.4279, -0.4095, -0.3778],
#          [-0.4587, -0.4360, -0.4531, -0.3520],
#          [-0.4663, -0.4502, -0.4503, -0.5305],
#          [-0.4800, -0.4817, -0.4752, -0.5750]]])
# tensor([[[-0.4213, -0.4279, -0.4095, -0.3778],
#          [-0.4587, -0.4360, -0.4531, -0.3520],
#          [-0.4663, -0.4502, -0.4503, -0.5305],
#          [-0.4800, -0.4817, -0.4752, -0.5750],
#          [-0.5027, -0.4952, -0.4913, -0.6067]],
#
#         [[-0.4587, -0.4360, -0.4531, -0.3520],
#          [-0.4663, -0.4502, -0.4503, -0.5305],
#          [-0.4800, -0.4817, -0.4752, -0.5750],
#          [-0.5027, -0.4952, -0.4913, -0.6067],
#          [-0.5106, -0.5117, -0.5002, -0.5245]],
#
#         [[-0.4663, -0.4502, -0.4503, -0.5305],
#          [-0.4800, -0.4817, -0.4752, -0.5750],
#          [-0.5027, -0.4952, -0.4913, -0.6067],
#          [-0.5106, -0.5117, -0.5002, -0.5245],
#          [-0.5126, -0.5120, -0.5053, -0.6374]],
#
#         ...,
#
#         [[-0.4846, -0.4980, -0.4741, -0.4877],
#          [-0.4832, -0.4961, -0.4711, -0.5889],
#          [-0.4535, -0.4677, -0.4653,  0.2692],
#          [-0.3943, -0.4053, -0.4295, -0.0201],
#          [-0.3774, -0.3743, -0.3740, -0.0054]],
#
#         [[-0.4832, -0.4961, -0.4711, -0.5889],
#          [-0.4535, -0.4677, -0.4653,  0.2692],
#          [-0.3943, -0.4053, -0.4295, -0.0201],
#          [-0.3774, -0.3743, -0.3740, -0.0054],
#          [-0.3691, -0.3814, -0.3649, -0.4563]],
#
#         [[-0.4535, -0.4677, -0.4653,  0.2692],
#          [-0.3943, -0.4053, -0.4295, -0.0201],
#          [-0.3774, -0.3743, -0.3740, -0.0054],
#          [-0.3691, -0.3814, -0.3649, -0.4563],
#          [-0.3773, -0.3752, -0.3662, -0.5076]]])
# tensor([[[-0.3943, -0.4053, -0.4295, -0.0201],
#          [-0.3774, -0.3743, -0.3740, -0.0054],
#          [-0.3691, -0.3814, -0.3649, -0.4563],
#          [-0.3773, -0.3752, -0.3662, -0.5076],
#          [-0.3322, -0.3488, -0.3433, -0.2647]],
#
#         [[-0.3774, -0.3743, -0.3740, -0.0054],
#          [-0.3691, -0.3814, -0.3649, -0.4563],
#          [-0.3773, -0.3752, -0.3662, -0.5076],
#          [-0.3322, -0.3488, -0.3433, -0.2647],
#          [-0.3220, -0.3195, -0.3084, -0.3230]],
#
#         [[-0.3691, -0.3814, -0.3649, -0.4563],
#          [-0.3773, -0.3752, -0.3662, -0.5076],
#          [-0.3322, -0.3488, -0.3433, -0.2647],
#          [-0.3220, -0.3195, -0.3084, -0.3230],
#          [-0.3326, -0.3301, -0.3427, -0.1951]],
#
#         ...,
#
#         [[-0.1263, -0.1259, -0.1101, -0.5426],
#          [-0.1217, -0.1346, -0.1136, -0.6760],
#          [-0.1247, -0.1386, -0.1149, -0.3278],
#          [-0.1108, -0.1213, -0.1117, -0.5881],
#          [-0.0846, -0.0991, -0.0822, -0.6100]],
#
#         [[-0.1217, -0.1346, -0.1136, -0.6760],
#          [-0.1247, -0.1386, -0.1149, -0.3278],
#          [-0.1108, -0.1213, -0.1117, -0.5881],
#          [-0.0846, -0.0991, -0.0822, -0.6100],
#          [-0.0767, -0.0917, -0.0636, -0.7670]],
#
#         [[-0.1247, -0.1386, -0.1149, -0.3278],
#          [-0.1108, -0.1213, -0.1117, -0.5881],
#          [-0.0846, -0.0991, -0.0822, -0.6100],
#          [-0.0767, -0.0917, -0.0636, -0.7670],
#          [-0.0808, -0.0949, -0.0677, -0.7896]]])
# tensor([[[-0.1108, -0.1213, -0.1117, -0.5881],
#          [-0.0846, -0.0991, -0.0822, -0.6100],
#          [-0.0767, -0.0917, -0.0636, -0.7670],
#          [-0.0808, -0.0949, -0.0677, -0.7896],
#          [-0.0869, -0.1021, -0.0760, -0.7669]],
#
#         [[-0.0846, -0.0991, -0.0822, -0.6100],
#          [-0.0767, -0.0917, -0.0636, -0.7670],
#          [-0.0808, -0.0949, -0.0677, -0.7896],
#          [-0.0869, -0.1021, -0.0760, -0.7669],
#          [-0.0982, -0.1018, -0.0809, -0.8004]],
#
#         [[-0.0767, -0.0917, -0.0636, -0.7670],
#          [-0.0808, -0.0949, -0.0677, -0.7896],
#          [-0.0869, -0.1021, -0.0760, -0.7669],
#          [-0.0982, -0.1018, -0.0809, -0.8004],
#          [-0.0914, -0.1066, -0.0779, -0.8110]],
#
#         ...,
#
#         [[-0.2219, -0.2184, -0.2068, -0.2783],
#          [-0.1714, -0.1800, -0.1763, -0.3432],
#          [-0.1687, -0.1819, -0.1648, -0.6083],
#          [-0.1529, -0.1714, -0.1665, -0.6248],
#          [-0.1375, -0.1521, -0.1441, -0.5588]],
#
#         [[-0.1714, -0.1800, -0.1763, -0.3432],
#          [-0.1687, -0.1819, -0.1648, -0.6083],
#          [-0.1529, -0.1714, -0.1665, -0.6248],
#          [-0.1375, -0.1521, -0.1441, -0.5588],
#          [-0.1608, -0.1569, -0.1427, -0.3812]],
#
#         [[-0.1687, -0.1819, -0.1648, -0.6083],
#          [-0.1529, -0.1714, -0.1665, -0.6248],
#          [-0.1375, -0.1521, -0.1441, -0.5588],
#          [-0.1608, -0.1569, -0.1427, -0.3812],
#          [-0.1752, -0.1632, -0.1576, -0.5308]]])
# tensor([[[-0.1529, -0.1714, -0.1665, -0.6248],
#          [-0.1375, -0.1521, -0.1441, -0.5588],
#          [-0.1608, -0.1569, -0.1427, -0.3812],
#          [-0.1752, -0.1632, -0.1576, -0.5308],
#          [-0.1543, -0.1732, -0.1632, -0.6742]],
#
#         [[-0.1375, -0.1521, -0.1441, -0.5588],
#          [-0.1608, -0.1569, -0.1427, -0.3812],
#          [-0.1752, -0.1632, -0.1576, -0.5308],
#          [-0.1543, -0.1732, -0.1632, -0.6742],
#          [-0.1540, -0.1615, -0.1383, -0.7168]],
#
#         [[-0.1608, -0.1569, -0.1427, -0.3812],
#          [-0.1752, -0.1632, -0.1576, -0.5308],
#          [-0.1543, -0.1732, -0.1632, -0.6742],
#          [-0.1540, -0.1615, -0.1383, -0.7168],
#          [-0.1379, -0.1529, -0.1345, -0.5750]],
#
#         ...,
#
#         [[-0.4717, -0.4839, -0.4717, -0.3414],
#          [-0.4442, -0.4588, -0.4536, -0.4029],
#          [-0.4638, -0.4640, -0.4470, -0.4867],
#          [-0.4860, -0.4948, -0.4898,  0.0730],
#          [-0.5034, -0.5017, -0.4921, -0.1598]],
#
#         [[-0.4442, -0.4588, -0.4536, -0.4029],
#          [-0.4638, -0.4640, -0.4470, -0.4867],
#          [-0.4860, -0.4948, -0.4898,  0.0730],
#          [-0.5034, -0.5017, -0.4921, -0.1598],
#          [-0.4775, -0.4768, -0.4902, -0.2442]],
#
#         [[-0.4638, -0.4640, -0.4470, -0.4867],
#          [-0.4860, -0.4948, -0.4898,  0.0730],
#          [-0.5034, -0.5017, -0.4921, -0.1598],
#          [-0.4775, -0.4768, -0.4902, -0.2442],
#          [-0.4421, -0.4515, -0.4559, -0.4147]]])
# tensor([[[-0.4860, -0.4948, -0.4898,  0.0730],
#          [-0.5034, -0.5017, -0.4921, -0.1598],
#          [-0.4775, -0.4768, -0.4902, -0.2442],
#          [-0.4421, -0.4515, -0.4559, -0.4147],
#          [-0.4293, -0.4383, -0.4284, -0.5017]],
#
#         [[-0.5034, -0.5017, -0.4921, -0.1598],
#          [-0.4775, -0.4768, -0.4902, -0.2442],
#          [-0.4421, -0.4515, -0.4559, -0.4147],
#          [-0.4293, -0.4383, -0.4284, -0.5017],
#          [-0.4005, -0.4175, -0.3984, -0.4817]],
#
#         [[-0.4775, -0.4768, -0.4902, -0.2442],
#          [-0.4421, -0.4515, -0.4559, -0.4147],
#          [-0.4293, -0.4383, -0.4284, -0.5017],
#          [-0.4005, -0.4175, -0.3984, -0.4817],
#          [-0.3527, -0.3704, -0.3824, -0.1993]],
#
#         ...,
#
#         [[-0.2690, -0.2491, -0.2630, -0.3997],
#          [-0.2933, -0.2605, -0.2755, -0.4616],
#          [-0.3539, -0.3457, -0.3573, -0.0209],
#          [-0.3380, -0.3534, -0.3556, -0.4002],
#          [-0.3172, -0.3322, -0.3598, -0.4336]],
#
#         [[-0.2933, -0.2605, -0.2755, -0.4616],
#          [-0.3539, -0.3457, -0.3573, -0.0209],
#          [-0.3380, -0.3534, -0.3556, -0.4002],
#          [-0.3172, -0.3322, -0.3598, -0.4336],
#          [-0.2928, -0.2864, -0.2848, -0.3456]],
#
#         [[-0.3539, -0.3457, -0.3573, -0.0209],
#          [-0.3380, -0.3534, -0.3556, -0.4002],
#          [-0.3172, -0.3322, -0.3598, -0.4336],
#          [-0.2928, -0.2864, -0.2848, -0.3456],
#          [-0.3271, -0.2962, -0.3122, -0.5203]]])
# tensor([[[-0.3380, -0.3534, -0.3556, -0.4002],
#          [-0.3172, -0.3322, -0.3598, -0.4336],
#          [-0.2928, -0.2864, -0.2848, -0.3456],
#          [-0.3271, -0.2962, -0.3122, -0.5203],
#          [-0.3315, -0.3180, -0.3395, -0.3699]],
#
#         [[-0.3172, -0.3322, -0.3598, -0.4336],
#          [-0.2928, -0.2864, -0.2848, -0.3456],
#          [-0.3271, -0.2962, -0.3122, -0.5203],
#          [-0.3315, -0.3180, -0.3395, -0.3699],
#          [-0.3722, -0.3612, -0.3560, -0.4127]],
#
#         [[-0.2928, -0.2864, -0.2848, -0.3456],
#          [-0.3271, -0.2962, -0.3122, -0.5203],
#          [-0.3315, -0.3180, -0.3395, -0.3699],
#          [-0.3722, -0.3612, -0.3560, -0.4127],
#          [-0.4360, -0.4002, -0.4198, -0.0035]],
#
#         ...,
#
#         [[ 0.0046, -0.0110,  0.0177, -0.4911],
#          [-0.0103, -0.0111, -0.0120, -0.4655],
#          [ 0.0024, -0.0114,  0.0145, -0.6233],
#          [ 0.0136, -0.0018,  0.0261, -0.7095],
#          [ 0.0368,  0.0301,  0.0309, -0.6738]],
#
#         [[-0.0103, -0.0111, -0.0120, -0.4655],
#          [ 0.0024, -0.0114,  0.0145, -0.6233],
#          [ 0.0136, -0.0018,  0.0261, -0.7095],
#          [ 0.0368,  0.0301,  0.0309, -0.6738],
#          [ 0.0351,  0.0317,  0.0510, -0.5521]],
#
#         [[ 0.0024, -0.0114,  0.0145, -0.6233],
#          [ 0.0136, -0.0018,  0.0261, -0.7095],
#          [ 0.0368,  0.0301,  0.0309, -0.6738],
#          [ 0.0351,  0.0317,  0.0510, -0.5521],
#          [ 0.0439,  0.0252,  0.0414, -0.6811]]])
# tensor([[[ 0.0136, -0.0018,  0.0261, -0.7095],
#          [ 0.0368,  0.0301,  0.0309, -0.6738],
#          [ 0.0351,  0.0317,  0.0510, -0.5521],
#          [ 0.0439,  0.0252,  0.0414, -0.6811],
#          [ 0.0553,  0.0374,  0.0638, -0.6327]],
#
#         [[ 0.0368,  0.0301,  0.0309, -0.6738],
#          [ 0.0351,  0.0317,  0.0510, -0.5521],
#          [ 0.0439,  0.0252,  0.0414, -0.6811],
#          [ 0.0553,  0.0374,  0.0638, -0.6327],
#          [ 0.1190,  0.1069,  0.0979, -0.1900]],
#
#         [[ 0.0351,  0.0317,  0.0510, -0.5521],
#          [ 0.0439,  0.0252,  0.0414, -0.6811],
#          [ 0.0553,  0.0374,  0.0638, -0.6327],
#          [ 0.1190,  0.1069,  0.0979, -0.1900],
#          [ 0.1284,  0.1137,  0.1250, -0.3799]],
#
#         ...,
#
#         [[ 0.0445,  0.0431,  0.0602, -0.5958],
#          [ 0.0665,  0.0463,  0.0557, -0.6241],
#          [ 0.0590,  0.0593,  0.0730, -0.5801],
#          [ 0.0875,  0.0759,  0.0937, -0.4559],
#          [ 0.0635,  0.0694,  0.0713, -0.5995]],
#
#         [[ 0.0665,  0.0463,  0.0557, -0.6241],
#          [ 0.0590,  0.0593,  0.0730, -0.5801],
#          [ 0.0875,  0.0759,  0.0937, -0.4559],
#          [ 0.0635,  0.0694,  0.0713, -0.5995],
#          [ 0.0401,  0.0593,  0.0605, -0.5092]],
#
#         [[ 0.0590,  0.0593,  0.0730, -0.5801],
#          [ 0.0875,  0.0759,  0.0937, -0.4559],
#          [ 0.0635,  0.0694,  0.0713, -0.5995],
#          [ 0.0401,  0.0593,  0.0605, -0.5092],
#          [ 0.0586,  0.0398,  0.0402, -0.5154]]])
# tensor([[[ 0.0875,  0.0759,  0.0937, -0.4559],
#          [ 0.0635,  0.0694,  0.0713, -0.5995],
#          [ 0.0401,  0.0593,  0.0605, -0.5092],
#          [ 0.0586,  0.0398,  0.0402, -0.5154],
#          [ 0.0446,  0.0413,  0.0527, -0.5713]],
#
#         [[ 0.0635,  0.0694,  0.0713, -0.5995],
#          [ 0.0401,  0.0593,  0.0605, -0.5092],
#          [ 0.0586,  0.0398,  0.0402, -0.5154],
#          [ 0.0446,  0.0413,  0.0527, -0.5713],
#          [ 0.0202,  0.0122,  0.0279, -0.6689]],
#
#         [[ 0.0401,  0.0593,  0.0605, -0.5092],
#          [ 0.0586,  0.0398,  0.0402, -0.5154],
#          [ 0.0446,  0.0413,  0.0527, -0.5713],
#          [ 0.0202,  0.0122,  0.0279, -0.6689],
#          [ 0.0109,  0.0039,  0.0196, -0.5073]],
#
#         ...,
#
#         [[-0.2230, -0.2180, -0.2147, -0.6796],
#          [-0.2100, -0.2229, -0.2077, -0.7337],
#          [-0.1950, -0.1989, -0.1862, -0.6537],
#          [-0.2113, -0.2241, -0.2151, -0.6003],
#          [-0.1598, -0.1789, -0.1658, -0.4604]],
#
#         [[-0.2100, -0.2229, -0.2077, -0.7337],
#          [-0.1950, -0.1989, -0.1862, -0.6537],
#          [-0.2113, -0.2241, -0.2151, -0.6003],
#          [-0.1598, -0.1789, -0.1658, -0.4604],
#          [-0.1585, -0.1696, -0.1517, -0.6623]],
#
#         [[-0.1950, -0.1989, -0.1862, -0.6537],
#          [-0.2113, -0.2241, -0.2151, -0.6003],
#          [-0.1598, -0.1789, -0.1658, -0.4604],
#          [-0.1585, -0.1696, -0.1517, -0.6623],
#          [-0.1344, -0.1520, -0.1468, -0.7712]]])
# tensor([[[-0.2113, -0.2241, -0.2151, -0.6003],
#          [-0.1598, -0.1789, -0.1658, -0.4604],
#          [-0.1585, -0.1696, -0.1517, -0.6623],
#          [-0.1344, -0.1520, -0.1468, -0.7712],
#          [-0.1080, -0.1142, -0.1121, -0.5010]],
#
#         [[-0.1598, -0.1789, -0.1658, -0.4604],
#          [-0.1585, -0.1696, -0.1517, -0.6623],
#          [-0.1344, -0.1520, -0.1468, -0.7712],
#          [-0.1080, -0.1142, -0.1121, -0.5010],
#          [-0.1405, -0.1355, -0.1309, -0.5440]],
#
#         [[-0.1585, -0.1696, -0.1517, -0.6623],
#          [-0.1344, -0.1520, -0.1468, -0.7712],
#          [-0.1080, -0.1142, -0.1121, -0.5010],
#          [-0.1405, -0.1355, -0.1309, -0.5440],
#          [-0.1404, -0.1514, -0.1361, -0.6484]],
#
#         ...,
#
#         [[ 0.3927,  0.4210,  0.4114,  0.3667],
#          [ 0.4067,  0.4092,  0.3895,  0.2766],
#          [ 0.4166,  0.4144,  0.4245, -0.1305],
#          [ 0.4101,  0.4029,  0.4228, -0.3987],
#          [ 0.4339,  0.4214,  0.4395, -0.3088]],
#
#         [[ 0.4067,  0.4092,  0.3895,  0.2766],
#          [ 0.4166,  0.4144,  0.4245, -0.1305],
#          [ 0.4101,  0.4029,  0.4228, -0.3987],
#          [ 0.4339,  0.4214,  0.4395, -0.3088],
#          [ 0.4182,  0.4246,  0.4199, -0.3972]],
#
#         [[ 0.4166,  0.4144,  0.4245, -0.1305],
#          [ 0.4101,  0.4029,  0.4228, -0.3987],
#          [ 0.4339,  0.4214,  0.4395, -0.3088],
#          [ 0.4182,  0.4246,  0.4199, -0.3972],
#          [ 0.4362,  0.4179,  0.4263, -0.5331]]])
# tensor([[[ 0.4101,  0.4029,  0.4228, -0.3987],
#          [ 0.4339,  0.4214,  0.4395, -0.3088],
#          [ 0.4182,  0.4246,  0.4199, -0.3972],
#          [ 0.4362,  0.4179,  0.4263, -0.5331],
#          [ 0.4544,  0.4373,  0.4500, -0.4757]],
#
#         [[ 0.4339,  0.4214,  0.4395, -0.3088],
#          [ 0.4182,  0.4246,  0.4199, -0.3972],
#          [ 0.4362,  0.4179,  0.4263, -0.5331],
#          [ 0.4544,  0.4373,  0.4500, -0.4757],
#          [ 0.4531,  0.4519,  0.4684, -0.4098]],
#
#         [[ 0.4182,  0.4246,  0.4199, -0.3972],
#          [ 0.4362,  0.4179,  0.4263, -0.5331],
#          [ 0.4544,  0.4373,  0.4500, -0.4757],
#          [ 0.4531,  0.4519,  0.4684, -0.4098],
#          [ 0.4210,  0.4168,  0.4327, -0.5915]],
#
#         ...,
#
#         [[ 0.2321,  0.2328,  0.2546, -0.7216],
#          [ 0.2562,  0.2446,  0.2414, -0.5824],
#          [ 0.3080,  0.2980,  0.3090, -0.4553],
#          [ 0.3094,  0.3140,  0.3227, -0.5075],
#          [ 0.3561,  0.3450,  0.3456, -0.4034]],
#
#         [[ 0.2562,  0.2446,  0.2414, -0.5824],
#          [ 0.3080,  0.2980,  0.3090, -0.4553],
#          [ 0.3094,  0.3140,  0.3227, -0.5075],
#          [ 0.3561,  0.3450,  0.3456, -0.4034],
#          [ 0.3456,  0.3382,  0.3552, -0.6623]],
#
#         [[ 0.3080,  0.2980,  0.3090, -0.4553],
#          [ 0.3094,  0.3140,  0.3227, -0.5075],
#          [ 0.3561,  0.3450,  0.3456, -0.4034],
#          [ 0.3456,  0.3382,  0.3552, -0.6623],
#          [ 0.3408,  0.3282,  0.3349, -0.6575]]])
# tensor([[[ 0.3094,  0.3140,  0.3227, -0.5075],
#          [ 0.3561,  0.3450,  0.3456, -0.4034],
#          [ 0.3456,  0.3382,  0.3552, -0.6623],
#          [ 0.3408,  0.3282,  0.3349, -0.6575],
#          [ 0.3566,  0.3349,  0.3487, -0.5760]],
#
#         [[ 0.3561,  0.3450,  0.3456, -0.4034],
#          [ 0.3456,  0.3382,  0.3552, -0.6623],
#          [ 0.3408,  0.3282,  0.3349, -0.6575],
#          [ 0.3566,  0.3349,  0.3487, -0.5760],
#          [ 0.3676,  0.3565,  0.3648, -0.6202]],
#
#         [[ 0.3456,  0.3382,  0.3552, -0.6623],
#          [ 0.3408,  0.3282,  0.3349, -0.6575],
# ...
#          [ 3.2356,  3.2174,  3.2537, -0.9008],
#          [ 3.2234,  3.2119,  3.2582, -0.9122]],
#
#         [[ 3.1528,  3.1164,  3.1361, -0.8938],
#          [ 3.2323,  3.2039,  3.1835, -0.8583],
#          [ 3.2356,  3.2174,  3.2537, -0.9008],
#          [ 3.2234,  3.2119,  3.2582, -0.9122],
#          [ 3.2439,  3.2055,  3.2440, -0.9251]],
#
#         ...,
#
#         [[ 3.3859,  3.3587,  3.4159, -0.8860],
#          [ 3.4448,  3.4187,  3.4279, -0.8546],
#          [ 3.4187,  3.3817,  3.4267, -0.9275],
#          [ 3.3980,  3.4291,  3.4379, -0.8682],
#          [ 3.3748,  3.3896,  3.4097, -0.9032]],
#
#         [[ 3.4448,  3.4187,  3.4279, -0.8546],
#          [ 3.4187,  3.3817,  3.4267, -0.9275],
#          [ 3.3980,  3.4291,  3.4379, -0.8682],
#          [ 3.3748,  3.3896,  3.4097, -0.9032],
#          [ 3.3538,  3.3381,  3.3704, -0.9261]],
#
#         [[ 3.4187,  3.3817,  3.4267, -0.9275],
#          [ 3.3980,  3.4291,  3.4379, -0.8682],
#          [ 3.3748,  3.3896,  3.4097, -0.9032],
#          [ 3.3538,  3.3381,  3.3704, -0.9261],
#          [ 3.3542,  3.3437,  3.3920, -0.9353]]])
# tensor([[[ 3.3980,  3.4291,  3.4379, -0.8682],
#          [ 3.3748,  3.3896,  3.4097, -0.9032],
#          [ 3.3538,  3.3381,  3.3704, -0.9261],
#          [ 3.3542,  3.3437,  3.3920, -0.9353],
#          [ 3.3451,  3.3312,  3.3474, -0.9235]],
#
#         [[ 3.3748,  3.3896,  3.4097, -0.9032],
#          [ 3.3538,  3.3381,  3.3704, -0.9261],
#          [ 3.3542,  3.3437,  3.3920, -0.9353],
#          [ 3.3451,  3.3312,  3.3474, -0.9235],
#          [ 3.3515,  3.3262,  3.3738, -0.9444]],
#
#         [[ 3.3538,  3.3381,  3.3704, -0.9261],
#          [ 3.3542,  3.3437,  3.3920, -0.9353],
#          [ 3.3451,  3.3312,  3.3474, -0.9235],
#          [ 3.3515,  3.3262,  3.3738, -0.9444],
#          [ 3.3465,  3.3244,  3.3766, -0.9186]],
#
#         ...,
#
#         [[ 3.8393,  3.8952,  3.8610, -0.8502],
#          [ 3.9246,  3.8989,  3.8855, -0.8381],
#          [ 3.8917,  3.9017,  3.8934, -0.8834],
#          [ 3.9698,  3.9447,  3.9538, -0.8586],
#          [ 4.0367,  4.0024,  4.0247, -0.9104]],
#
#         [[ 3.9246,  3.8989,  3.8855, -0.8381],
#          [ 3.8917,  3.9017,  3.8934, -0.8834],
#          [ 3.9698,  3.9447,  3.9538, -0.8586],
#          [ 4.0367,  4.0024,  4.0247, -0.9104],
#          [ 4.0452,  4.0092,  4.0407, -0.9196]],
#
#         [[ 3.8917,  3.9017,  3.8934, -0.8834],
#          [ 3.9698,  3.9447,  3.9538, -0.8586],
#          [ 4.0367,  4.0024,  4.0247, -0.9104],
#          [ 4.0452,  4.0092,  4.0407, -0.9196],
#          [ 4.1353,  4.1061,  4.1230, -0.8709]]])
# tensor([[[ 3.9698,  3.9447,  3.9538, -0.8586],
#          [ 4.0367,  4.0024,  4.0247, -0.9104],
#          [ 4.0452,  4.0092,  4.0407, -0.9196],
#          [ 4.1353,  4.1061,  4.1230, -0.8709],
#          [ 4.1572,  4.1593,  4.1794, -0.8985]],
#
#         [[ 4.0367,  4.0024,  4.0247, -0.9104],
#          [ 4.0452,  4.0092,  4.0407, -0.9196],
#          [ 4.1353,  4.1061,  4.1230, -0.8709],
#          [ 4.1572,  4.1593,  4.1794, -0.8985],
#          [ 4.2151,  4.1753,  4.2124, -0.9265]],
#
#         [[ 4.0452,  4.0092,  4.0407, -0.9196],
#          [ 4.1353,  4.1061,  4.1230, -0.8709],
#          [ 4.1572,  4.1593,  4.1794, -0.8985],
#          [ 4.2151,  4.1753,  4.2124, -0.9265],
#          [ 4.1982,  4.2003,  4.2206, -0.9135]],
#
#         ...,
#
#         [[ 4.2269,  4.1824,  4.2199, -0.9458],
#          [ 4.1868,  4.1980,  4.2301, -0.9384],
#          [ 4.3067,  4.2666,  4.2598, -0.9079],
#          [ 4.3653,  4.3223,  4.3138, -0.9126],
#          [ 4.3529,  4.3612,  4.3980, -0.9455]],
#
#         [[ 4.1868,  4.1980,  4.2301, -0.9384],
#          [ 4.3067,  4.2666,  4.2598, -0.9079],
#          [ 4.3653,  4.3223,  4.3138, -0.9126],
#          [ 4.3529,  4.3612,  4.3980, -0.9455],
#          [ 4.3240,  4.3361,  4.3318, -0.9365]],
#
#         [[ 4.3067,  4.2666,  4.2598, -0.9079],
#          [ 4.3653,  4.3223,  4.3138, -0.9126],
#          [ 4.3529,  4.3612,  4.3980, -0.9455],
#          [ 4.3240,  4.3361,  4.3318, -0.9365],
#          [ 4.4332,  4.3956,  4.3725, -0.8521]]])
# tensor([[[ 4.3653,  4.3223,  4.3138, -0.9126],
#          [ 4.3529,  4.3612,  4.3980, -0.9455],
#          [ 4.3240,  4.3361,  4.3318, -0.9365],
#          [ 4.4332,  4.3956,  4.3725, -0.8521],
#          [ 4.4239,  4.4179,  4.4567, -0.9023]],
#
#         [[ 4.3529,  4.3612,  4.3980, -0.9455],
#          [ 4.3240,  4.3361,  4.3318, -0.9365],
#          [ 4.4332,  4.3956,  4.3725, -0.8521],
#          [ 4.4239,  4.4179,  4.4567, -0.9023],
#          [ 4.4360,  4.4380,  4.4831, -0.9130]],
#
#         [[ 4.3240,  4.3361,  4.3318, -0.9365],
#          [ 4.4332,  4.3956,  4.3725, -0.8521],
#          [ 4.4239,  4.4179,  4.4567, -0.9023],
#          [ 4.4360,  4.4380,  4.4831, -0.9130],
#          [ 4.4512,  4.4165,  4.4501, -0.9432]],
#
#         ...,
#
#         [[ 4.9297,  4.9346,  4.9620, -0.9015],
#          [ 4.9210,  4.9082,  4.9638, -0.9333],
#          [ 4.8980,  4.8747,  4.9483, -0.9613],
#          [ 4.8758,  4.8481,  4.8873, -0.9607],
#          [ 4.8275,  4.8367,  4.8731, -0.9012]],
#
#         [[ 4.9210,  4.9082,  4.9638, -0.9333],
#          [ 4.8980,  4.8747,  4.9483, -0.9613],
#          [ 4.8758,  4.8481,  4.8873, -0.9607],
#          [ 4.8275,  4.8367,  4.8731, -0.9012],
#          [ 4.8194,  4.8131,  4.8514, -0.9518]],
#
#         [[ 4.8980,  4.8747,  4.9483, -0.9613],
#          [ 4.8758,  4.8481,  4.8873, -0.9607],
#          [ 4.8275,  4.8367,  4.8731, -0.9012],
#          [ 4.8194,  4.8131,  4.8514, -0.9518],
#          [ 4.8080,  4.7802,  4.8523, -0.9459]]])
# tensor([[[ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051]],
#
#         [[ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 5.0447,  5.0187,  4.9732, -0.8827]],
#
#         [[ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 4.9300,  4.8926,  4.8545, -0.9051],
#          [ 5.0447,  5.0187,  4.9732, -0.8827],
#          [ 5.0704,  5.0662,  5.1105, -0.9323]],
#
#         ...,
#
#         [[ 4.8527,  4.8189,  4.6112, -0.7390],
#          [ 4.5372,  4.8789,  4.5354, -0.6889],
#          [ 4.5336,  4.6142,  4.4279, -0.6570],
#          [ 4.7122,  4.7365,  4.5749, -0.7318],
#          [ 4.5461,  4.6831,  4.4922, -0.7372]],
#
#         [[ 4.5372,  4.8789,  4.5354, -0.6889],
#          [ 4.5336,  4.6142,  4.4279, -0.6570],
#          [ 4.7122,  4.7365,  4.5749, -0.7318],
#          [ 4.5461,  4.6831,  4.4922, -0.7372],
#          [ 4.5917,  4.5930,  4.5166, -0.7844]],
#
#         [[ 4.5336,  4.6142,  4.4279, -0.6570],
#          [ 4.7122,  4.7365,  4.5749, -0.7318],
#          [ 4.5461,  4.6831,  4.4922, -0.7372],
#          [ 4.5917,  4.5930,  4.5166, -0.7844],
#          [ 4.6686,  4.6434,  4.5095, -0.7600]]])
# tensor([[[ 4.7122,  4.7365,  4.5749, -0.7318],
#          [ 4.5461,  4.6831,  4.4922, -0.7372],
#          [ 4.5917,  4.5930,  4.5166, -0.7844],
#          [ 4.6686,  4.6434,  4.5095, -0.7600],
#          [ 4.6861,  4.7352,  4.6887, -0.8906]],
#
#         [[ 4.5461,  4.6831,  4.4922, -0.7372],
#          [ 4.5917,  4.5930,  4.5166, -0.7844],
#          [ 4.6686,  4.6434,  4.5095, -0.7600],
#          [ 4.6861,  4.7352,  4.6887, -0.8906],
#          [ 4.5499,  4.6610,  4.5758, -0.8459]],
#
#         [[ 4.5917,  4.5930,  4.5166, -0.7844],
#          [ 4.6686,  4.6434,  4.5095, -0.7600],
#          [ 4.6861,  4.7352,  4.6887, -0.8906],
#          [ 4.5499,  4.6610,  4.5758, -0.8459],
#          [ 4.6050,  4.7144,  4.6487, -0.8453]],
#
#         ...,
#
#         [[ 5.2806,  5.3246,  5.3262, -0.8672],
#          [ 5.1857,  5.3156,  5.2401, -0.8986],
#          [ 5.2528,  5.2535,  5.1898, -0.9244],
#          [ 5.2622,  5.2921,  5.3152, -0.8961],
#          [ 5.3397,  5.2906,  5.1752, -0.9075]],
#
#         [[ 5.1857,  5.3156,  5.2401, -0.8986],
#          [ 5.2528,  5.2535,  5.1898, -0.9244],
#          [ 5.2622,  5.2921,  5.3152, -0.8961],
#          [ 5.3397,  5.2906,  5.1752, -0.9075],
#          [ 5.1785,  5.3416,  5.2163, -0.9702]],
#
#         [[ 5.2528,  5.2535,  5.1898, -0.9244],
#          [ 5.2622,  5.2921,  5.3152, -0.8961],
#          [ 5.3397,  5.2906,  5.1752, -0.9075],
#          [ 5.1785,  5.3416,  5.2163, -0.9702],
#          [ 5.3187,  5.2874,  5.2722, -0.9250]]])
# tensor([[[ 5.2622,  5.2921,  5.3152, -0.8961],
#          [ 5.3397,  5.2906,  5.1752, -0.9075],
#          [ 5.1785,  5.3416,  5.2163, -0.9702],
#          [ 5.3187,  5.2874,  5.2722, -0.9250],
#          [ 5.4230,  5.3749,  5.3531, -0.9333]],
#
#         [[ 5.3397,  5.2906,  5.1752, -0.9075],
#          [ 5.1785,  5.3416,  5.2163, -0.9702],
#          [ 5.3187,  5.2874,  5.2722, -0.9250],
#          [ 5.4230,  5.3749,  5.3531, -0.9333],
#          [ 5.5141,  5.4645,  5.5029, -0.9434]],
#
#         [[ 5.1785,  5.3416,  5.2163, -0.9702],
#          [ 5.3187,  5.2874,  5.2722, -0.9250],
#          [ 5.4230,  5.3749,  5.3531, -0.9333],
#          [ 5.5141,  5.4645,  5.5029, -0.9434],
#          [ 5.5061,  5.4966,  5.5436, -0.9563]],
#
#         ...,
#
#         [[ 5.6875,  5.7224,  5.7099, -0.8790],
#          [ 5.7803,  5.7737,  5.7684, -0.9024],
#          [ 5.7726,  5.7301,  5.7742, -0.8885],
#          [ 5.7847,  5.8245,  5.8125, -0.8912],
#          [ 5.8161,  5.8249,  5.7883, -0.8527]],
#
#         [[ 5.7803,  5.7737,  5.7684, -0.9024],
#          [ 5.7726,  5.7301,  5.7742, -0.8885],
#          [ 5.7847,  5.8245,  5.8125, -0.8912],
#          [ 5.8161,  5.8249,  5.7883, -0.8527],
#          [ 5.8348,  5.8018,  5.8358, -0.9030]],
#
#         [[ 5.7726,  5.7301,  5.7742, -0.8885],
#          [ 5.7847,  5.8245,  5.8125, -0.8912],
#          [ 5.8161,  5.8249,  5.7883, -0.8527],
#          [ 5.8348,  5.8018,  5.8358, -0.9030],
#          [ 5.6068,  5.7438,  5.5832, -0.7920]]])
# tensor([[[ 5.7847,  5.8245,  5.8125, -0.8912],
#          [ 5.8161,  5.8249,  5.7883, -0.8527],
#          [ 5.8348,  5.8018,  5.8358, -0.9030],
#          [ 5.6068,  5.7438,  5.5832, -0.7920],
#          [ 5.5357,  5.5873,  5.5141, -0.9114]],
#
#         [[ 5.8161,  5.8249,  5.7883, -0.8527],
#          [ 5.8348,  5.8018,  5.8358, -0.9030],
#          [ 5.6068,  5.7438,  5.5832, -0.7920],
#          [ 5.5357,  5.5873,  5.5141, -0.9114],
#          [ 5.4807,  5.5514,  5.3969, -0.8243]],
#
#         [[ 5.8348,  5.8018,  5.8358, -0.9030],
#          [ 5.6068,  5.7438,  5.5832, -0.7920],
#          [ 5.5357,  5.5873,  5.5141, -0.9114],
#          [ 5.4807,  5.5514,  5.3969, -0.8243],
#          [ 5.4142,  5.4624,  5.4643, -0.8969]],
#
#         ...,
#
#         [[ 4.7469,  4.8184,  4.7744, -0.8845],
#          [ 4.7373,  4.7998,  4.7116, -0.8754],
#          [ 4.8044,  4.7973,  4.6595, -0.8708],
#          [ 4.6090,  4.8277,  4.6487, -0.8349],
#          [ 4.9675,  4.9180,  4.7368, -0.8055]],
#
#         [[ 4.7373,  4.7998,  4.7116, -0.8754],
#          [ 4.8044,  4.7973,  4.6595, -0.8708],
#          [ 4.6090,  4.8277,  4.6487, -0.8349],
#          [ 4.9675,  4.9180,  4.7368, -0.8055],
#          [ 4.9522,  4.9386,  4.9174, -0.8185]],
#
#         [[ 4.8044,  4.7973,  4.6595, -0.8708],
#          [ 4.6090,  4.8277,  4.6487, -0.8349],
#          [ 4.9675,  4.9180,  4.7368, -0.8055],
#          [ 4.9522,  4.9386,  4.9174, -0.8185],
#          [ 5.0040,  5.0075,  4.9555, -0.8438]]])
# tensor([[[ 4.6090,  4.8277,  4.6487, -0.8349],
#          [ 4.9675,  4.9180,  4.7368, -0.8055],
#          [ 4.9522,  4.9386,  4.9174, -0.8185],
#          [ 5.0040,  5.0075,  4.9555, -0.8438],
#          [ 4.9934,  4.9949,  4.9943, -0.9096]],
#
#         [[ 4.9675,  4.9180,  4.7368, -0.8055],
#          [ 4.9522,  4.9386,  4.9174, -0.8185],
#          [ 5.0040,  5.0075,  4.9555, -0.8438],
#          [ 4.9934,  4.9949,  4.9943, -0.9096],
#          [ 4.9650,  4.9200,  4.9369, -0.8797]],
#
#         [[ 4.9522,  4.9386,  4.9174, -0.8185],
#          [ 5.0040,  5.0075,  4.9555, -0.8438],
#          [ 4.9934,  4.9949,  4.9943, -0.9096],
#          [ 4.9650,  4.9200,  4.9369, -0.8797],
#          [ 4.8788,  4.8720,  4.8759, -0.8722]],
#
#         ...,
#
#         [[ 5.8186,  5.7688,  5.7822, -0.9528],
#          [ 5.8543,  5.8663,  5.8799, -0.9311],
#          [ 5.9138,  5.8622,  5.9038, -0.9386],
#          [ 5.8623,  5.8657,  5.9098, -0.9436],
#          [ 5.8406,  5.8167,  5.8756, -0.9491]],
#
#         [[ 5.8543,  5.8663,  5.8799, -0.9311],
#          [ 5.9138,  5.8622,  5.9038, -0.9386],
#          [ 5.8623,  5.8657,  5.9098, -0.9436],
#          [ 5.8406,  5.8167,  5.8756, -0.9491],
#          [ 5.7974,  5.7749,  5.8308, -0.9472]],
#
#         [[ 5.9138,  5.8622,  5.9038, -0.9386],
#          [ 5.8623,  5.8657,  5.9098, -0.9436],
#          [ 5.8406,  5.8167,  5.8756, -0.9491],
#          [ 5.7974,  5.7749,  5.8308, -0.9472],
#          [ 5.8296,  5.7847,  5.8530, -0.9649]]])
# tensor([[[ 5.8623,  5.8657,  5.9098, -0.9436],
#          [ 5.8406,  5.8167,  5.8756, -0.9491],
#          [ 5.7974,  5.7749,  5.8308, -0.9472],
#          [ 5.8296,  5.7847,  5.8530, -0.9649],
#          [ 5.8457,  5.8119,  5.8774, -0.9665]],
#
#         [[ 5.8406,  5.8167,  5.8756, -0.9491],
#          [ 5.7974,  5.7749,  5.8308, -0.9472],
#          [ 5.8296,  5.7847,  5.8530, -0.9649],
#          [ 5.8457,  5.8119,  5.8774, -0.9665],
#          [ 5.9326,  5.8796,  5.9301, -0.9406]],
#
#         [[ 5.7974,  5.7749,  5.8308, -0.9472],
#          [ 5.8296,  5.7847,  5.8530, -0.9649],
#          [ 5.8457,  5.8119,  5.8774, -0.9665],
#          [ 5.9326,  5.8796,  5.9301, -0.9406],
#          [ 5.9538,  5.9178,  5.9367, -0.9110]],
#
#         ...,
#
#         [[ 5.3011,  5.2826,  5.3077, -0.9599],
#          [ 5.3668,  5.3225,  5.3227, -0.9020],
#          [ 5.2668,  5.2775,  5.2902, -0.9053],
#          [ 5.3224,  5.2908,  5.2635, -0.8943],
#          [ 5.4251,  5.3822,  5.4207, -0.9084]],
#
#         [[ 5.3668,  5.3225,  5.3227, -0.9020],
#          [ 5.2668,  5.2775,  5.2902, -0.9053],
#          [ 5.3224,  5.2908,  5.2635, -0.8943],
#          [ 5.4251,  5.3822,  5.4207, -0.9084],
#          [ 5.4495,  5.4541,  5.4775, -0.9101]],
#
#         [[ 5.2668,  5.2775,  5.2902, -0.9053],
#          [ 5.3224,  5.2908,  5.2635, -0.8943],
#          [ 5.4251,  5.3822,  5.4207, -0.9084],
#          [ 5.4495,  5.4541,  5.4775, -0.9101],
#          [ 5.4540,  5.4167,  5.4723, -0.9486]]])
# tensor([[[ 5.3224,  5.2908,  5.2635, -0.8943],
#          [ 5.4251,  5.3822,  5.4207, -0.9084],
#          [ 5.4495,  5.4541,  5.4775, -0.9101],
#          [ 5.4540,  5.4167,  5.4723, -0.9486],
#          [ 5.4897,  5.4394,  5.4764, -0.9440]],
#
#         [[ 5.4251,  5.3822,  5.4207, -0.9084],
#          [ 5.4495,  5.4541,  5.4775, -0.9101],
#          [ 5.4540,  5.4167,  5.4723, -0.9486],
#          [ 5.4897,  5.4394,  5.4764, -0.9440],
#          [ 5.5110,  5.4900,  5.5133, -0.9050]],
#
#         [[ 5.4495,  5.4541,  5.4775, -0.9101],
#          [ 5.4540,  5.4167,  5.4723, -0.9486],
#          [ 5.4897,  5.4394,  5.4764, -0.9440],
#          [ 5.5110,  5.4900,  5.5133, -0.9050],
#          [ 5.4636,  5.4886,  5.5184, -0.9130]],
#
#         ...,
#
#         [[ 6.1205,  6.0749,  5.9432, -0.8801],
#          [ 6.0869,  6.0534,  6.0896, -0.8702],
#          [ 5.9800,  6.0470,  5.9720, -0.8916],
#          [ 5.9400,  5.9295,  5.9578, -0.8858],
#          [ 5.8489,  5.9636,  5.9002, -0.9010]],
#
#         [[ 6.0869,  6.0534,  6.0896, -0.8702],
#          [ 5.9800,  6.0470,  5.9720, -0.8916],
#          [ 5.9400,  5.9295,  5.9578, -0.8858],
#          [ 5.8489,  5.9636,  5.9002, -0.9010],
#          [ 5.6621,  5.7403,  5.6870, -0.8612]],
#
#         [[ 5.9800,  6.0470,  5.9720, -0.8916],
#          [ 5.9400,  5.9295,  5.9578, -0.8858],
#          [ 5.8489,  5.9636,  5.9002, -0.9010],
#          [ 5.6621,  5.7403,  5.6870, -0.8612],
#          [ 5.7356,  5.6887,  5.6284, -0.8605]]])
#              Open_lead1  Model forecast
# Date
# 2004-08-19   -16.254554       -8.941772
# 2004-08-20    -8.747396       -8.248352
# 2004-08-23    -8.369729       -4.497711
# 2004-08-24   -13.210070       -8.049377
# 2004-08-25   -13.217779       -9.216003
# ...                 ...             ...
# 2019-09-27  1795.084505     1582.247803
# 2019-09-30  1792.036391     1578.117310
# 2019-10-01  1757.965063     1573.234131
# 2019-10-02  1731.692131     1553.687744
# 2019-10-03  1750.089417     1553.255737
#
# [3808 rows x 2 columns]

# %% [markdown]
# ### metrices

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error
def MASE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y) / torch.mean(torch.abs(y[1:] - y[:-1]))))

def SMAPE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(200 * torch.mean(torch.abs(pred - y) / (torch.abs(y) + torch.abs(pred))))

def MAE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y)))

def sharp_ratio(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean((pred - y) / torch.std(y)))

print( 'MASE =', MASE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )
print( 'SMAPE =', SMAPE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'MAE =', MAE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'sharp_ratio =', sharp_ratio(df_test['Open_lead1'], df_test['Model forecast']))
# Out:
# MASE = 16.66442901492821
# RMSE = 156.14792146826946
# SMAPE = 9.212825870314035
# MAE = 147.746862355438
# sharp_ratio = 2.7669824805886587

# %% [markdown]
# ### prediction

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d6c4b25e-43b5-4462-a975-0de21636b158" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6c4b25e-43b5-4462-a975-0de21636b158")) {                    Plotly.newPlot(                        "d6c4b25e-43b5-4462-a975-0de21636b158",                        [{"hovertemplate":"variable=Open_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open_lead1","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08- ...

# %% [markdown]
# # Trading Algo

# %%
df_test['Model forecast']
# Out:
# Date
# 2018-01-02    1449.869263
# 2018-01-03    1466.085693
# 2018-01-04    1473.681152
# 2018-01-05    1484.616577
# 2018-01-08    1490.589722
#                  ...
# 2019-09-27    1582.247803
# 2019-09-30    1578.117310
# 2019-10-01    1573.234131
# 2019-10-02    1553.687744
# 2019-10-03    1553.255737
# Name: Model forecast, Length: 442, dtype: float32

# %%
def buy_sell_stock(prices,real):
    buy_days = []
    sell_days = []
    current_bought= None
    returns = []
    real_current_bought= None
    real_returns = []
    holding = False  # Flag to indicate if we're holding a stock

    for i in range(1, len(prices)-1):
        if  holding and prices[i] > prices[i - 1] and prices[i] > prices[i + 1]:
            holding = False
            sell_days.append(prices.index[i])
            # Calculating rate of return
            returns.append(((prices[i] - current_bought) / current_bought)+1)
            real_returns.append(((real[i] - real_current_bought) / real_current_bought)+1)

        elif not holding and prices[i] < prices[i - 1] and prices[i] < prices[i + 1]:
            buy_days.append(prices.index[i])
            holding = True
            current_bought = prices[i]
            real_current_bought = real[i]

    returns = np.array(returns)
    expected_return = (np.prod(returns)-1)*100
    max_expected_return = (returns.max()-1)*100

    real_returns = np.array(real_returns)
    real_return = (np.prod(real_returns)-1)*100
    max_real_return =(real_returns.max()-1)*100
    return buy_days, sell_days, expected_return,real_return,max_expected_return,max_real_return,returns,real_returns

def plot_stock_prices(prices,real, buy_days, sell_days):
    plt.figure(figsize=(30, 10))
    plt.plot(prices.index, prices.values, label='Pred Stock Prices')
    plt.plot(real.index, real.values, label='Real Stock Prices')
    plt.scatter(buy_days, prices.loc[buy_days], color='green', marker='^', label='Buy')
    plt.scatter(sell_days, prices.loc[sell_days], color='red', marker='v', label='Sell')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('Stock Prices with Buy/Sell Signals')
    plt.legend()
    # plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()

# %%
buy_days, sell_days, expected_return, real_return,max_expected_return,max_real_return,returns,real_returns =  buy_sell_stock(df_test['Model forecast'],df_test['Open_lead1'])
print("expected_return =",expected_return,"%")
print("real_return =",real_return,"%")
print("max_expected_return =",max_expected_return,"%")
print("max_real_return =",max_real_return,"%")
# print(returns)
# print(real_returns)
# Out:
# expected_return = 273.740284736334 %
# real_return = 423.11403251374236 %
# max_expected_return = 4.890824109315872 %
# max_real_return = 9.35209125465748 %

# %%
plot_stock_prices(df_test['Model forecast'],df_test['Open_lead1'], buy_days, sell_days)
