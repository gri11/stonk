# %% [markdown]
# # How to use PyTorch LSTMs/GRUs for time series regression
# We aim to forcast stock price value by using LSTM with Pytorch.
#
# credit: https://github.com/CrosstabKite/lstm-forecasting/blob/master/lstm_forecasting.ipynb
#
# modified on (12/02/2023)

# %% [markdown]
# # Data

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# !wget https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Out:
# --2024-04-17 14:08:28--  https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv [following]
# --2024-04-17 14:08:28--  https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 284248 (278K) [text/plain]
# Saving to: ‘GOOG.csv’
#
# GOOG.csv            100%[===================>] 277.59K  --.-KB/s    in 0.004s
#
# 2024-04-17 14:08:29 (60.8 MB/s) - ‘GOOG.csv’ saved [284248/284248]

# %%
import pandas as pd

df = pd.read_csv('GOOG.csv', index_col="Date")
df = df.drop(['Adj Close'], axis = 1)
df
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
# 2019-10-04  1191.890015  1211.439941  1189.170044  1209.000000   1021092
#
# [3809 rows x 5 columns]

# %%
df.loc['2019-02-26']
# Out:
# Open      1.105750e+03
# High      1.119510e+03
# Low       1.099920e+03
# Close     1.115130e+03
# Volume    1.471300e+06
# Name: 2019-02-26, dtype: float64

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig = px.line(df['Open'], labels=dict(
    created_at="Date", value="Open", variable="Sensor"
))
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5ab84101-c3f1-44eb-8c0b-d344ae7061bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ab84101-c3f1-44eb-8c0b-d344ae7061bb")) {                    Plotly.newPlot(                        "5ab84101-c3f1-44eb-8c0b-d344ae7061bb",                        [{"hovertemplate":"Sensor=Open\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08-04","2005-08-05","20 ...

# %% [markdown]
# ## Create the target variable

# %%
target_col = "Open"
features = list(df.columns.difference([target_col]))

forecast_lead = 1
target = f"{target_col}_lead{forecast_lead}"

df[target] = df[target_col].shift(-forecast_lead)
df = df.iloc[:-forecast_lead]

# %%
features
# Out:
# ['Close', 'High', 'Low', 'Volume']

# %%
df
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-27  1243.010010  1244.020020  1214.449951  1225.089966   1353900
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
#
#              Open_lead1
# Date
# 2004-08-19    50.316402
# 2004-08-20    55.168217
# 2004-08-23    55.412300
# 2004-08-24    52.284027
# 2004-08-25    52.279045
# ...                 ...
# 2019-09-27  1220.969971
# 2019-09-30  1219.000000
# 2019-10-01  1196.979980
# 2019-10-02  1180.000000
# 2019-10-03  1191.890015
#
# [3808 rows x 6 columns]

# %% [markdown]
# ## Create a hold-out test set and preprocess the data

# %%
test_start = "2019-01-01"
val_start = "2018-01-01"

df_train = df.loc[:val_start].copy()
df_val = df.loc[val_start:test_start].copy()
df_test = df.loc[test_start:].copy()

print("Test set fraction:", len(df_test) / len(df))
# Out:
# Test set fraction: 0.050157563025210086

# %% [markdown]
# ## Standardize the features and target, based on the training set

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_val[c] = (df_val[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %% [markdown]
# ## Create datasets that PyTorch `DataLoader` can work with

# %%
import torch
from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i):
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %%
i = 27
sequence_length = 4

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)

X, y = train_dataset[i]
print(X)
# Out:
# tensor([[-1.4005, -1.4044, -1.4018,  0.0794],
#         [-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892]])

# %%
X, y = train_dataset[i + 1]
print(X)
# Out:
# tensor([[-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892],
#         [-1.3789, -1.3784, -1.3822,  2.7240]])

# %%
print(df_train[features].iloc[(i - sequence_length + 1): (i + 1)])
# Out:
#                Close      High       Low    Volume
# Date
# 2004-09-23 -1.400509 -1.404409 -1.401750  0.079391
# 2004-09-24 -1.402597 -1.401323 -1.395935  0.150113
# 2004-09-27 -1.405909 -1.408082 -1.400095 -0.097414
# 2004-09-28 -1.387767 -1.394397 -1.394980  1.089247

# %%
from torch.utils.data import DataLoader
torch.manual_seed(99)

train_loader = DataLoader(train_dataset, batch_size=3, shuffle=True)

X, y = next(iter(train_loader))
print(X.shape)
print(X)
# Out:
# torch.Size([3, 4, 4])
# tensor([[[-1.0283e+00, -1.0363e+00, -1.0355e+00,  3.3244e+00],
#          [-1.0139e+00, -1.0227e+00, -1.0264e+00,  3.3321e+00],
#          [-1.0183e+00, -1.0127e+00, -1.0091e+00,  3.6286e+00],
#          [-1.0379e+00, -1.0229e+00, -1.0300e+00,  3.4512e+00]],
#
#         [[-3.0608e-01, -3.1554e-01, -3.1614e-01,  2.0066e+00],
#          [-2.9534e-01, -2.7960e-01, -2.8488e-01,  2.8479e+00],
#          [-2.8260e-01, -2.8693e-01, -2.9963e-01,  6.5448e-01],
#          [-2.2982e-01, -2.3949e-01, -2.4929e-01,  6.8556e-01]],
#
#         [[-4.5368e-03, -1.7926e-03,  1.3788e-03, -4.5791e-01],
#          [-3.9661e-02, -1.2372e-02, -3.4364e-02, -1.4888e-01],
#          [ 3.1979e-02,  2.4656e-02, -2.3751e-02,  4.4746e-01],
#          [ 3.2486e-02,  2.5747e-02, -5.2009e-03, -2.5444e-01]]])

# %% [markdown]
# ## Create the datasets and data loaders for real

# %% [markdown]
# In this tutorial we will
# use sequences of length 60 (60 days) to forcast 1 day ahead.
#
# The PyTorch `DataLoader` is a very convenient way to iterate through these datasets. For
# the training set we'll shuffle (the rows *within* each training sequence are not
# shuffled, only the order in which we draw those blocks). For the test set, shuffling
# isn't necessary.

# %%
torch.manual_seed(101)

batch_size = 32
sequence_length = 60

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([32, 60, 4])
# Target shape: torch.Size([32])

# %%
print(len(features))
# Out:
# 4

# %% [markdown]
# # LSTM

# %% [markdown]
# ## The model and learning algorithm

# %% [markdown]
# ![picture](https://i.stack.imgur.com/SjnTl.png)
#
# Credit : https://stackoverflow.com/questions/48302810/whats-the-difference-between-hidden-and-output-in-pytorch-lstm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionLSTM(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.lstm = nn.LSTM(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        print("batch_size :",batch_size)
        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionLSTM(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))
# Out:
# batch_size : 32
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShallowRegressionLSTM                    [32]                      --
# ├─LSTM: 1-1                              [32, 60, 60]              103,680
# ├─Linear: 1-2                            [32, 1]                   61
# ==========================================================================================
# Total params: 103,741
# Trainable params: 103,741
# Non-trainable params: 0
# Total mult-adds (M): 199.07
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.41
# Estimated Total Size (MB): 1.37
# ==========================================================================================

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    print( num_batches )
    total_loss = 0
    model.train()

    for X, y in data_loader:
        print(X.shape,y.shape)
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0004776285208002796
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.01263112120795995
#
# Epoch 78
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0005498433295903147
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.007142321759602055
#
# Epoch 79
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.00045828064808892176
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.01273486649733968
#
# Epoch 80
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0004883010815148118
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.007567213426227681
#
# Epoch 81
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.00046024336229750606
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.01234806963475421
#
# Epoch 82
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0004552830484138916
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.007169874501414597
#
# Epoch 83
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.000492867534908242
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.008703589177457616
#
# Epoch 84
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.00044299312328391506
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.006468520499765873
#
# Epoch 85
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# ...
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0004026479589399214
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.009305526706157252
#
# Epoch 98
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0005254231153505212
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.006461587443482131
#
# Epoch 99
# ---------
# 106
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([32, 60, 4]) torch.Size([32])
# batch_size : 32
# torch.Size([6, 60, 4]) torch.Size([6])
# batch_size : 6
# Train loss: 0.0005936153531090998
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# Test loss: 0.024170255754143

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model.pth'
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 6
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 27
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 32
# batch_size : 31
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402       52.646271
# 2004-08-20    55.168217       52.799896
# 2004-08-23    55.412300       54.844299
# 2004-08-24    52.284027       53.112549
# 2004-08-25    52.279045       52.587830
# ...                 ...             ...
# 2019-09-27  1220.969971     1203.750732
# 2019-09-30  1219.000000     1200.191284
# 2019-10-01  1196.979980     1195.909912
# 2019-10-02  1180.000000     1181.464844
# 2019-10-03  1191.890015     1176.163696
#
# [3808 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )
# Out:
# MPAE = 1.9260293625066343
# RMSE = 0.08593972531198864

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="768ad2c2-e299-4d58-b546-ce726a518be0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("768ad2c2-e299-4d58-b546-ce726a518be0")) {                    Plotly.newPlot(                        "768ad2c2-e299-4d58-b546-ce726a518be0",                        [{"hovertemplate":"variable=Open_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open_lead1","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08- ...

# %% [markdown]
# # GRU

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionGRU(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.gru = nn.GRU(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]

        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, hn = self.gru(x, h0)
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionGRU(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShallowRegressionGRU                     [32]                      --
# ├─GRU: 1-1                               [32, 60, 60]              77,760
# ├─Linear: 1-2                            [32, 1]                   61
# ==========================================================================================
# Total params: 77,821
# Trainable params: 77,821
# Non-trainable params: 0
# Total mult-adds (M): 149.30
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.31
# Estimated Total Size (MB): 1.26
# ==========================================================================================

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model_gru.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 0.13306787491881483
# Test loss: 0.36998648941516876
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.007901101212790411
# Test loss: 0.19157683476805687
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.004264304540691159
# Test loss: 0.11873267125338316
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.002774549963365678
# Test loss: 0.03328928363043815
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.002355318848715814
# Test loss: 0.03085647546686232
# Save new best model
#
# Epoch 5
# ---------
# Train loss: 0.0017743902794362203
# Test loss: 0.04075576167088002
#
# Epoch 6
# ---------
# Train loss: 0.001587920632204568
# Test loss: 0.035996956867165864
#
# Epoch 7
# ---------
# Train loss: 0.0015596242801106167
# Test loss: 0.026783331704791635
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.001340228405546063
# Test loss: 0.031298769637942314
#
# Epoch 9
# ---------
# Train loss: 0.0011723210259762435
# Test loss: 0.020110544632188976
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.0012534677653951254
# Test loss: 0.017556400154717267
# Save new best model
#
# Epoch 11
# ---------
# Train loss: 0.0009295942949873553
# Test loss: 0.02321656368440017
#
# Epoch 12
# ---------
# Train loss: 0.0008150321746657972
# Test loss: 0.020074914413271472
#
# Epoch 13
# ---------
# Train loss: 0.0007713769278642809
# Test loss: 0.01949304057052359
#
# Epoch 14
# ---------
# Train loss: 0.0007926252244873947
# Test loss: 0.016663617512676865
# Save new best model
#
# Epoch 15
# ---------
# Train loss: 0.0008949054740610936
# Test loss: 0.01570723467739299
# Save new best model
#
# Epoch 16
# ---------
# Train loss: 0.0007205279782866919
# Test loss: 0.019238439272157848
#
# Epoch 17
# ---------
# Train loss: 0.0007199479985948134
# Test loss: 0.01590360768022947
#
# Epoch 18
# ---------
# Train loss: 0.0006387172731403964
# Test loss: 0.01587987257516943
#
# Epoch 19
# ---------
# Train loss: 0.000627941190993264
# Test loss: 0.01312574467738159
# Save new best model
#
# Epoch 20
# ---------
# Train loss: 0.0006426895355239054
# Test loss: 0.015631538233719766
#
# Epoch 21
# ---------
# Train loss: 0.0006642544026791891
# Test loss: 0.018516271142289042
#
# Epoch 22
# ---------
# Train loss: 0.0007577777872046561
# Test loss: 0.01254376454744488
# Save new best model
#
# Epoch 23
# ---------
# Train loss: 0.0007326775125446422
# Test loss: 0.014760177349671721
#
# Epoch 24
# ---------
# Train loss: 0.0005749475065660487
# Test loss: 0.018033028318313882
#
# Epoch 25
# ---------
# Train loss: 0.0006658035355322458
# Test loss: 0.017214673018315807
#
# Epoch 26
# ---------
# Train loss: 0.0006294603013918946
# Test loss: 0.022482374624814838
#
# Epoch 27
# ---------
# Train loss: 0.00046146939218127747
# Test loss: 0.016966033494099975
#
# Epoch 28
# ---------
# Train loss: 0.000589851301244706
# Test loss: 0.01452041621087119
#
# Epoch 29
# ---------
# Train loss: 0.0005258536581301465
# Test loss: 0.014296906185336411
#
# Epoch 30
# ---------
# Train loss: 0.0005994173232740546
# Test loss: 0.011208806157810614
# Save new best model
#
# Epoch 31
# ---------
# Train loss: 0.0006157718280347872
# Test loss: 0.01584238844225183
#
# Epoch 32
# ---------
# Train loss: 0.0005282304372022341
# Test loss: 0.013349927816307172
#
# Epoch 33
# ---------
# Train loss: 0.0005967802969949707
# Test loss: 0.012231430649990216
#
# Epoch 34
# ---------
# Train loss: 0.000512897376674513
# Test loss: 0.013224986294517294
#
# Epoch 35
# ---------
# Train loss: 0.0007148382709996406
# Test loss: 0.01170848126639612
#
# Epoch 36
# ---------
# Train loss: 0.0008002310772459374
# Test loss: 0.01977061785873957
#
# Epoch 37
# ---------
# Train loss: 0.0005378955482331737
# Test loss: 0.014158757694531232
#
# Epoch 38
# ---------
# Train loss: 0.0005672219814650301
# Test loss: 0.016229614266194403
#
# Epoch 39
# ---------
# Train loss: 0.0005187016557891115
# Test loss: 0.012209112523123622
#
# Epoch 40
# ---------
# Train loss: 0.0006445766418935063
# Test loss: 0.01273855846375227
#
# Epoch 41
# ---------
# Train loss: 0.0005482012671769931
# Test loss: 0.014390215772436932
#
# Epoch 42
# ---------
# Train loss: 0.0005791203325058615
# Test loss: 0.01597258186666295
#
# Epoch 43
# ---------
# Train loss: 0.000459265895325137
# Test loss: 0.012825890153180808
#
# Epoch 44
# ---------
# Train loss: 0.0004979219761394834
# Test loss: 0.010779020289191976
# Save new best model
#
# Epoch 45
# ---------
# Train loss: 0.000555445031973507
# Test loss: 0.013998660491779447
#
# Epoch 46
# ---------
# Train loss: 0.0007958392146425673
# Test loss: 0.0239496678696014
#
# Epoch 47
# ---------
# Train loss: 0.0006029601739461419
# Test loss: 0.018367869895882905
#
# Epoch 48
# ---------
# Train loss: 0.00046381021333355367
# Test loss: 0.015417198635987006
#
# Epoch 49
# ---------
# Train loss: 0.0005419991364348943
# Test loss: 0.013811056705890223
#
# Epoch 50
# ---------
# Train loss: 0.0004791686270728637
# Test loss: 0.01175890551530756
#
# Epoch 51
# ---------
# Train loss: 0.00045404673427291753
# Test loss: 0.015929849178064615
#
# Epoch 52
# ---------
# Train loss: 0.000507745471725873
# Test loss: 0.011894414841663092
#
# Epoch 53
# ---------
# Train loss: 0.0005171902104059041
# Test loss: 0.015339854406192899
#
# Epoch 54
# ---------
# Train loss: 0.0005820912412227184
# Test loss: 0.017332788615021855
#
# Epoch 55
# ---------
# Train loss: 0.0005044901960711697
# Test loss: 0.010308708675438538
# Save new best model
#
# Epoch 56
# ---------
# Train loss: 0.0006931141565388007
# Test loss: 0.03455962997395545
#
# Epoch 57
# ---------
# Train loss: 0.0005715620387696995
# Test loss: 0.012073137244442478
#
# Epoch 58
# ---------
# Train loss: 0.0005363452359199313
# Test loss: 0.017306792171439156
#
# Epoch 59
# ---------
# Train loss: 0.0004959808335664797
# Test loss: 0.015537215978838503
#
# Epoch 60
# ---------
# Train loss: 0.0005193880643450681
# Test loss: 0.019712964334758
#
# Epoch 61
# ---------
# Train loss: 0.0005426811774943313
# Test loss: 0.016690471617039293
#
# Epoch 62
# ---------
# Train loss: 0.0005017361983399891
# Test loss: 0.0140559917781502
#
# Epoch 63
# ---------
# Train loss: 0.0006377424676584098
# Test loss: 0.013626135390950367
#
# Epoch 64
# ---------
# Train loss: 0.0005856483278550067
# Test loss: 0.009708748664706945
# Save new best model
#
# Epoch 65
# ---------
# Train loss: 0.0007568008960625552
# Test loss: 0.012206562329083681
#
# Epoch 66
# ---------
# Train loss: 0.0005430686418000029
# Test loss: 0.013777533720713109
#
# Epoch 67
# ---------
# Train loss: 0.00043400448957295595
# Test loss: 0.011965336074354127
#
# Epoch 68
# ---------
# Train loss: 0.0004525128037096023
# Test loss: 0.012878922891104594
#
# Epoch 69
# ---------
# Train loss: 0.0005397729544470939
# Test loss: 0.010302312846761197
#
# Epoch 70
# ---------
# Train loss: 0.0005625043966849158
# Test loss: 0.01080219518917147
#
# Epoch 71
# ---------
# Train loss: 0.0005209180505843042
# Test loss: 0.015777512191561982
#
# Epoch 72
# ---------
# Train loss: 0.0007657352050372074
# Test loss: 0.02306200680322945
#
# Epoch 73
# ---------
# Train loss: 0.0006343191209864772
# Test loss: 0.017991792439715937
#
# Epoch 74
# ---------
# Train loss: 0.0004312556115075735
# Test loss: 0.012664837791817263
#
# Epoch 75
# ---------
# Train loss: 0.0004590009186084092
# Test loss: 0.017580368788912892
#
# Epoch 76
# ---------
# Train loss: 0.00046608075223597345
# Test loss: 0.008332621888257563
# Save new best model
#
# Epoch 77
# ---------
# Train loss: 0.0005889966391204891
# Test loss: 0.013320553669473156
#
# Epoch 78
# ---------
# Train loss: 0.00040752660095436886
# Test loss: 0.010207350758719258
#
# Epoch 79
# ---------
# Train loss: 0.0005733443882353691
# Test loss: 0.01516204752260819
#
# Epoch 80
# ---------
# Train loss: 0.0005782799796505506
# Test loss: 0.015336393320467323
#
# Epoch 81
# ---------
# Train loss: 0.00048112967996067317
# Test loss: 0.012165443680714816
#
# Epoch 82
# ---------
# Train loss: 0.0005539888242876843
# Test loss: 0.010061804205179214
#
# Epoch 83
# ---------
# Train loss: 0.0008441890575615513
# Test loss: 0.009886042709695175
#
# Epoch 84
# ---------
# Train loss: 0.00048559360055940417
# Test loss: 0.019380451063625515
#
# Epoch 85
# ---------
# Train loss: 0.00043090159052330563
# Test loss: 0.00989703563391231
#
# Epoch 86
# ---------
# Train loss: 0.0005765256205192583
# Test loss: 0.007960453571286052
# Save new best model
#
# Epoch 87
# ---------
# Train loss: 0.00042784553580480313
# Test loss: 0.009374507309985347
#
# Epoch 88
# ---------
# Train loss: 0.0004185373683592946
# Test loss: 0.021739371470175683
#
# Epoch 89
# ---------
# Train loss: 0.0004497223681542926
# Test loss: 0.010137317731278017
#
# Epoch 90
# ---------
# Train loss: 0.000445665230352392
# Test loss: 0.011375449452316388
#
# Epoch 91
# ---------
# Train loss: 0.0005050261697417811
# Test loss: 0.01448987057665363
#
# Epoch 92
# ---------
# Train loss: 0.000437702897404549
# Test loss: 0.011029197368770838
#
# Epoch 93
# ---------
# Train loss: 0.00046987376831480706
# Test loss: 0.00966805696953088
#
# Epoch 94
# ---------
# Train loss: 0.0004805141200810091
# Test loss: 0.01100030675297603
#
# Epoch 95
# ---------
# Train loss: 0.0004883231781175984
# Test loss: 0.010230940068140626
#
# Epoch 96
# ---------
# Train loss: 0.0005047655888703511
# Test loss: 0.00856661077705212
#
# Epoch 97
# ---------
# Train loss: 0.0005782439189578378
# Test loss: 0.008545562799554318
#
# Epoch 98
# ---------
# Train loss: 0.0005246331069051763
# Test loss: 0.010916314728092402
#
# Epoch 99
# ---------
# Train loss: 0.0004602726733554726
# Test loss: 0.01174512691795826

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model_gru.pth'
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402       47.450989
# 2004-08-20    55.168217       45.702606
# 2004-08-23    55.412300       48.377014
# 2004-08-24    52.284027       45.704010
# 2004-08-25    52.279045       45.685150
# ...                 ...             ...
# 2019-09-27  1220.969971     1199.030273
# 2019-09-30  1219.000000     1195.956543
# 2019-10-01  1196.979980     1191.044434
# 2019-10-02  1180.000000     1175.459839
# 2019-10-03  1191.890015     1174.728760
#
# [3808 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_val['Open_lead1'], df_val['Model forecast'])) )
# Out:
# MPAE = 1.9992084789058113
# RMSE = 0.08901431416171235

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="56d88293-629a-4842-8fd1-5ad0c3929f49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56d88293-629a-4842-8fd1-5ad0c3929f49")) {                    Plotly.newPlot(                        "56d88293-629a-4842-8fd1-5ad0c3929f49",                        [{"hovertemplate":"variable=Open_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open_lead1","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08- ...

# %% [markdown]
# # ResNLS

# %% [markdown]
# **Data**
#
#
# *   10 consecutive trading days as the unit step
# *   clean
#
#
# *   normalize it to eliminate scale differences
# *   transform it into tensors
#
# **Train** : closing price data of the SSE Composite
# Index from January 1, 2011 to December 31, 2020
#
# **Test** : closing price data from January 1, 2021 to December 31, 2021
#
#
#
# **Conv**
#
#
# *   filter = 64
# *   kernel size = 3
#
# *   applies ReLU as the activation
# function
# *   weight decay of 1e-5
#
# **dropout layer** with a retain probability of 0.8
#
# **LSTM**
#
#
# *   hidden size = 32
#
# **optimizer** Adam
#
# batch size (64) with a larger initial
# learning rate (1e-3) are preferred
#
# epoch = 50

# %% [markdown]
# ## Data

# %%
features
# Out:
# ['Close', 'High', 'Low', 'Volume']

# %%
torch.manual_seed(101)
# aj
# batch_size = 32
# sequence_length = 60

# best in paper
batch_size = 64
sequence_length = 5

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([64, 5, 4])
# Target shape: torch.Size([64])

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# input = (batch,10,4)
# output = (batch,10,4)
# filter of each conv = 64
# conv1 = (10) -> (64)
# conv2 = (64) -> (64)
# linear = (64) -> (10)
# shortcut = (10) -> (10)
class ResBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, filter, kernel_size=3, stride=1, padding=1):
        super(ResBlock, self).__init__()
        self.conv1 = torch.nn.Conv1d(in_channels, filter, kernel_size, stride, padding)
        self.conv2 = torch.nn.Conv1d(filter, filter, kernel_size, stride, padding)
        self.linear = torch.nn.Linear(filter, out_channels)
        self.relu = torch.nn.ReLU()
        self.bn1 = torch.nn.BatchNorm1d(filter)
        self.bn2 = torch.nn.BatchNorm1d(filter)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.dropout(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = out.view(out.size(0), -1)
        out = self.linear(out)
        out += x.view(x.size(0), -1)
        return out

# model = ResBlock(10, 10, 64)
# summary(model, input_size=(1, 10, 1))

# %%
class ResNLS(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_layer, num_layer, num_feature=4, filter=64, kernel_size=3):
        super(ResNLS, self).__init__()
        self.resblock1 = ResBlock(in_channels, in_channels, filter)
        self.resblock2 = ResBlock(in_channels, in_channels, filter)
        self.resblock3 = ResBlock(in_channels, in_channels, filter)
        self.resblock4 = ResBlock(in_channels, in_channels, filter)
        self.num_layers = num_layer
        self.hidden_layer = hidden_layer
        self.lstm = torch.nn.LSTM(num_feature, hidden_layer, num_layer, batch_first=True)
        self.linear = torch.nn.Linear(hidden_layer, out_channels)

    def forward(self, x):
        batch_size = x.size(0)
        out = torch.split(x, 1, 2)
        out1 = self.resblock1(out[0])
        out2 = self.resblock2(out[1])
        out3 = self.resblock3(out[2])
        out4 = self.resblock4(out[3])
        out1 = out1.unsqueeze(2)
        out2 = out2.unsqueeze(2)
        out3 = out3.unsqueeze(2)
        out4 = out4.unsqueeze(2)
        out = torch.cat((out1, out2, out3, out4), 2)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[-1]).flatten()
        return out

# %%
# Init from paper
num_consecutive_days = sequence_length
days_pred = 1
num_lstm_hiddensize = 32
lstm_layers = 4 # from aj
num_features = len(features)
filters = 64  # Number of filters in convolutional layers
kernel_size = 3  # Kernel size for convolutional layers

model = ResNLS(num_consecutive_days, days_pred, num_lstm_hiddensize,lstm_layers,num_features,filters,kernel_size)
model.to(device)
summary(model, input_size=(32, num_consecutive_days, num_features))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNLS                                   [32]                      --
# ├─ResBlock: 1-1                          [32, 5]                   --
# │    └─Conv1d: 2-1                       [32, 64, 1]               1,024
# │    └─BatchNorm1d: 2-2                  [32, 64, 1]               128
# │    └─ReLU: 2-3                         [32, 64, 1]               --
# │    └─Dropout: 2-4                      [32, 64, 1]               --
# │    └─Conv1d: 2-5                       [32, 64, 1]               12,352
# │    └─BatchNorm1d: 2-6                  [32, 64, 1]               128
# │    └─ReLU: 2-7                         [32, 64, 1]               --
# │    └─Linear: 2-8                       [32, 5]                   325
# ├─ResBlock: 1-2                          [32, 5]                   --
# │    └─Conv1d: 2-9                       [32, 64, 1]               1,024
# │    └─BatchNorm1d: 2-10                 [32, 64, 1]               128
# │    └─ReLU: 2-11                        [32, 64, 1]               --
# │    └─Dropout: 2-12                     [32, 64, 1]               --
# │    └─Conv1d: 2-13                      [32, 64, 1]               12,352
# │    └─BatchNorm1d: 2-14                 [32, 64, 1]               128
# │    └─ReLU: 2-15                        [32, 64, 1]               --
# │    └─Linear: 2-16                      [32, 5]                   325
# ├─ResBlock: 1-3                          [32, 5]                   --
# │    └─Conv1d: 2-17                      [32, 64, 1]               1,024
# │    └─BatchNorm1d: 2-18                 [32, 64, 1]               128
# │    └─ReLU: 2-19                        [32, 64, 1]               --
# │    └─Dropout: 2-20                     [32, 64, 1]               --
# │    └─Conv1d: 2-21                      [32, 64, 1]               12,352
# │    └─BatchNorm1d: 2-22                 [32, 64, 1]               128
# │    └─ReLU: 2-23                        [32, 64, 1]               --
# │    └─Linear: 2-24                      [32, 5]                   325
# ├─ResBlock: 1-4                          [32, 5]                   --
# │    └─Conv1d: 2-25                      [32, 64, 1]               1,024
# │    └─BatchNorm1d: 2-26                 [32, 64, 1]               128
# │    └─ReLU: 2-27                        [32, 64, 1]               --
# │    └─Dropout: 2-28                     [32, 64, 1]               --
# │    └─Conv1d: 2-29                      [32, 64, 1]               12,352
# │    └─BatchNorm1d: 2-30                 [32, 64, 1]               128
# │    └─ReLU: 2-31                        [32, 64, 1]               --
# │    └─Linear: 2-32                      [32, 5]                   325
# ├─LSTM: 1-5                              [32, 5, 32]               30,208
# ├─Linear: 1-6                            [32, 1]                   33
# ==========================================================================================
# Total params: 86,069
# Trainable params: 86,069
# Non-trainable params: 0
# Total mult-adds (M): 6.62
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 0.34
# Estimated Total Size (MB): 0.66
# ==========================================================================================

# %%
parameters_to_decay = []
for name, param in model.named_parameters():
  if 'conv1' in name or 'conv2' in name:
        parameters_to_decay.append(param)

weight_decay=1e-5
learning_rate = 1e-3 # Optimizer lr
optimizer = torch.optim.Adam([{'params': parameters_to_decay, 'weight_decay': weight_decay}], lr=learning_rate)
loss_function = nn.MSELoss() # We use Mean Absolute Error (MAE), Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(500)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 1.01959760796349
# Test loss: 8.578165173530579
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 1.0194551112516872
# Test loss: 8.578165173530579
#
# Epoch 2
# ---------
# Train loss: 1.018442669004764
# Test loss: 8.578165173530579
#
# Epoch 3
# ---------
# Train loss: 1.0201662261531037
# Test loss: 8.578165173530579
#
# Epoch 4
# ---------
# Train loss: 1.0209605356432356
# Test loss: 8.578165173530579
#
# Epoch 5
# ---------
# Train loss: 1.018621657254561
# Test loss: 8.578165173530579
#
# Epoch 6
# ---------
# Train loss: 1.020983950147089
# Test loss: 8.578165173530579
#
# Epoch 7
# ---------
# Train loss: 1.017728679585007
# Test loss: 8.578165173530579
#
# Epoch 8
# ---------
# Train loss: 1.0178309881462242
# Test loss: 8.578165173530579
#
# Epoch 9
# ---------
# Train loss: 1.0174744185411706
# Test loss: 8.578165173530579
#
# Epoch 10
# ---------
# Train loss: 1.0155811287322134
# Test loss: 8.578165173530579
#
# Epoch 11
# ---------
# Train loss: 1.018179842885935
# Test loss: 8.578165173530579
#
# Epoch 12
# ---------
# Train loss: 1.019353156944491
# Test loss: 8.578165173530579
#
# Epoch 13
# ---------
# Train loss: 1.0174519059793004
# Test loss: 8.578165173530579
#
# Epoch 14
# ---------
# Train loss: 1.018650140402452
# Test loss: 8.578165173530579
#
# Epoch 15
# ---------
# Train loss: 1.0197013492854137
# Test loss: 8.578165173530579
#
# Epoch 16
# ---------
# Train loss: 1.0180303836768527
# Test loss: 8.578165173530579
#
# Epoch 17
# ---------
# Train loss: 1.0174585524595008
# Test loss: 8.578165173530579
#
# Epoch 18
# ---------
# Train loss: 1.0169830254788668
# Test loss: 8.578165173530579
#
# Epoch 19
# ---------
# Train loss: 1.014814147409403
# Test loss: 8.578165173530579
#
# Epoch 20
# ---------
# Train loss: 1.0195035653294258
# Test loss: 8.578165173530579
#
# Epoch 21
# ---------
# Train loss: 1.02232940129514
# Test loss: 8.578165173530579
#
# Epoch 22
# ---------
# Train loss: 1.018108384789161
# Test loss: 8.578165173530579
#
# Epoch 23
# ---------
# Train loss: 1.0191663256231345
# Test loss: 8.578165173530579
#
# Epoch 24
# ---------
# Train loss: 1.0175065094569944
# Test loss: 8.578165173530579
#
# Epoch 25
# ---------
# Train loss: 1.0169892479788583
# Test loss: 8.578165173530579
#
# Epoch 26
# ---------
# Train loss: 1.0185569648472768
# Test loss: 8.578165173530579
#
# Epoch 27
# ---------
# Train loss: 1.0210898023731303
# Test loss: 8.578165173530579
#
# Epoch 28
# ---------
# Train loss: 1.0190440348859102
# Test loss: 8.578165173530579
#
# Epoch 29
# ---------
# Train loss: 1.0171737423482932
# Test loss: 8.578165173530579
#
# Epoch 30
# ---------
# Train loss: 1.0165346613470114
# Test loss: 8.578165173530579
#
# Epoch 31
# ---------
# Train loss: 1.016575887518109
# Test loss: 8.578165173530579
#
# Epoch 32
# ---------
# Train loss: 1.019641436495871
# Test loss: 8.578165173530579
#
# Epoch 33
# ---------
# Train loss: 1.0208563602195595
# Test loss: 8.578165173530579
#
# Epoch 34
# ---------
# Train loss: 1.01916474553774
# Test loss: 8.578165173530579
#
# Epoch 35
# ---------
# Train loss: 1.0169500168764367
# Test loss: 8.578165173530579
#
# Epoch 36
# ---------
# Train loss: 1.019616723060608
# Test loss: 8.578165173530579
#
# Epoch 37
# ---------
# Train loss: 1.018526945474013
# Test loss: 8.578165173530579
#
# Epoch 38
# ---------
# Train loss: 1.017447423260167
# Test loss: 8.578165173530579
#
# Epoch 39
# ---------
# Train loss: 1.0182146711169549
# Test loss: 8.578165173530579
#
# Epoch 40
# ---------
# Train loss: 1.0169538192029268
# Test loss: 8.578165173530579
#
# Epoch 41
# ---------
# Train loss: 1.0202487988292046
# Test loss: 8.578165173530579
#
# Epoch 42
# ---------
# Train loss: 1.0162893151337247
# Test loss: 8.578165173530579
#
# Epoch 43
# ---------
# Train loss: 1.0198856918316968
# Test loss: 8.578165173530579
#
# Epoch 44
# ---------
# Train loss: 1.0205370468913384
# Test loss: 8.578165173530579
#
# Epoch 45
# ---------
# Train loss: 1.0199862178766503
# Test loss: 8.578165173530579
#
# Epoch 46
# ---------
# Train loss: 1.0182808390203513
# Test loss: 8.578165173530579
#
# Epoch 47
# ---------
# Train loss: 1.0189102112122301
# Test loss: 8.578165173530579
#
# Epoch 48
# ---------
# Train loss: 1.0180642188719984
# Test loss: 8.578165173530579
#
# Epoch 49
# ---------
# Train loss: 1.0188139542093817
# Test loss: 8.578165173530579

# %% [markdown]
# ## Eval

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
# PATH = './model_gru.pth'
# model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402      423.740845
# 2004-08-20    55.168217      423.725830
# 2004-08-23    55.412300      423.702026
# 2004-08-24    52.284027      423.679565
# 2004-08-25    52.279045      423.670776
# ...                 ...             ...
# 2019-09-27  1220.969971      423.785370
# 2019-09-30  1219.000000      423.783203
# 2019-10-01  1196.979980      423.781494
# 2019-10-02  1180.000000      423.777924
# 2019-10-03  1191.890015      423.774323
#
# [3808 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )
# Out:
# MPAE = 95.7197416779083
# RMSE = 3.0991985062529235

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="62a53a91-2b4a-42fc-88d3-62b3b7d2db3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62a53a91-2b4a-42fc-88d3-62b3b7d2db3a")) {                    Plotly.newPlot(                        "62a53a91-2b4a-42fc-88d3-62b3b7d2db3a",                        [{"hovertemplate":"variable=Open_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eOpen=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open_lead1","showlegend":true,"x":["2004-08-19","2004-08-20","2004-08-23","2004-08-24","2004-08-25","2004-08-26","2004-08-27","2004-08-30","2004-08-31","2004-09-01","2004-09-02","2004-09-03","2004-09-07","2004-09-08","2004-09-09","2004-09-10","2004-09-13","2004-09-14","2004-09-15","2004-09-16","2004-09-17","2004-09-20","2004-09-21","2004-09-22","2004-09-23","2004-09-24","2004-09-27","2004-09-28","2004-09-29","2004-09-30","2004-10-01","2004-10-04","2004-10-05","2004-10-06","2004-10-07","2004-10-08","2004-10-11","2004-10-12","2004-10-13","2004-10-14","2004-10-15","2004-10-18","2004-10-19","2004-10-20","2004-10-21","2004-10-22","2004-10-25","2004-10-26","2004-10-27","2004-10-28","2004-10-29","2004-11-01","2004-11-02","2004-11-03","2004-11-04","2004-11-05","2004-11-08","2004-11-09","2004-11-10","2004-11-11","2004-11-12","2004-11-15","2004-11-16","2004-11-17","2004-11-18","2004-11-19","2004-11-22","2004-11-23","2004-11-24","2004-11-26","2004-11-29","2004-11-30","2004-12-01","2004-12-02","2004-12-03","2004-12-06","2004-12-07","2004-12-08","2004-12-09","2004-12-10","2004-12-13","2004-12-14","2004-12-15","2004-12-16","2004-12-17","2004-12-20","2004-12-21","2004-12-22","2004-12-23","2004-12-27","2004-12-28","2004-12-29","2004-12-30","2004-12-31","2005-01-03","2005-01-04","2005-01-05","2005-01-06","2005-01-07","2005-01-10","2005-01-11","2005-01-12","2005-01-13","2005-01-14","2005-01-18","2005-01-19","2005-01-20","2005-01-21","2005-01-24","2005-01-25","2005-01-26","2005-01-27","2005-01-28","2005-01-31","2005-02-01","2005-02-02","2005-02-03","2005-02-04","2005-02-07","2005-02-08","2005-02-09","2005-02-10","2005-02-11","2005-02-14","2005-02-15","2005-02-16","2005-02-17","2005-02-18","2005-02-22","2005-02-23","2005-02-24","2005-02-25","2005-02-28","2005-03-01","2005-03-02","2005-03-03","2005-03-04","2005-03-07","2005-03-08","2005-03-09","2005-03-10","2005-03-11","2005-03-14","2005-03-15","2005-03-16","2005-03-17","2005-03-18","2005-03-21","2005-03-22","2005-03-23","2005-03-24","2005-03-28","2005-03-29","2005-03-30","2005-03-31","2005-04-01","2005-04-04","2005-04-05","2005-04-06","2005-04-07","2005-04-08","2005-04-11","2005-04-12","2005-04-13","2005-04-14","2005-04-15","2005-04-18","2005-04-19","2005-04-20","2005-04-21","2005-04-22","2005-04-25","2005-04-26","2005-04-27","2005-04-28","2005-04-29","2005-05-02","2005-05-03","2005-05-04","2005-05-05","2005-05-06","2005-05-09","2005-05-10","2005-05-11","2005-05-12","2005-05-13","2005-05-16","2005-05-17","2005-05-18","2005-05-19","2005-05-20","2005-05-23","2005-05-24","2005-05-25","2005-05-26","2005-05-27","2005-05-31","2005-06-01","2005-06-02","2005-06-03","2005-06-06","2005-06-07","2005-06-08","2005-06-09","2005-06-10","2005-06-13","2005-06-14","2005-06-15","2005-06-16","2005-06-17","2005-06-20","2005-06-21","2005-06-22","2005-06-23","2005-06-24","2005-06-27","2005-06-28","2005-06-29","2005-06-30","2005-07-01","2005-07-05","2005-07-06","2005-07-07","2005-07-08","2005-07-11","2005-07-12","2005-07-13","2005-07-14","2005-07-15","2005-07-18","2005-07-19","2005-07-20","2005-07-21","2005-07-22","2005-07-25","2005-07-26","2005-07-27","2005-07-28","2005-07-29","2005-08-01","2005-08-02","2005-08-03","2005-08- ...
