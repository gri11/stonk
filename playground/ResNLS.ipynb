# %% [markdown]
# # How to use PyTorch LSTMs/GRUs for time series regression
# We aim to forcast stock price value by using LSTM with Pytorch.
#
# credit: https://github.com/CrosstabKite/lstm-forecasting/blob/master/lstm_forecasting.ipynb
#
# modified on (12/02/2023)

# %% [markdown]
# # Data

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# !wget https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Out:
# --2024-04-17 17:32:04--  https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv [following]
# --2024-04-17 17:32:04--  https://raw.githubusercontent.com/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/GOOG.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 284248 (278K) [text/plain]
# Saving to: ‘GOOG.csv’
#
# GOOG.csv            100%[===================>] 277.59K  --.-KB/s    in 0.01s
#
# 2024-04-17 17:32:04 (22.0 MB/s) - ‘GOOG.csv’ saved [284248/284248]

# %%
import pandas as pd

df = pd.read_csv('GOOG.csv', index_col="Date")
df = df.drop(['Adj Close'], axis = 1)
df
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
# 2019-10-04  1191.890015  1211.439941  1189.170044  1209.000000   1021092
#
# [3809 rows x 5 columns]

# %%
df.loc['2019-02-26']
# Out:
# Open      1.105750e+03
# High      1.119510e+03
# Low       1.099920e+03
# Close     1.115130e+03
# Volume    1.471300e+06
# Name: 2019-02-26, dtype: float64

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig = px.line(df['Open'], labels=dict(
    created_at="Date", value="Open", variable="Sensor"
))
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()

# %% [markdown]
# ## Create the target variable

# %%
target_col = "Open"
features = list(df.columns.difference([target_col]))

forecast_lead = 1
target = f"{target_col}_lead{forecast_lead}"

df[target] = df[target_col].shift(-forecast_lead)
df = df.iloc[:-forecast_lead]

# %%
features
# Out:
# ['Close', 'High', 'Low', 'Volume']

# %%
df
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2004-08-19    49.813286    51.835709    47.800831    49.982655  44871300
# 2004-08-20    50.316402    54.336334    50.062355    53.952770  22942800
# 2004-08-23    55.168217    56.528118    54.321388    54.495735  18342800
# 2004-08-24    55.412300    55.591629    51.591621    52.239193  15319700
# 2004-08-25    52.284027    53.798351    51.746044    52.802086   9232100
# ...                 ...          ...          ...          ...       ...
# 2019-09-27  1243.010010  1244.020020  1214.449951  1225.089966   1353900
# 2019-09-30  1220.969971  1226.000000  1212.300049  1219.000000   1404100
# 2019-10-01  1219.000000  1231.229980  1203.579956  1205.099976   1273500
# 2019-10-02  1196.979980  1196.979980  1171.290039  1176.630005   1615100
# 2019-10-03  1180.000000  1189.060059  1162.430054  1187.829956   1621200
#
#              Open_lead1
# Date
# 2004-08-19    50.316402
# 2004-08-20    55.168217
# 2004-08-23    55.412300
# 2004-08-24    52.284027
# 2004-08-25    52.279045
# ...                 ...
# 2019-09-27  1220.969971
# 2019-09-30  1219.000000
# 2019-10-01  1196.979980
# 2019-10-02  1180.000000
# 2019-10-03  1191.890015
#
# [3808 rows x 6 columns]

# %% [markdown]
# ## Create a hold-out test set and preprocess the data

# %%
test_start = "2019-01-01"
val_start = "2018-01-01"

df_train = df.loc[:val_start].copy()
df_val = df.loc[val_start:test_start].copy()
df_test = df.loc[test_start:].copy()

print("Test set fraction:", len(df_test) / len(df))
# Out:
# Test set fraction: 0.050157563025210086

# %% [markdown]
# ## Standardize the features and target, based on the training set

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_val[c] = (df_val[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %% [markdown]
# ## Create datasets that PyTorch `DataLoader` can work with

# %%
import torch
from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i):
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %%
i = 27
sequence_length = 4

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)

X, y = train_dataset[i]
print(X)
# Out:
# tensor([[-1.4005, -1.4044, -1.4018,  0.0794],
#         [-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892]])

# %%
X, y = train_dataset[i + 1]
print(X)
# Out:
# tensor([[-1.4026, -1.4013, -1.3959,  0.1501],
#         [-1.4059, -1.4081, -1.4001, -0.0974],
#         [-1.3878, -1.3944, -1.3950,  1.0892],
#         [-1.3789, -1.3784, -1.3822,  2.7240]])

# %%
print(df_train[features].iloc[(i - sequence_length + 1): (i + 1)])
# Out:
#                Close      High       Low    Volume
# Date
# 2004-09-23 -1.400509 -1.404409 -1.401750  0.079391
# 2004-09-24 -1.402597 -1.401323 -1.395935  0.150113
# 2004-09-27 -1.405909 -1.408082 -1.400095 -0.097414
# 2004-09-28 -1.387767 -1.394397 -1.394980  1.089247

# %%
from torch.utils.data import DataLoader
torch.manual_seed(99)

train_loader = DataLoader(train_dataset, batch_size=3, shuffle=True)

X, y = next(iter(train_loader))
print(X.shape)
print(X)
# Out:
# torch.Size([3, 4, 4])
# tensor([[[-1.0283e+00, -1.0363e+00, -1.0355e+00,  3.3244e+00],
#          [-1.0139e+00, -1.0227e+00, -1.0264e+00,  3.3321e+00],
#          [-1.0183e+00, -1.0127e+00, -1.0091e+00,  3.6286e+00],
#          [-1.0379e+00, -1.0229e+00, -1.0300e+00,  3.4512e+00]],
#
#         [[-3.0608e-01, -3.1554e-01, -3.1614e-01,  2.0066e+00],
#          [-2.9534e-01, -2.7960e-01, -2.8488e-01,  2.8479e+00],
#          [-2.8260e-01, -2.8693e-01, -2.9963e-01,  6.5448e-01],
#          [-2.2982e-01, -2.3949e-01, -2.4929e-01,  6.8556e-01]],
#
#         [[-4.5368e-03, -1.7926e-03,  1.3788e-03, -4.5791e-01],
#          [-3.9661e-02, -1.2372e-02, -3.4364e-02, -1.4888e-01],
#          [ 3.1979e-02,  2.4656e-02, -2.3751e-02,  4.4746e-01],
#          [ 3.2486e-02,  2.5747e-02, -5.2009e-03, -2.5444e-01]]])

# %% [markdown]
# ## Create the datasets and data loaders for real

# %% [markdown]
# In this tutorial we will
# use sequences of length 60 (60 days) to forcast 1 day ahead.
#
# The PyTorch `DataLoader` is a very convenient way to iterate through these datasets. For
# the training set we'll shuffle (the rows *within* each training sequence are not
# shuffled, only the order in which we draw those blocks). For the test set, shuffling
# isn't necessary.

# %%
torch.manual_seed(101)

batch_size = 32
sequence_length = 60

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([32, 60, 4])
# Target shape: torch.Size([32])

# %%
print(len(features))
# Out:
# 4

# %% [markdown]
# # Evaluate Function

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

def MASE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y) / torch.mean(torch.abs(y[1:] - y[:-1]))))

def SMAPE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(200 * torch.mean(torch.abs(pred - y) / (torch.abs(y) + torch.abs(pred))))

def MAE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y)))

def sharp_ratio(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean((pred - y) / torch.std(y)))

def directional_accuracy(Y_actual, Y_predicted):
    """
    Calculate the directional accuracy of predictions.

    Parameters:
        Y_actual (array-like): Array of actual stock prices.
        Y_predicted (array-like): Array of predicted stock prices.

    Returns:
        float: Directional accuracy percentage.
    """
    actual_changes = np.sign(np.diff(Y_actual))
    predicted_changes = np.sign(np.diff(Y_predicted))
    correct_predictions = np.sum(actual_changes == predicted_changes)
    total_predictions = len(actual_changes)
    directional_accuracy = correct_predictions / total_predictions * 100
    return directional_accuracy

def evaluate(y_true, y_pred, save=False, model_name="model_name"):
    performance = {}
    performance['MAPE'] = MAPE(y_true, y_pred)
    performance['MASE'] = MASE(y_true, y_pred)
    performance['RMSE'] = math.sqrt(mean_squared_error(y_true, y_pred))
    performance['SMAPE'] = SMAPE(y_true, y_pred)
    performance['MAE'] = MAE(y_true, y_pred)
    performance['sharp_ratio'] = sharp_ratio(y_true, y_pred)
    performance['Directional Accuracy'] = directional_accuracy(y_true, y_pred)

    if save:
        pd.DataFrame(performance, index=[model_name]).to_csv(f'../performance/{model_name}.csv')
        
    return performance

# %% [markdown]
# # LSTM

# %% [markdown]
# ## The model and learning algorithm

# %% [markdown]
# ![picture](https://i.stack.imgur.com/SjnTl.png)
#
# Credit : https://stackoverflow.com/questions/48302810/whats-the-difference-between-hidden-and-output-in-pytorch-lstm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionLSTM(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.lstm = nn.LSTM(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        print("batch_size :",batch_size)
        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionLSTM(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))
# Out:
# batch_size : 32
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShallowRegressionLSTM                    [32]                      --
# ├─LSTM: 1-1                              [32, 60, 60]              103,680
# ├─Linear: 1-2                            [32, 1]                   61
# ==========================================================================================
# Total params: 103,741
# Trainable params: 103,741
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 199.07
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.41
# Estimated Total Size (MB): 1.37
# ==========================================================================================

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    print( num_batches )
    total_loss = 0
    model.train()

    for X, y in data_loader:
        print(X.shape,y.shape)
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), '../model/lstm.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.6869453766014216
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.6352406516671181
# Save new best model
#
# Epoch 1
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.04509786263389407
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.6133237108588219
# Save new best model
#
# Epoch 2
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.016703519662666432
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.2648439146578312
# Save new best model
#
# Epoch 3
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.006306585860175063
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.12165476195514202
# Save new best model
#
# Epoch 4
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0030035132955197456
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.06695755152031779
# Save new best model
#
# Epoch 5
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.002909949923566771
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.08488798514008522
#
# Epoch 6
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.002607616284018699
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.06701554916799068
#
# Epoch 7
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.002582464479173551
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.05220836866647005
# Save new best model
#
# Epoch 8
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.002473340455425095
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.04044804582372308
# Save new best model
#
# Epoch 9
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0024374757700090137
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.04489030293188989
#
# Epoch 10
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.002421742570937945
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.03913172287866473
# Save new best model
#
# Epoch 11
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0023920079100139017
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.036059998674318194
# Save new best model
#
# Epoch 12
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.00237146054091424
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.03697107173502445
#
# Epoch 13
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0025358569131777534
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.05774031858891249
#
# Epoch 14
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0024088241559681745
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.03172330325469375
# Save new best model
#
# Epoch 15
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# ...
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.00047161203467524347
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.005166694871149957
# Save new best model
#
# Epoch 95
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.00044252368745631275
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.004604581627063453
# Save new best model
#
# Epoch 96
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0005158296989975497
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.0058754110941663384
#
# Epoch 97
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0005614542995935377
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.004853985767113045
#
# Epoch 98
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0005070298565837185
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.008767282823100686
#
# Epoch 99
# ---------
# 53
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([64, 5, 4]) torch.Size([64])
# batch_size : 64
# torch.Size([38, 5, 4]) torch.Size([38])
# batch_size : 38
# Train loss: 0.0004969692236045375
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# Test loss: 0.004788063874002546

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model.pth'
model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)

df_out.to_csv('../prediction/lstm.csv')
# Out:
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 38
# batch_size : 64
# batch_size : 64
# batch_size : 64
# batch_size : 59
# batch_size : 64
# batch_size : 64
# batch_size : 63
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402       53.112091
# 2004-08-20    55.168217       53.917480
# 2004-08-23    55.412300       55.764038
# 2004-08-24    52.284027       56.058838
# 2004-08-25    52.279045       55.869080
# ...                 ...             ...
# 2019-09-27  1220.969971     1206.670166
# 2019-09-30  1219.000000     1201.962158
# 2019-10-01  1196.979980     1197.274048
# 2019-10-02  1180.000000     1176.141968
# 2019-10-03  1191.890015     1175.093018
#
# [3808 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )

evaluate(df_test['Open_lead1'], df_test['Model forecast'], save=True, model_name="lstm")
# Out:
# MPAE = 1.681959530243949
# RMSE = 0.07500119532062692
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:10: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:11: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:15: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:16: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:20: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:21: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:25: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:26: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# {'MAPE': 1.681959530243949,
#  'MASE': 1.7282557499060849,
#  'RMSE': 0.07500119532062692,
#  'SMAPE': 1.6987941070934531,
#  'MAE': 0.05606894179363033,
#  'sharp_ratio': 0.18878158381620538,
#  'Directional Accuracy': 67.89473684210526}

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()

# %% [markdown]
# # GRU

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch import nn

class ShallowRegressionGRU(nn.Module):
    def __init__(self, num_features, hidden_units):
        super().__init__()
        self.num_features = num_features  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 4

        self.gru = nn.GRU(
            input_size=num_features,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]

        # initialize the hidden and cell state of the LSTM layer
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).to(device).requires_grad_()

        _, hn = self.gru(x, h0)
        out = self.linear(hn[-1]).flatten()  # get the output of the last hidden layer
        return out

# %%
learning_rate = 5e-4
num_hidden_units = 60

model = ShallowRegressionGRU(num_features=len(features), hidden_units=num_hidden_units)
model.to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torchinfo import summary
summary(model, input_size=(32, 60, 4))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShallowRegressionGRU                     [32]                      --
# ├─GRU: 1-1                               [32, 60, 60]              77,760
# ├─Linear: 1-2                            [32, 1]                   61
# ==========================================================================================
# Total params: 77,821
# Trainable params: 77,821
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 149.30
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.31
# Estimated Total Size (MB): 1.26
# ==========================================================================================

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), '../model/gru.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 0.34671240784930735
# Test loss: 1.1305491477251053
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.015550160385176258
# Test loss: 0.4455285295844078
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.010495688089714298
# Test loss: 0.27411897853016853
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.007961613266676102
# Test loss: 0.2680000104010105
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.006141328968916018
# Test loss: 0.16705784387886524
# Save new best model
#
# Epoch 5
# ---------
# Train loss: 0.004930584880365235
# Test loss: 0.14498217217624187
# Save new best model
#
# Epoch 6
# ---------
# Train loss: 0.004139708655991785
# Test loss: 0.13536485005170107
# Save new best model
#
# Epoch 7
# ---------
# Train loss: 0.003499512046680979
# Test loss: 0.10128855984658003
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.0029590885453629045
# Test loss: 0.06653110217303038
# Save new best model
#
# Epoch 9
# ---------
# Train loss: 0.002549750205428111
# Test loss: 0.04123120731674135
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.0024779351551155997
# Test loss: 0.03417206043377519
# Save new best model
#
# Epoch 11
# ---------
# Train loss: 0.0021768094464380927
# Test loss: 0.036673490423709154
#
# Epoch 12
# ---------
# Train loss: 0.002116040254169899
# Test loss: 0.023619500221684575
# Save new best model
#
# Epoch 13
# ---------
# Train loss: 0.0020098503731753466
# Test loss: 0.030075277900323272
#
# Epoch 14
# ---------
# Train loss: 0.002040379742195584
# Test loss: 0.03229836421087384
#
# Epoch 15
# ---------
# Train loss: 0.001893576524519133
# Test loss: 0.02590327733196318
#
# Epoch 16
# ---------
# Train loss: 0.0018442512472283165
# Test loss: 0.03334298590198159
#
# Epoch 17
# ---------
# Train loss: 0.0018416387567138474
# Test loss: 0.022692670114338398
# Save new best model
#
# Epoch 18
# ---------
# Train loss: 0.002080942052724016
# Test loss: 0.02121960138902068
# Save new best model
#
# Epoch 19
# ---------
# Train loss: 0.0022012200733681894
# Test loss: 0.022694617277011275
#
# Epoch 20
# ---------
# Train loss: 0.001944946831329462
# Test loss: 0.02509733522310853
#
# Epoch 21
# ---------
# Train loss: 0.0016546926981734359
# Test loss: 0.02636028709821403
#
# Epoch 22
# ---------
# Train loss: 0.0016067558745765742
# Test loss: 0.021233084611594677
#
# Epoch 23
# ---------
# Train loss: 0.0016274007953228956
# Test loss: 0.025562020018696785
#
# Epoch 24
# ---------
# Train loss: 0.00165925235245904
# Test loss: 0.02110083377920091
# Save new best model
#
# Epoch 25
# ---------
# Train loss: 0.001672931436124205
# Test loss: 0.01977866538800299
# Save new best model
#
# Epoch 26
# ---------
# Train loss: 0.001577692389716658
# Test loss: 0.018555981572717428
# Save new best model
#
# Epoch 27
# ---------
# Train loss: 0.0015668827877819258
# Test loss: 0.017310704803094268
# Save new best model
#
# Epoch 28
# ---------
# Train loss: 0.0016109339908239836
# Test loss: 0.025085900677368045
#
# Epoch 29
# ---------
# Train loss: 0.001437911708874382
# Test loss: 0.020396029809489846
#
# Epoch 30
# ---------
# Train loss: 0.0014539250603191696
# Test loss: 0.02825603960081935
#
# Epoch 31
# ---------
# Train loss: 0.0014549198204581186
# Test loss: 0.019778328016400337
#
# Epoch 32
# ---------
# Train loss: 0.001332934363745153
# Test loss: 0.01872594957239926
#
# Epoch 33
# ---------
# Train loss: 0.0013240579777080918
# Test loss: 0.021806093864142895
#
# Epoch 34
# ---------
# Train loss: 0.0013482966229653444
# Test loss: 0.016820373246446252
# Save new best model
#
# Epoch 35
# ---------
# Train loss: 0.001173761660092563
# Test loss: 0.016374538536183536
# Save new best model
#
# Epoch 36
# ---------
# Train loss: 0.001142816901435408
# Test loss: 0.0216258333530277
#
# Epoch 37
# ---------
# Train loss: 0.0012937366725209187
# Test loss: 0.016945381532423198
#
# Epoch 38
# ---------
# Train loss: 0.001109968792901919
# Test loss: 0.011952103697694838
# Save new best model
#
# Epoch 39
# ---------
# Train loss: 0.0010888118380329237
# Test loss: 0.015530557138845325
#
# Epoch 40
# ---------
# Train loss: 0.001143962071268415
# Test loss: 0.021039228653535247
#
# Epoch 41
# ---------
# Train loss: 0.0010092366302280494
# Test loss: 0.010537241818383336
# Save new best model
#
# Epoch 42
# ---------
# Train loss: 0.0011425755021847643
# Test loss: 0.013094073859974742
#
# Epoch 43
# ---------
# Train loss: 0.0009733007689235064
# Test loss: 0.03045639954507351
#
# Epoch 44
# ---------
# Train loss: 0.0009478009547511081
# Test loss: 0.016234074253588915
#
# Epoch 45
# ---------
# Train loss: 0.0008838581918510345
# Test loss: 0.021751316031441092
#
# Epoch 46
# ---------
# Train loss: 0.0010221106157295475
# Test loss: 0.013420045026578009
#
# Epoch 47
# ---------
# Train loss: 0.0008474265940197445
# Test loss: 0.016145917703397572
#
# Epoch 48
# ---------
# Train loss: 0.0010371165161179204
# Test loss: 0.011154391802847385
#
# Epoch 49
# ---------
# Train loss: 0.0008467509870347127
# Test loss: 0.01064947189297527
#
# Epoch 50
# ---------
# Train loss: 0.0008244031737119241
# Test loss: 0.015996258473023772
#
# Epoch 51
# ---------
# Train loss: 0.0008012623482774767
# Test loss: 0.013775254716165364
#
# Epoch 52
# ---------
# Train loss: 0.0007502174555139511
# Test loss: 0.014758182456716895
#
# Epoch 53
# ---------
# Train loss: 0.0007565894465067617
# Test loss: 0.017149804159998894
#
# Epoch 54
# ---------
# Train loss: 0.0007570777846201552
# Test loss: 0.01814039540477097
#
# Epoch 55
# ---------
# Train loss: 0.0008080092957243323
# Test loss: 0.011297319957520813
#
# Epoch 56
# ---------
# Train loss: 0.0006207691945952698
# Test loss: 0.016636716667562723
#
# Epoch 57
# ---------
# Train loss: 0.000628377157724726
# Test loss: 0.012197736883535981
#
# Epoch 58
# ---------
# Train loss: 0.000642074945268555
# Test loss: 0.007717920409049839
# Save new best model
#
# Epoch 59
# ---------
# Train loss: 0.0005939473856003287
# Test loss: 0.009903070982545614
#
# Epoch 60
# ---------
# Train loss: 0.0006490812012552336
# Test loss: 0.011209959397092462
#
# Epoch 61
# ---------
# Train loss: 0.0005938573581175351
# Test loss: 0.007987800112459809
#
# Epoch 62
# ---------
# Train loss: 0.0006200138884179189
# Test loss: 0.01241494168061763
#
# Epoch 63
# ---------
# Train loss: 0.000552083879603811
# Test loss: 0.010245785815641284
#
# Epoch 64
# ---------
# Train loss: 0.0005425592949767685
# Test loss: 0.01291551231406629
#
# Epoch 65
# ---------
# Train loss: 0.00050141652667113
# Test loss: 0.013259718078188598
#
# Epoch 66
# ---------
# Train loss: 0.0006037142414946706
# Test loss: 0.009802257176488638
#
# Epoch 67
# ---------
# Train loss: 0.0004788240816505661
# Test loss: 0.011498515377752483
#
# Epoch 68
# ---------
# Train loss: 0.0004950442056518645
# Test loss: 0.017797519452869892
#
# Epoch 69
# ---------
# Train loss: 0.0005635079281966922
# Test loss: 0.009576327924150974
#
# Epoch 70
# ---------
# Train loss: 0.0005725798216859266
# Test loss: 0.010215836809948087
#
# Epoch 71
# ---------
# Train loss: 0.0005287488767073297
# Test loss: 0.013721193303354084
#
# Epoch 72
# ---------
# Train loss: 0.00044774115365657535
# Test loss: 0.008688641886692494
#
# Epoch 73
# ---------
# Train loss: 0.0004847129828292209
# Test loss: 0.009138077963143587
#
# Epoch 74
# ---------
# Train loss: 0.0004922522161647959
# Test loss: 0.013745583011768758
#
# Epoch 75
# ---------
# Train loss: 0.0004570729696117166
# Test loss: 0.006425452535040677
# Save new best model
#
# Epoch 76
# ---------
# Train loss: 0.00042164773377699705
# Test loss: 0.007052094617392868
#
# Epoch 77
# ---------
# Train loss: 0.000492162705961404
# Test loss: 0.007050577783957124
#
# Epoch 78
# ---------
# Train loss: 0.0004998964692997517
# Test loss: 0.008761420263908803
#
# Epoch 79
# ---------
# Train loss: 0.0004370042418331822
# Test loss: 0.006805032666306943
#
# Epoch 80
# ---------
# Train loss: 0.00042850932285940836
# Test loss: 0.008641061489470303
#
# Epoch 81
# ---------
# Train loss: 0.0004748111310138209
# Test loss: 0.01180095283780247
#
# Epoch 82
# ---------
# Train loss: 0.0004530133596316138
# Test loss: 0.006512274092528969
#
# Epoch 83
# ---------
# Train loss: 0.0004058583928678483
# Test loss: 0.00975914264563471
#
# Epoch 84
# ---------
# Train loss: 0.00044957352340889146
# Test loss: 0.011378240655176342
#
# Epoch 85
# ---------
# Train loss: 0.00043126048145701514
# Test loss: 0.005725789931602776
# Save new best model
#
# Epoch 86
# ---------
# Train loss: 0.0004150436853139907
# Test loss: 0.007840962731279433
#
# Epoch 87
# ---------
# Train loss: 0.0004422471000272605
# Test loss: 0.00817255099536851
#
# Epoch 88
# ---------
# Train loss: 0.0003896482590309186
# Test loss: 0.006673207157291472
#
# Epoch 89
# ---------
# Train loss: 0.0005318183375836596
# Test loss: 0.012599910027347505
#
# Epoch 90
# ---------
# Train loss: 0.0005282953672302132
# Test loss: 0.01976441079750657
#
# Epoch 91
# ---------
# Train loss: 0.0004894569535950586
# Test loss: 0.010675979661755264
#
# Epoch 92
# ---------
# Train loss: 0.0005258257684236358
# Test loss: 0.009902177844196558
#
# Epoch 93
# ---------
# Train loss: 0.0004677531772890603
# Test loss: 0.008717906312085688
#
# Epoch 94
# ---------
# Train loss: 0.00045046650305970235
# Test loss: 0.008328609343152493
#
# Epoch 95
# ---------
# Train loss: 0.0005283335060153578
# Test loss: 0.011917797150090337
#
# Epoch 96
# ---------
# Train loss: 0.000531829516612046
# Test loss: 0.005080787988845259
# Save new best model
#
# Epoch 97
# ---------
# Train loss: 0.0004511079410495201
# Test loss: 0.011223227833397686
#
# Epoch 98
# ---------
# Train loss: 0.0004652769647742938
# Test loss: 0.00978762551676482
#
# Epoch 99
# ---------
# Train loss: 0.000484551133956971
# Test loss: 0.007516517769545317

# %% [markdown]
# ## Evaluation

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
PATH = './model_gru.pth'
model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)

df_out.to_csv('../prediction/gru.csv')
# Out:
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402       53.371277
# 2004-08-20    55.168217       52.273773
# 2004-08-23    55.412300       54.736511
# 2004-08-24    52.284027       53.409149
# 2004-08-25    52.279045       53.409210
# ...                 ...             ...
# 2019-09-27  1220.969971     1194.187134
# 2019-09-30  1219.000000     1188.922119
# 2019-10-01  1196.979980     1183.737549
# 2019-10-02  1180.000000     1163.824829
# 2019-10-03  1191.890015     1163.166748
#
# [3808 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

print( 'MPAE =', MAPE(df_test['Open_lead1'], df_test['Model forecast']) )
print( 'RMSE =', math.sqrt(mean_squared_error(df_val['Open_lead1'], df_val['Model forecast'])) )

evaluate(df_test['Open_lead1'], df_test['Model forecast'], save=True, model_name="gru")
# Out:
# MPAE = 2.5194540548463307
# RMSE = 0.08706364115633747
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:10: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:11: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:15: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:16: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:20: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:21: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:25: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/3516962791.py:26: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# {'MAPE': 2.5194540548463307,
#  'MASE': 2.6029905851951716,
#  'RMSE': 0.10386774314433589,
#  'SMAPE': 2.5635520506314737,
#  'MAE': 0.08425753775456545,
#  'sharp_ratio': 0.4110691183660507,
#  'Directional Accuracy': 69.47368421052632}

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()

# %% [markdown]
# # ResNLS

# %% [markdown]
# **Data**
#
#
# *   10 consecutive trading days as the unit step
# *   clean
#
#
# *   normalize it to eliminate scale differences
# *   transform it into tensors
#
# **Train** : closing price data of the SSE Composite
# Index from January 1, 2011 to December 31, 2020
#
# **Test** : closing price data from January 1, 2021 to December 31, 2021
#
#
#
# **Conv**
#
#
# *   filter = 64
# *   kernel size = 3
#
# *   applies ReLU as the activation
# function
# *   weight decay of 1e-5
#
# **dropout layer** with a retain probability of 0.8
#
# **LSTM**
#
#
# *   hidden size = 32
#
# **optimizer** Adam
#
# batch size (64) with a larger initial
# learning rate (1e-3) are preferred
#
# epoch = 50

# %% [markdown]
# ## Data

# %%
features
# Out:
# ['Close', 'High', 'Low', 'Volume']

# %%
torch.manual_seed(101)
# aj
# batch_size = 32
# sequence_length = 60

# # best in paper
batch_size = 64
sequence_length = 5

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([64, 5, 4])
# Target shape: torch.Size([64])

# %% [markdown]
# ## The model and learning algorithm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# input = (batch,10,4)
# output = (batch,10,4)
# filter of each conv = 64
# conv1 = (10) -> (64)
# conv2 = (64) -> (64)
# linear = (64) -> (10)
# shortcut = (10) -> (10)
class ResBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, filter, kernel_size=3, stride=1, padding=1):
        super(ResBlock, self).__init__()
        self.conv1 = torch.nn.Conv1d(in_channels, filter, kernel_size, stride, padding)
        self.conv2 = torch.nn.Conv1d(filter, filter, kernel_size, stride, padding)
        self.linear = torch.nn.Linear(filter, out_channels)
        self.relu = torch.nn.ReLU()
        self.bn1 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.bn2 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.dropout = nn.Dropout(0.2)
        # intialise weights of the attention mechanism
        self.weight = nn.Parameter(torch.zeros(1)).to(device)


    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.bn1(out)

        out = self.dropout(out)

        out = self.conv2(out)
        out = self.relu(out)
        out = self.bn2(out)

        out = out.view(out.size(0), -1)
        out = self.linear(out)
        out = self.weight*out
        out += x.view(x.size(0), -1)
        return out

# model = ResBlock(10, 10, 64)
# summary(model, input_size=(1, 10, 1))

# %%
class ResNLS(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_layer, num_layer, num_feature=4, filter=64, kernel_size=3):
        super(ResNLS, self).__init__()
        self.resblock1 = ResBlock(in_channels, in_channels, filter)
        self.resblock2 = ResBlock(in_channels, in_channels, filter)
        self.resblock3 = ResBlock(in_channels, in_channels, filter)
        self.resblock4 = ResBlock(in_channels, in_channels, filter)
        self.num_layers = num_layer
        self.hidden_layer = hidden_layer
        self.lstm = torch.nn.LSTM(num_feature, hidden_layer, num_layer, batch_first=True)
        self.linear = torch.nn.Linear(hidden_layer, out_channels)


    def forward(self, x):
        batch_size = x.size(0)
        out = torch.split(x, 1, 2)
        out1 = self.resblock1(out[0])
        out2 = self.resblock2(out[1])
        out3 = self.resblock3(out[2])
        out4 = self.resblock4(out[3])
        out1 = out1.unsqueeze(2)
        out2 = out2.unsqueeze(2)
        out3 = out3.unsqueeze(2)
        out4 = out4.unsqueeze(2)
        out = torch.cat((out1, out2, out3, out4), 2)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_layer).to(device).requires_grad_()
        _, (hn, _) = self.lstm(out, (h0, c0))
        out = self.linear(hn[-1]).flatten()
        return out

# %%
# Init from paper
num_consecutive_days = sequence_length
days_pred = 1
# num_lstm_hiddensize = 32
num_lstm_hiddensize = 64
# lstm_layers = 4 # from aj
# lstm_layers = 64 # from paper
lstm_layers = 1

num_features = len(features)
filters = 64  # Number of filters in convolutional layers
kernel_size = 3  # Kernel size for convolutional layers

model = ResNLS(num_consecutive_days,
               days_pred,
               num_lstm_hiddensize,
               lstm_layers,
               num_features,
               filters,
               kernel_size)
model.to(device)
summary(model, input_size=(batch_size, num_consecutive_days, num_features))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNLS                                   [64]                      --
# ├─ResBlock: 1-1                          [64, 5]                   1
# │    └─Conv1d: 2-1                       [64, 64, 1]               1,024
# │    └─ReLU: 2-2                         [64, 64, 1]               --
# │    └─BatchNorm1d: 2-3                  [64, 64, 1]               128
# │    └─Dropout: 2-4                      [64, 64, 1]               --
# │    └─Conv1d: 2-5                       [64, 64, 1]               12,352
# │    └─ReLU: 2-6                         [64, 64, 1]               --
# │    └─BatchNorm1d: 2-7                  [64, 64, 1]               128
# │    └─Linear: 2-8                       [64, 5]                   325
# ├─ResBlock: 1-2                          [64, 5]                   1
# │    └─Conv1d: 2-9                       [64, 64, 1]               1,024
# │    └─ReLU: 2-10                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-11                 [64, 64, 1]               128
# │    └─Dropout: 2-12                     [64, 64, 1]               --
# │    └─Conv1d: 2-13                      [64, 64, 1]               12,352
# │    └─ReLU: 2-14                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-15                 [64, 64, 1]               128
# │    └─Linear: 2-16                      [64, 5]                   325
# ├─ResBlock: 1-3                          [64, 5]                   1
# │    └─Conv1d: 2-17                      [64, 64, 1]               1,024
# │    └─ReLU: 2-18                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-19                 [64, 64, 1]               128
# │    └─Dropout: 2-20                     [64, 64, 1]               --
# │    └─Conv1d: 2-21                      [64, 64, 1]               12,352
# │    └─ReLU: 2-22                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-23                 [64, 64, 1]               128
# │    └─Linear: 2-24                      [64, 5]                   325
# ├─ResBlock: 1-4                          [64, 5]                   1
# │    └─Conv1d: 2-25                      [64, 64, 1]               1,024
# │    └─ReLU: 2-26                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-27                 [64, 64, 1]               128
# │    └─Dropout: 2-28                     [64, 64, 1]               --
# │    └─Conv1d: 2-29                      [64, 64, 1]               12,352
# │    └─ReLU: 2-30                        [64, 64, 1]               --
# │    └─BatchNorm1d: 2-31                 [64, 64, 1]               128
# │    └─Linear: 2-32                      [64, 5]                   325
# ├─LSTM: 1-5                              [64, 5, 64]               17,920
# ├─Linear: 1-6                            [64, 1]                   65
# ==========================================================================================
# Total params: 73,817
# Trainable params: 73,817
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 9.31
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.70
# Params size (MB): 0.30
# Estimated Total Size (MB): 1.00
# ==========================================================================================

# %%
parameters_to_decay = []
for name, param in model.named_parameters():
  if 'conv1' in name or 'conv2' in name:
        parameters_to_decay.append(param)

weight_decay=1e-5
learning_rate = 1e-3 # Optimizer lr
# optimizer = torch.optim.Adam([{'params': parameters_to_decay, 'weight_decay': weight_decay}], lr=learning_rate)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)


loss_function = nn.MSELoss() # We use Mean Absolute Error (MAE), Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)

# %%
# class RealResNLS(nn.Module):

#     def __init__(self):
#         super(ResNLS, self).__init__()

#         # intialise weights of the attention mechanism
#         self.weight = nn.Parameter(torch.zeros(1)).to(device)

#         # intialise cnn structure
#         self.cnn = nn.Sequential(
#             nn.Conv1d(in_channels=1, out_channels=n_hidden, kernel_size=3, stride=1, padding=1), # ((5 + 1*2 - 3)/1 + 1) = 5
#             nn.ReLU(inplace=True),
#             nn.BatchNorm1d(n_hidden, eps=1e-5),
#             nn.Dropout(0.1),

#             nn.Conv1d(in_channels=n_hidden, out_channels=n_hidden, kernel_size=3, stride=1, padding=1), # ((5 + 1*2 - 3)/1 + 1) = 5
#             nn.ReLU(inplace=True),
#             nn.BatchNorm1d(n_hidden, eps=1e-5),

#             nn.Flatten(),
#             nn.Linear(n_input * n_hidden, n_input)
#         )

#         # intialise lstm structure
#         self.lstm = nn.LSTM(n_input, n_hidden, batch_first=True, bidirectional=False)
#         self.linear = nn.Linear(n_hidden, 1)


#     def forward(self, x):

#         cnn_output = self.cnn(x)
#         cnn_output = cnn_output.view(-1, 1, n_input)

#         residuals = x + self.weight * cnn_output

#         _, (h_n, _)  = self.lstm(residuals)
#         y_hat = self.linear(h_n[0,:,:])

#         return y_hat

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## Train

# %%
from tqdm.notebook import tqdm

def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss

# %%
best_val_loss = torch.inf
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_model(train_loader, model, loss_function, optimizer=optimizer)
    best_val_loss = test_model(val_loader, model, loss_function, best_val_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 0.3152063791903685
# Test loss: 0.7282065153121948
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.011816457098455361
# Test loss: 0.24090491980314255
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.0028736096672836763
# Test loss: 0.0962008903734386
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.0014576506471472247
# Test loss: 0.06493652192875743
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.0013158784153484652
# Test loss: 0.07038786774501204
#
# Epoch 5
# ---------
# Train loss: 0.0011431648525549979
# Test loss: 0.07026521675288677
#
# Epoch 6
# ---------
# Train loss: 0.000897392734911574
# Test loss: 0.08574298489838839
#
# Epoch 7
# ---------
# Train loss: 0.0009044980650047227
# Test loss: 0.04329994390718639
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.0008332820857418174
# Test loss: 0.03324078465811908
# Save new best model
#
# Epoch 9
# ---------
# Train loss: 0.0006717633640499047
# Test loss: 0.03894808911718428
#
# Epoch 10
# ---------
# Train loss: 0.0007122868926259953
# Test loss: 0.04056375357322395
#
# Epoch 11
# ---------
# Train loss: 0.0006851978948172884
# Test loss: 0.03047180105932057
# Save new best model
#
# Epoch 12
# ---------
# Train loss: 0.0005996538895041735
# Test loss: 0.024167737108655274
# Save new best model
#
# Epoch 13
# ---------
# Train loss: 0.0005724619811001005
# Test loss: 0.022265949635766447
# Save new best model
#
# Epoch 14
# ---------
# Train loss: 0.0005631774951119573
# Test loss: 0.017914780415594578
# Save new best model
#
# Epoch 15
# ---------
# Train loss: 0.0005814667748845235
# Test loss: 0.02314889244735241
#
# Epoch 16
# ---------
# Train loss: 0.0005899916006524538
# Test loss: 0.019662982900626957
#
# Epoch 17
# ---------
# Train loss: 0.0005478551309283401
# Test loss: 0.01879814174026251
#
# Epoch 18
# ---------
# Train loss: 0.0005432850500581926
# Test loss: 0.017480607493780553
# Save new best model
#
# Epoch 19
# ---------
# Train loss: 0.0005050052107281034
# Test loss: 0.016896841931156814
# Save new best model
#
# Epoch 20
# ---------
# Train loss: 0.0006005251675817834
# Test loss: 0.023078243248164654
#
# Epoch 21
# ---------
# Train loss: 0.0005069128665985223
# Test loss: 0.01353390741860494
# Save new best model
#
# Epoch 22
# ---------
# Train loss: 0.0005515285634176524
# Test loss: 0.017942248843610287
#
# Epoch 23
# ---------
# Train loss: 0.0004918431362932337
# Test loss: 0.010347098752390593
# Save new best model
#
# Epoch 24
# ---------
# Train loss: 0.0005168215715423015
# Test loss: 0.028156225569546223
#
# Epoch 25
# ---------
# Train loss: 0.0004888944031850804
# Test loss: 0.026651879074051976
#
# Epoch 26
# ---------
# Train loss: 0.0004988896225596655
# Test loss: 0.025308382464572787
#
# Epoch 27
# ---------
# Train loss: 0.0005320756991870508
# Test loss: 0.04559527104720473
#
# Epoch 28
# ---------
# Train loss: 0.0005470454604430827
# Test loss: 0.017553482321090996
#
# Epoch 29
# ---------
# Train loss: 0.0005268184448930628
# Test loss: 0.02531349239870906
#
# Epoch 30
# ---------
# Train loss: 0.000458235499055898
# Test loss: 0.016811429639346898
#
# Epoch 31
# ---------
# Train loss: 0.0005180992912017864
# Test loss: 0.014822106924839318
#
# Epoch 32
# ---------
# Train loss: 0.0005062608543084934
# Test loss: 0.015884141554124653
#
# Epoch 33
# ---------
# Train loss: 0.0004955816811899531
# Test loss: 0.010081241838634014
# Save new best model
#
# Epoch 34
# ---------
# Train loss: 0.0005615620562512393
# Test loss: 0.018683467409573495
#
# Epoch 35
# ---------
# Train loss: 0.0005024857580209291
# Test loss: 0.011406540346797556
#
# Epoch 36
# ---------
# Train loss: 0.000506725255070465
# Test loss: 0.012786791892722249
#
# Epoch 37
# ---------
# Train loss: 0.0004820257707011341
# Test loss: 0.011964244651608169
#
# Epoch 38
# ---------
# Train loss: 0.0004487280546630434
# Test loss: 0.012748135370202363
#
# Epoch 39
# ---------
# Train loss: 0.0005422666389385309
# Test loss: 0.017275321413762867
#
# Epoch 40
# ---------
# Train loss: 0.00047844069963760393
# Test loss: 0.018848625477403402
#
# Epoch 41
# ---------
# Train loss: 0.0005261854492105931
# Test loss: 0.013336954405531287
#
# Epoch 42
# ---------
# Train loss: 0.00047960443579249157
# Test loss: 0.010366278002038598
#
# Epoch 43
# ---------
# Train loss: 0.0005042548291385174
# Test loss: 0.007403247524052858
# Save new best model
#
# Epoch 44
# ---------
# Train loss: 0.0005381917569979603
# Test loss: 0.01314762921538204
#
# Epoch 45
# ---------
# Train loss: 0.0005275915049561212
# Test loss: 0.012698182021267712
#
# Epoch 46
# ---------
# Train loss: 0.0004479738500382189
# Test loss: 0.016979713458567858
#
# Epoch 47
# ---------
# Train loss: 0.00045753540696339014
# Test loss: 0.021459444658830762
#
# Epoch 48
# ---------
# Train loss: 0.00046938492006068735
# Test loss: 0.011596156749874353
#
# Epoch 49
# ---------
# Train loss: 0.0005369637359728826
# Test loss: 0.010492806497495621
#
# Epoch 50
# ---------
# Train loss: 0.0004738226636172325
# Test loss: 0.007309182605240494
# Save new best model
#
# Epoch 51
# ---------
# Train loss: 0.000504362109701483
# Test loss: 0.006935216602869332
# Save new best model
#
# Epoch 52
# ---------
# Train loss: 0.0005067568181745954
# Test loss: 0.01661429589148611
#
# Epoch 53
# ---------
# Train loss: 0.000592344590431993
# Test loss: 0.009186060226056725
#
# Epoch 54
# ---------
# Train loss: 0.00048378226402180516
# Test loss: 0.010091151692904532
#
# Epoch 55
# ---------
# Train loss: 0.00044611212687637163
# Test loss: 0.0074199618538841605
#
# Epoch 56
# ---------
# Train loss: 0.000603853868494109
# Test loss: 0.01613800460472703
#
# Epoch 57
# ---------
# Train loss: 0.0005210894965819294
# Test loss: 0.012470406130887568
#
# Epoch 58
# ---------
# Train loss: 0.0004832144027118975
# Test loss: 0.006670444621704519
# Save new best model
#
# Epoch 59
# ---------
# Train loss: 0.0004976345732740021
# Test loss: 0.006023254187311977
# Save new best model
#
# Epoch 60
# ---------
# Train loss: 0.0005356655983289458
# Test loss: 0.009696328081190586
#
# Epoch 61
# ---------
# Train loss: 0.00046992134429154177
# Test loss: 0.0056751340162009
# Save new best model
#
# Epoch 62
# ---------
# Train loss: 0.00047230285857057305
# Test loss: 0.01292872754856944
#
# Epoch 63
# ---------
# Train loss: 0.000502826761561973
# Test loss: 0.011594397015869617
#
# Epoch 64
# ---------
# Train loss: 0.0005342791404438925
# Test loss: 0.013620803598314524
#
# Epoch 65
# ---------
# Train loss: 0.0005151561646994625
# Test loss: 0.015810819575563073
#
# Epoch 66
# ---------
# Train loss: 0.00048757852950212456
# Test loss: 0.00591652566799894
#
# Epoch 67
# ---------
# Train loss: 0.00044696858245549937
# Test loss: 0.009784001158550382
#
# Epoch 68
# ---------
# Train loss: 0.0004741884008838514
# Test loss: 0.0057235321146436036
#
# Epoch 69
# ---------
# Train loss: 0.0005296584996306952
# Test loss: 0.03135311510413885
#
# Epoch 70
# ---------
# Train loss: 0.000592725564789396
# Test loss: 0.013497048057615757
#
# Epoch 71
# ---------
# Train loss: 0.0005188175550670767
# Test loss: 0.008537359826732427
#
# Epoch 72
# ---------
# Train loss: 0.0005128613932888498
# Test loss: 0.00820057897362858
#
# Epoch 73
# ---------
# Train loss: 0.000472030911555092
# Test loss: 0.0067352597252465785
#
# Epoch 74
# ---------
# Train loss: 0.000487855044995294
# Test loss: 0.008771954861003906
#
# Epoch 75
# ---------
# Train loss: 0.0004304980537645466
# Test loss: 0.006006320705637336
#
# Epoch 76
# ---------
# Train loss: 0.0004958687998125997
# Test loss: 0.007518752594478428
#
# Epoch 77
# ---------
# Train loss: 0.0005606834256125368
# Test loss: 0.016276231268420815
#
# Epoch 78
# ---------
# Train loss: 0.0005201349001408573
# Test loss: 0.005090566526632756
# Save new best model
#
# Epoch 79
# ---------
# Train loss: 0.00048702795229817056
# Test loss: 0.009871212765574455
#
# Epoch 80
# ---------
# Train loss: 0.00047239726672897923
# Test loss: 0.0052708124567288905
#
# Epoch 81
# ---------
# Train loss: 0.0005204924752931374
# Test loss: 0.011595319723710418
#
# Epoch 82
# ---------
# Train loss: 0.0004336391070435913
# Test loss: 0.008032662910409272
#
# Epoch 83
# ---------
# Train loss: 0.00047181411245442433
# Test loss: 0.004388870409457013
# Save new best model
#
# Epoch 84
# ---------
# Train loss: 0.000879483961638608
# Test loss: 0.005887812119908631
#
# Epoch 85
# ---------
# Train loss: 0.000655643980212088
# Test loss: 0.005994671140797436
#
# Epoch 86
# ---------
# Train loss: 0.00045536232525746355
# Test loss: 0.010789706953801215
#
# Epoch 87
# ---------
# Train loss: 0.0004076450859429315
# Test loss: 0.005097625340567902
#
# Epoch 88
# ---------
# Train loss: 0.0004439122770596647
# Test loss: 0.005260398989776149
#
# Epoch 89
# ---------
# Train loss: 0.00043210053400747164
# Test loss: 0.009953174274414778
#
# Epoch 90
# ---------
# Train loss: 0.0004975654350655188
# Test loss: 0.004287621763069183
# Save new best model
#
# Epoch 91
# ---------
# Train loss: 0.0004593939794983082
# Test loss: 0.0045923277793917805
#
# Epoch 92
# ---------
# Train loss: 0.00041515189596399104
# Test loss: 0.00873669853899628
#
# Epoch 93
# ---------
# Train loss: 0.00043368140863746685
# Test loss: 0.00573519803583622
#
# Epoch 94
# ---------
# Train loss: 0.0004470809898229386
# Test loss: 0.0035941507667303085
# Save new best model
#
# Epoch 95
# ---------
# Train loss: 0.0004097417133963526
# Test loss: 0.007848122564610094
#
# Epoch 96
# ---------
# Train loss: 0.00046411794824481785
# Test loss: 0.005376026267185807
#
# Epoch 97
# ---------
# Train loss: 0.0004242357752892136
# Test loss: 0.006411731999833137
#
# Epoch 98
# ---------
# Train loss: 0.0004974975690513604
# Test loss: 0.008338259649462998
#
# Epoch 99
# ---------
# Train loss: 0.000458052463418769
# Test loss: 0.004392554459627718

# %% [markdown]
# ## Eval

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)

    return output

# %%
# PATH = './model_gru.pth'
# model.load_state_dict(torch.load(PATH))

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)

df_out.to_csv('../prediction/resnls.csv')
# Out:
#              Open_lead1  Model forecast
# Date
# 2004-08-19    50.316402       53.084229
# 2004-08-20    55.168217       55.470551
# 2004-08-23    55.412300       55.734650
# 2004-08-24    52.284027       55.338898
# 2004-08-25    52.279045       55.325745
# ...                 ...             ...
# 2019-09-27  1220.969971     1202.233521
# 2019-09-30  1219.000000     1200.860718
# 2019-10-01  1196.979980     1193.661743
# 2019-10-02  1180.000000     1171.300171
# 2019-10-03  1191.890015     1175.334595
#
# [3808 rows x 2 columns]

# %%
def MASE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y) / torch.mean(torch.abs(y[1:] - y[:-1]))))

def SMAPE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(200 * torch.mean(torch.abs(pred - y) / (torch.abs(y) + torch.abs(pred))))

def MAE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y)))

def sharp_ratio(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean((pred - y) / torch.std(y)))

def directional_accuracy(Y_actual, Y_predicted):
    """
    Calculate the directional accuracy of predictions.

    Parameters:
        Y_actual (array-like): Array of actual stock prices.
        Y_predicted (array-like): Array of predicted stock prices.

    Returns:
        float: Directional accuracy percentage.
    """
    actual_changes = np.sign(np.diff(Y_actual))
    predicted_changes = np.sign(np.diff(Y_predicted))
    correct_predictions = np.sum(actual_changes == predicted_changes)
    total_predictions = len(actual_changes)
    directional_accuracy = correct_predictions / total_predictions * 100
    return directional_accuracy

def evaluate(y_true, y_pred, save=False, model_name="ModelName"):
    performance = {}
    performance['MAPE'] = MAPE(y_true, y_pred)
    performance['MASE'] = MASE(y_true, y_pred)
    performance['RMSE'] = math.sqrt(mean_squared_error(y_true, y_pred))
    performance['SMAPE'] = SMAPE(y_true, y_pred)
    performance['MAE'] = MAE(y_true, y_pred)
    performance['sharp_ratio'] = sharp_ratio(y_true, y_pred)
    performance['Directional Accuracy'] = directional_accuracy(y_true, y_pred)

    if save:
        pd.DataFrame(performance, index=[model_name]).to_csv(f'../performance/{model_name}.csv')
        
    return performance

print( 'MASE =', MASE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'RMSE =', math.sqrt(mean_squared_error(df_test['Open_lead1'], df_test['Model forecast'])) )
print( 'SMAPE =', SMAPE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'MAE =', MAE(df_test['Open_lead1'], df_test['Model forecast']))
print( 'sharp_ratio =', sharp_ratio(df_test['Open_lead1'], df_test['Model forecast']))
print('Directional Accuracy =', directional_accuracy(df_test['Open_lead1'], df_test['Model forecast']))
# Out:
# MASE = 1.4714017610573302
# RMSE = 0.07691748512471508
# SMAPE = 1.7915257074142246
# MAE = 0.0590093564415598
# sharp_ratio = 0.2288923038313096
# Directional Accuracy = 70.52631578947368
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:7: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:8: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:12: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:17: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:18: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
perf = evaluate(df_test['Open_lead1'], df_test['Model forecast'])
perf = pd.DataFrame(perf, index=['ResNLS'])
display(perf)

perf.to_csv('../performance/resnls.csv')
# Out:
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:7: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:8: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:12: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:17: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/8z/qdskhbhn44jfd2ckl12bx6xr0000gn/T/ipykernel_31781/2022029330.py:18: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#             MAPE      MASE      RMSE     SMAPE       MAE  sharp_ratio  \
# ResNLS  1.771263  1.471402  0.076917  1.791526  0.059009     0.228892
#
#         Directional Accuracy
# ResNLS             70.526316

# %%
fig = px.line(df_out, labels={'value': "Open", 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")
# fig.add_annotation(xref="paper", x=0.75, yref="paper", y=0.8, text="Test set start", showarrow=False)
fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
